# %%
# GLOBAL #

import random
import pandas as pd
from collections import defaultdict, Counter
import numpy as np
from itertools import product
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

random.seed(123)
np.random.seed(123)

# %%
# HELPER FUNCTIONS #

# collapse sequence by self-transitions (e.g. [aaaabbbbcccdddccc] = [abcdc]) for collapsed context model
def collapseLength(seq):

    collapsed = []

    for s in seq:
        if not collapsed or collapsed[-1] != s:
            collapsed.append(s)

    return collapsed

# check if tuple has consecutive repeated states (we want to ignore these combinations in collapsed context model transition matrix)
def hasConsecutiveRepeats(states):

    for i in range(len(states) - 1):
        if states[i] == states[i + 1]:
            return True
        
    return False

# find indices of first state in each state run within sequence (e.g., [aaaabbbbcccdddccccc] = [0, 4, 8, 11, 14])
def uniqueIdxs(seq):

    lasts = []
    runChar = seq[0]

    for i, s in enumerate(seq[1:], start=1):
        if s != runChar:
            lasts.append(i - 1)
            runChar = s

    lasts.append(len(seq) - 1)
    return lasts

# expand  numeric vector into repetitions corresponding to each number value (e.g., [0, 4, 8, 11, 14] = [0, 0, 0, 0, 4, 4, 4, 4, 8, 8, 8, 11, 11, 11, 14, 14, 14]) 
# for matching strings to indices in collapsed context model 
def expandVec(vec):

    if not vec:
        return []
    
    result = []

    vecIDX = 0

    for pos in range(vec[-1] + 1):
        while vecIDX < len(vec) - 1 and pos > vec[vecIDX]:
            vecIDX += 1
        result.append(vec[vecIDX])

    return result

#calculate weighted log likelihood of test transitions (unnormalized) under train model (normalized)
def averageLL(trainProbs, testProbs):

    ll = 0.0 # start at zero

    weight = 0.0

    for s, nexts in testProbs.items(): #for each item in the test transition 
        trainContext = trainProbs.get(s) #find matching train model probability

        if trainContext is None:
            continue  
                             # if context unseen in train, skip
        for s2, p_test in nexts.items():
            p_train = trainContext.get(s2)

            if p_train is None or p_train <= 0:
                continue  # if transition unseen in train, skip
                             
            ll += p_test * np.log(p_train)
            weight += p_test

    if weight == 0:
        return np.nan
    
    return ll / weight

## main sampling functions ##

""" general pipeline:

normalize the training set because we are essentially building a smoothed model that we can use to evaluate test set fit
keep test set as count data because we are comparing how well it fits to our smoothed model

 """

##### Lagged Context Markov Sampling--bad performance in synthetic eval, not used #####

# def laggedTransNorm(states, lines, k, smoother, lag):

#     transitions = defaultdict(Counter)
    
#     #for k=0 version, transition matrix turns into simple marginal state distributions
#     if k == 0:
#         for state in states:
#             transitions[()][state] = smoother #add laplace smoother to each curr state

#         for seq in lines:
#             for curr in seq:
#                 transitions[()][curr] += 1 #add one count in corresponding transition cell for each instance of each state

#         total = sum(transitions[()].values())

#         return {(): {s: c / total for s, c in transitions[()].items()}} #normalize

#     for prev in product(states, repeat=k): #add laplace smoother to every combination of prev & curr states

#         for curr in states:
#             transitions[prev][curr] = smoother

#     for seq in lines:
#         seqLength = len(seq)

#         for t in range(k * lag, seqLength):
#             prev = tuple(seq[t - lag * i - 1] for i in reversed(range(k))) # important line: looks back at k previous states each spaced one lag apart, starting from t-1
#             curr = seq[t] # curr state is at time t
#             transitions[prev][curr] += 1 #add 1 count to this prev & curr combination

#     transNorm = {}

#     for cond, counter in transitions.items():
#         total = sum(counter.values())
#         transNorm[cond] = {s: c / total for s, c in counter.items()} #normalize counts by total number of transitions

#     return transNorm

# def laggedTransCount(lines, k, lag):

#     transitions = defaultdict(Counter)

#     # if k is zero, just count instances of each state
#     if k == 0:
#         for seq in lines:
#             for curr in seq:
#                 transitions[()][curr] += 1
#         return transitions
    

#     for seq in lines:
#         seqLength = len(seq)
#         for t in range(k * lag, seqLength):
#             prev = tuple(seq[t - lag * i - 1] for i in reversed(range(k))) # important line: looks back at k previous states each spaced one lag apart, starting from t-1
#             curr = seq[t] # curr state is at time t
#             transitions[prev][curr] += 1  #add 1 count to this prev & curr combination

#     return transitions

### Collapsed Context Markov Sampling ###

def collapsedTransNorm(states, lines, k, smoother):
    
    transitions = defaultdict(Counter)

    #for k=0 version, transition matrix turns into simple marginal state distributions
    if k == 0:
        for state in states:
            transitions[()][state] = smoother #add laplace smoother to each curr state

        for seq in lines:
            for curr in seq:
                transitions[()][curr] += 1 #add one count in corresponding transition cell for each instance of each state

        total = sum(transitions[()].values())

        return {(): {s: c / total for s, c in transitions[()].items()}} #normalize

    for prev in product(states, repeat=k):

        if hasConsecutiveRepeats(prev): #if prev tuple has consecutive repeats, skip (because this cannot be observed when self-transitions are collapsed)
            continue

        for curr in states:
            transitions[prev][curr] = smoother #add laplace smoother to every valid combination of prev & curr states

    for seq in lines:

        idxs = uniqueIdxs(seq) #find indices of unique states in sequence
        idxsExpanded = expandVec(idxs) #expand indices for mapping

        for t in range(1, len(seq)):

            idxsCollapsed = idxs.index(idxsExpanded[t - 1]) #find corresponding index of each token

            if idxsCollapsed < k - 1:
                continue

            prevIdxsUnique = idxs[idxsCollapsed- (k - 1):idxsCollapsed+ 1]
            prev = tuple(seq[i] for i in prevIdxsUnique)
            curr = seq[t]
            transitions[prev][curr] += 1

    transNorm = {}

    for cond, counter in transitions.items():
        total = sum(counter.values())
        transNorm[cond] = {s: c / total for s, c in counter.items()} #normalize 

    return transNorm

def collapsedTransCount(lines, k):

    transitions = defaultdict(Counter)

    # if k is zero, just count instances of each state
    if k == 0:
        for seq in lines:
            for curr in seq:
                transitions[()][curr] += 1

        return transitions
    
    for seq in lines:
        idxs = uniqueIdxs(seq)
        idxsExpanded = expandVec(idxs)

        for t in range(1, len(seq)):
            idxsCollapsed= idxs.index(idxsExpanded[t - 1])

            if idxsCollapsed< k - 1:
                continue

            prevIdxsUnique = idxs[idxsCollapsed- (k - 1):idxsCollapsed+ 1]
            prev = tuple(seq[i] for i in prevIdxsUnique)
            curr = seq[t]
            transitions[prev][curr] += 1

    return transitions

### sample over k's ###

def fitModel(species, i, trainLines, testLines, kMax, smootherSet):
 
    results = []

    #find unique states in corpus
    states = sorted({char for line in trainLines for char in line})

    for k in range(0, kMax + 1):

        for smoother in smootherSet:

            train_trans = collapsedTransNorm(states = states, lines=trainLines, k=k, smoother=smoother)

            test_trans  = collapsedTransCount(lines=testLines, k=k)

            ll = averageLL(train_trans, test_trans)

            results.append({
                'species': species, 'k': k,
                'sim': i,
                'smoother': smoother,
                'log_likelihood': ll,
                'num_train_states': len(train_trans),
                'num_test_states':  len(test_trans),
            })
            print(f"Species {species}, k={k}, "
                    f"smoother={smoother}: LL={ll:.4f}")

    return pd.DataFrame(results)

# %%
# DO IT! #

birds = ("bird1", "bird2", "bird4")

# params to test
nIter = 50
kmax=5
smoothers=[0.001, 0.01, 0.1]
cropped = True

#run iterations
results = []

for bird in birds:

    for i in range(1, nIter+1):

        #random train/test split in each iteration

        if cropped == True:
            filename = f"bird-data/raw/{bird}_cropped_full.txt"  
                     
        else: 
            filename = f"bird-data/raw/{bird}_full.txt"

        with open(filename, "r", encoding="utf-8") as f:
                lines = f.readlines()
 
        train_lines, test_lines = train_test_split(lines, test_size=0.2)
        
        # run markov sampling on this split and save results
        iModel = fitModel(species = bird, i = i, trainLines=train_lines, testLines=test_lines, kMax = kmax, smootherSet = smoothers)

        results.append(iModel)


#save as .csv
results_df = pd.concat(results, ignore_index=True)

if cropped == True:
    savename = "birdResultsCropped.csv" 
else:
    savename = "birdResultsFull.csv"

results_df.to_csv(savename, index=False)
# Out:
# Species bird1, k=0, smoother=0.001: LL=-1.7686
# Species bird1, k=0, smoother=0.01: LL=-1.7686
# Species bird1, k=0, smoother=0.1: LL=-1.7686
# Species bird1, k=1, smoother=0.001: LL=-0.7879
# Species bird1, k=1, smoother=0.01: LL=-0.7872
# Species bird1, k=1, smoother=0.1: LL=-0.7866
# Species bird1, k=2, smoother=0.001: LL=-0.7429
# Species bird1, k=2, smoother=0.01: LL=-0.7418
# Species bird1, k=2, smoother=0.1: LL=-0.7409
# Species bird1, k=3, smoother=0.001: LL=-0.7285
# Species bird1, k=3, smoother=0.01: LL=-0.7265
# Species bird1, k=3, smoother=0.1: LL=-0.7255
# Species bird1, k=4, smoother=0.001: LL=-0.7285
# Species bird1, k=4, smoother=0.01: LL=-0.7256
# Species bird1, k=4, smoother=0.1: LL=-0.7246
# Species bird1, k=5, smoother=0.001: LL=-0.7427
# Species bird1, k=5, smoother=0.01: LL=-0.7362
# Species bird1, k=5, smoother=0.1: LL=-0.7329
# Species bird1, k=0, smoother=0.001: LL=-1.7507
# Species bird1, k=0, smoother=0.01: LL=-1.7507
# Species bird1, k=0, smoother=0.1: LL=-1.7507
# Species bird1, k=1, smoother=0.001: LL=-0.7898
# Species bird1, k=1, smoother=0.01: LL=-0.7898
# Species bird1, k=1, smoother=0.1: LL=-0.7898
# Species bird1, k=2, smoother=0.001: LL=-0.7480
# Species bird1, k=2, smoother=0.01: LL=-0.7466
# Species bird1, k=2, smoother=0.1: LL=-0.7455
# Species bird1, k=3, smoother=0.001: LL=-0.7393
# Species bird1, k=3, smoother=0.01: LL=-0.7374
# Species bird1, k=3, smoother=0.1: LL=-0.7364
# Species bird1, k=4, smoother=0.001: LL=-0.7438
# Species bird1, k=4, smoother=0.01: LL=-0.7397
# Species bird1, k=4, smoother=0.1: LL=-0.7376
# Species bird1, k=5, smoother=0.001: LL=-0.7595
# Species bird1, k=5, smoother=0.01: LL=-0.7509
# Species bird1, k=5, smoother=0.1: LL=-0.7465
# Species bird1, k=0, smoother=0.001: LL=-1.7737
# Species bird1, k=0, smoother=0.01: LL=-1.7737
# Species bird1, k=0, smoother=0.1: LL=-1.7737
# Species bird1, k=1, smoother=0.001: LL=-0.7927
# Species bird1, k=1, smoother=0.01: LL=-0.7924
# Species bird1, k=1, smoother=0.1: LL=-0.7920
# Species bird1, k=2, smoother=0.001: LL=-0.7468
# Species bird1, k=2, smoother=0.01: LL=-0.7449
# Species bird1, k=2, smoother=0.1: LL=-0.7434
# Species bird1, k=3, smoother=0.001: LL=-0.7342
# Species bird1, k=3, smoother=0.01: LL=-0.7319
# Species bird1, k=3, smoother=0.1: LL=-0.7306
# Species bird1, k=4, smoother=0.001: LL=-0.7389
# Species bird1, k=4, smoother=0.01: LL=-0.7336
# Species bird1, k=4, smoother=0.1: LL=-0.7305
# Species bird1, k=5, smoother=0.001: LL=-0.7475
# Species bird1, k=5, smoother=0.01: LL=-0.7403
# Species bird1, k=5, smoother=0.1: LL=-0.7365
# Species bird1, k=0, smoother=0.001: LL=-1.7634
# Species bird1, k=0, smoother=0.01: LL=-1.7634
# Species bird1, k=0, smoother=0.1: LL=-1.7634
# Species bird1, k=1, smoother=0.001: LL=-0.7965
# Species bird1, k=1, smoother=0.01: LL=-0.7959
# Species bird1, k=1, smoother=0.1: LL=-0.7953
# Species bird1, k=2, smoother=0.001: LL=-0.7545
# Species bird1, k=2, smoother=0.01: LL=-0.7529
# Species bird1, k=2, smoother=0.1: LL=-0.7515
# Species bird1, k=3, smoother=0.001: LL=-0.7446
# Species bird1, k=3, smoother=0.01: LL=-0.7427
# Species bird1, k=3, smoother=0.1: LL=-0.7419
# Species bird1, k=4, smoother=0.001: LL=-0.7493
# Species bird1, k=4, smoother=0.01: LL=-0.7453
# Species bird1, k=4, smoother=0.1: LL=-0.7437
# Species bird1, k=5, smoother=0.001: LL=-0.7669
# Species bird1, k=5, smoother=0.01: LL=-0.7582
# Species bird1, k=5, smoother=0.1: LL=-0.7538
# Species bird1, k=0, smoother=0.001: LL=-1.7540
# Species bird1, k=0, smoother=0.01: LL=-1.7540
# Species bird1, k=0, smoother=0.1: LL=-1.7540
# Species bird1, k=1, smoother=0.001: LL=-0.7827
# Species bird1, k=1, smoother=0.01: LL=-0.7827
# Species bird1, k=1, smoother=0.1: LL=-0.7827
# Species bird1, k=2, smoother=0.001: LL=-0.7363
# Species bird1, k=2, smoother=0.01: LL=-0.7358
# Species bird1, k=2, smoother=0.1: LL=-0.7356
# Species bird1, k=3, smoother=0.001: LL=-0.7245
# Species bird1, k=3, smoother=0.01: LL=-0.7231
# Species bird1, k=3, smoother=0.1: LL=-0.7226
# Species bird1, k=4, smoother=0.001: LL=-0.7275
# Species bird1, k=4, smoother=0.01: LL=-0.7247
# Species bird1, k=4, smoother=0.1: LL=-0.7236
# Species bird1, k=5, smoother=0.001: LL=-0.7413
# Species bird1, k=5, smoother=0.01: LL=-0.7337
# Species bird1, k=5, smoother=0.1: LL=-0.7293
# Species bird1, k=0, smoother=0.001: LL=-1.7482
# Species bird1, k=0, smoother=0.01: LL=-1.7482
# Species bird1, k=0, smoother=0.1: LL=-1.7482
# Species bird1, k=1, smoother=0.001: LL=-0.7838
# Species bird1, k=1, smoother=0.01: LL=-0.7838
# Species bird1, k=1, smoother=0.1: LL=-0.7838
# Species bird1, k=2, smoother=0.001: LL=-0.7440
# Species bird1, k=2, smoother=0.01: LL=-0.7421
# Species bird1, k=2, smoother=0.1: LL=-0.7405
# Species bird1, k=3, smoother=0.001: LL=-0.7305
# Species bird1, k=3, smoother=0.01: LL=-0.7291
# Species bird1, k=3, smoother=0.1: LL=-0.7284
# Species bird1, k=4, smoother=0.001: LL=-0.7349
# Species bird1, k=4, smoother=0.01: LL=-0.7316
# Species bird1, k=4, smoother=0.1: LL=-0.7297
# Species bird1, k=5, smoother=0.001: LL=-0.7385
# Species bird1, k=5, smoother=0.01: LL=-0.7338
# Species bird1, k=5, smoother=0.1: LL=-0.7318
# Species bird1, k=0, smoother=0.001: LL=-1.7673
# Species bird1, k=0, smoother=0.01: LL=-1.7673
# Species bird1, k=0, smoother=0.1: LL=-1.7673
# Species bird1, k=1, smoother=0.001: LL=-0.7932
# Species bird1, k=1, smoother=0.01: LL=-0.7930
# Species bird1, k=1, smoother=0.1: LL=-0.7929
# Species bird1, k=2, smoother=0.001: LL=-0.7505
# Species bird1, k=2, smoother=0.01: LL=-0.7487
# Species bird1, k=2, smoother=0.1: LL=-0.7473
# Species bird1, k=3, smoother=0.001: LL=-0.7361
# Species bird1, k=3, smoother=0.01: LL=-0.7342
# Species bird1, k=3, smoother=0.1: LL=-0.7332
# Species bird1, k=4, smoother=0.001: LL=-0.7453
# Species bird1, k=4, smoother=0.01: LL=-0.7404
# Species bird1, k=4, smoother=0.1: LL=-0.7378
# Species bird1, k=5, smoother=0.001: LL=-0.7591
# Species bird1, k=5, smoother=0.01: LL=-0.7493
# Species bird1, k=5, smoother=0.1: LL=-0.7440
# Species bird1, k=0, smoother=0.001: LL=-1.7685
# Species bird1, k=0, smoother=0.01: LL=-1.7685
# Species bird1, k=0, smoother=0.1: LL=-1.7685
# Species bird1, k=1, smoother=0.001: LL=-0.7880
# Species bird1, k=1, smoother=0.01: LL=-0.7877
# Species bird1, k=1, smoother=0.1: LL=-0.7874
# Species bird1, k=2, smoother=0.001: LL=-0.7462
# Species bird1, k=2, smoother=0.01: LL=-0.7442
# Species bird1, k=2, smoother=0.1: LL=-0.7426
# Species bird1, k=3, smoother=0.001: LL=-0.7396
# Species bird1, k=3, smoother=0.01: LL=-0.7365
# Species bird1, k=3, smoother=0.1: LL=-0.7343
# Species bird1, k=4, smoother=0.001: LL=-0.7436
# Species bird1, k=4, smoother=0.01: LL=-0.7392
# Species bird1, k=4, smoother=0.1: LL=-0.7363
# Species bird1, k=5, smoother=0.001: LL=-0.7549
# Species bird1, k=5, smoother=0.01: LL=-0.7474
# Species bird1, k=5, smoother=0.1: LL=-0.7426
# Species bird1, k=0, smoother=0.001: LL=-1.7365
# Species bird1, k=0, smoother=0.01: LL=-1.7365
# Species bird1, k=0, smoother=0.1: LL=-1.7365
# Species bird1, k=1, smoother=0.001: LL=-0.7906
# Species bird1, k=1, smoother=0.01: LL=-0.7906
# Species bird1, k=1, smoother=0.1: LL=-0.7907
# Species bird1, k=2, smoother=0.001: LL=-0.7463
# Species bird1, k=2, smoother=0.01: LL=-0.7452
# Species bird1, k=2, smoother=0.1: LL=-0.7445
# Species bird1, k=3, smoother=0.001: LL=-0.7312
# Species bird1, k=3, smoother=0.01: LL=-0.7296
# Species bird1, k=3, smoother=0.1: LL=-0.7289
# Species bird1, k=4, smoother=0.001: LL=-0.7341
# Species bird1, k=4, smoother=0.01: LL=-0.7311
# Species bird1, k=4, smoother=0.1: LL=-0.7298
# Species bird1, k=5, smoother=0.001: LL=-0.7446
# Species bird1, k=5, smoother=0.01: LL=-0.7383
# Species bird1, k=5, smoother=0.1: LL=-0.7351
# Species bird1, k=0, smoother=0.001: LL=-1.7465
# Species bird1, k=0, smoother=0.01: LL=-1.7465
# Species bird1, k=0, smoother=0.1: LL=-1.7465
# Species bird1, k=1, smoother=0.001: LL=-0.7891
# Species bird1, k=1, smoother=0.01: LL=-0.7889
# Species bird1, k=1, smoother=0.1: LL=-0.7888
# Species bird1, k=2, smoother=0.001: LL=-0.7490
# Species bird1, k=2, smoother=0.01: LL=-0.7468
# Species bird1, k=2, smoother=0.1: LL=-0.7449
# Species bird1, k=3, smoother=0.001: LL=-0.7358
# Species bird1, k=3, smoother=0.01: LL=-0.7333
# Species bird1, k=3, smoother=0.1: LL=-0.7315
# Species bird1, k=4, smoother=0.001: LL=-0.7426
# Species bird1, k=4, smoother=0.01: LL=-0.7379
# Species bird1, k=4, smoother=0.1: LL=-0.7348
# Species bird1, k=5, smoother=0.001: LL=-0.7428
# Species bird1, k=5, smoother=0.01: LL=-0.7384
# Species bird1, k=5, smoother=0.1: LL=-0.7364
# Species bird1, k=0, smoother=0.001: LL=-1.7649
# Species bird1, k=0, smoother=0.01: LL=-1.7649
# Species bird1, k=0, smoother=0.1: LL=-1.7649
# Species bird1, k=1, smoother=0.001: LL=-0.7844
# Species bird1, k=1, smoother=0.01: LL=-0.7837
# Species bird1, k=1, smoother=0.1: LL=-0.7831
# Species bird1, k=2, smoother=0.001: LL=-0.7424
# Species bird1, k=2, smoother=0.01: LL=-0.7413
# Species bird1, k=2, smoother=0.1: LL=-0.7406
# Species bird1, k=3, smoother=0.001: LL=-0.7320
# Species bird1, k=3, smoother=0.01: LL=-0.7295
# Species bird1, k=3, smoother=0.1: LL=-0.7276
# Species bird1, k=4, smoother=0.001: LL=-0.7381
# Species bird1, k=4, smoother=0.01: LL=-0.7345
# Species bird1, k=4, smoother=0.1: LL=-0.7323
# Species bird1, k=5, smoother=0.001: LL=-0.7479
# Species bird1, k=5, smoother=0.01: LL=-0.7419
# Species bird1, k=5, smoother=0.1: LL=-0.7380
# Species bird1, k=0, smoother=0.001: LL=-1.7641
# Species bird1, k=0, smoother=0.01: LL=-1.7641
# Species bird1, k=0, smoother=0.1: LL=-1.7641
# Species bird1, k=1, smoother=0.001: LL=-0.7905
# Species bird1, k=1, smoother=0.01: LL=-0.7900
# Species bird1, k=1, smoother=0.1: LL=-0.7896
# Species bird1, k=2, smoother=0.001: LL=-0.7439
# Species bird1, k=2, smoother=0.01: LL=-0.7427
# Species bird1, k=2, smoother=0.1: LL=-0.7418
# Species bird1, k=3, smoother=0.001: LL=-0.7358
# Species bird1, k=3, smoother=0.01: LL=-0.7328
# Species bird1, k=3, smoother=0.1: LL=-0.7306
# Species bird1, k=4, smoother=0.001: LL=-0.7402
# Species bird1, k=4, smoother=0.01: LL=-0.7373
# Species bird1, k=4, smoother=0.1: LL=-0.7359
# Species bird1, k=5, smoother=0.001: LL=-0.7477
# Species bird1, k=5, smoother=0.01: LL=-0.7416
# Species bird1, k=5, smoother=0.1: LL=-0.7384
# Species bird1, k=0, smoother=0.001: LL=-1.7815
# Species bird1, k=0, smoother=0.01: LL=-1.7815
# Species bird1, k=0, smoother=0.1: LL=-1.7815
# Species bird1, k=1, smoother=0.001: LL=-0.7906
# Species bird1, k=1, smoother=0.01: LL=-0.7904
# Species bird1, k=1, smoother=0.1: LL=-0.7903
# Species bird1, k=2, smoother=0.001: LL=-0.7511
# Species bird1, k=2, smoother=0.01: LL=-0.7493
# Species bird1, k=2, smoother=0.1: LL=-0.7480
# Species bird1, k=3, smoother=0.001: LL=-0.7425
# Species bird1, k=3, smoother=0.01: LL=-0.7386
# Species bird1, k=3, smoother=0.1: LL=-0.7362
# Species bird1, k=4, smoother=0.001: LL=-0.7485
# Species bird1, k=4, smoother=0.01: LL=-0.7428
# Species bird1, k=4, smoother=0.1: LL=-0.7395
# Species bird1, k=5, smoother=0.001: LL=-0.7597
# Species bird1, k=5, smoother=0.01: LL=-0.7524
# Species bird1, k=5, smoother=0.1: LL=-0.7486
# Species bird1, k=0, smoother=0.001: LL=-1.7562
# Species bird1, k=0, smoother=0.01: LL=-1.7562
# Species bird1, k=0, smoother=0.1: LL=-1.7562
# Species bird1, k=1, smoother=0.001: LL=-0.7864
# Species bird1, k=1, smoother=0.01: LL=-0.7859
# Species bird1, k=1, smoother=0.1: LL=-0.7854
# Species bird1, k=2, smoother=0.001: LL=-0.7380
# Species bird1, k=2, smoother=0.01: LL=-0.7372
# Species bird1, k=2, smoother=0.1: LL=-0.7367
# Species bird1, k=3, smoother=0.001: LL=-0.7293
# Species bird1, k=3, smoother=0.01: LL=-0.7268
# Species bird1, k=3, smoother=0.1: LL=-0.7253
# Species bird1, k=4, smoother=0.001: LL=-0.7349
# Species bird1, k=4, smoother=0.01: LL=-0.7306
# Species bird1, k=4, smoother=0.1: LL=-0.7281
# Species bird1, k=5, smoother=0.001: LL=-0.7443
# Species bird1, k=5, smoother=0.01: LL=-0.7372
# Species bird1, k=5, smoother=0.1: LL=-0.7331
# Species bird1, k=0, smoother=0.001: LL=-1.7750
# Species bird1, k=0, smoother=0.01: LL=-1.7750
# Species bird1, k=0, smoother=0.1: LL=-1.7750
# Species bird1, k=1, smoother=0.001: LL=-0.7808
# Species bird1, k=1, smoother=0.01: LL=-0.7808
# Species bird1, k=1, smoother=0.1: LL=-0.7808
# Species bird1, k=2, smoother=0.001: LL=-0.7389
# Species bird1, k=2, smoother=0.01: LL=-0.7372
# Species bird1, k=2, smoother=0.1: LL=-0.7360
# Species bird1, k=3, smoother=0.001: LL=-0.7252
# Species bird1, k=3, smoother=0.01: LL=-0.7229
# Species bird1, k=3, smoother=0.1: LL=-0.7216
# Species bird1, k=4, smoother=0.001: LL=-0.7274
# Species bird1, k=4, smoother=0.01: LL=-0.7235
# Species bird1, k=4, smoother=0.1: LL=-0.7216
# Species bird1, k=5, smoother=0.001: LL=-0.7452
# Species bird1, k=5, smoother=0.01: LL=-0.7372
# Species bird1, k=5, smoother=0.1: LL=-0.7324
# Species bird1, k=0, smoother=0.001: LL=-1.7658
# Species bird1, k=0, smoother=0.01: LL=-1.7658
# Species bird1, k=0, smoother=0.1: LL=-1.7658
# Species bird1, k=1, smoother=0.001: LL=-0.7878
# Species bird1, k=1, smoother=0.01: LL=-0.7873
# Species bird1, k=1, smoother=0.1: LL=-0.7869
# Species bird1, k=2, smoother=0.001: LL=-0.7407
# Species bird1, k=2, smoother=0.01: LL=-0.7395
# Species bird1, k=2, smoother=0.1: LL=-0.7384
# Species bird1, k=3, smoother=0.001: LL=-0.7259
# Species bird1, k=3, smoother=0.01: LL=-0.7235
# Species bird1, k=3, smoother=0.1: LL=-0.7219
# Species bird1, k=4, smoother=0.001: LL=-0.7263
# Species bird1, k=4, smoother=0.01: LL=-0.7230
# Species bird1, k=4, smoother=0.1: LL=-0.7210
# Species bird1, k=5, smoother=0.001: LL=-0.7297
# Species bird1, k=5, smoother=0.01: LL=-0.7243
# Species bird1, k=5, smoother=0.1: LL=-0.7211
# Species bird1, k=0, smoother=0.001: LL=-1.7610
# Species bird1, k=0, smoother=0.01: LL=-1.7610
# Species bird1, k=0, smoother=0.1: LL=-1.7610
# Species bird1, k=1, smoother=0.001: LL=-0.7836
# Species bird1, k=1, smoother=0.01: LL=-0.7833
# Species bird1, k=1, smoother=0.1: LL=-0.7830
# Species bird1, k=2, smoother=0.001: LL=-0.7427
# Species bird1, k=2, smoother=0.01: LL=-0.7416
# Species bird1, k=2, smoother=0.1: LL=-0.7408
# Species bird1, k=3, smoother=0.001: LL=-0.7336
# Species bird1, k=3, smoother=0.01: LL=-0.7304
# Species bird1, k=3, smoother=0.1: LL=-0.7284
# Species bird1, k=4, smoother=0.001: LL=-0.7385
# Species bird1, k=4, smoother=0.01: LL=-0.7342
# Species bird1, k=4, smoother=0.1: LL=-0.7321
# Species bird1, k=5, smoother=0.001: LL=-0.7466
# Species bird1, k=5, smoother=0.01: LL=-0.7400
# Species bird1, k=5, smoother=0.1: LL=-0.7370
# Species bird1, k=0, smoother=0.001: LL=-1.7621
# Species bird1, k=0, smoother=0.01: LL=-1.7621
# Species bird1, k=0, smoother=0.1: LL=-1.7621
# Species bird1, k=1, smoother=0.001: LL=-0.7845
# Species bird1, k=1, smoother=0.01: LL=-0.7843
# Species bird1, k=1, smoother=0.1: LL=-0.7842
# Species bird1, k=2, smoother=0.001: LL=-0.7421
# Species bird1, k=2, smoother=0.01: LL=-0.7402
# Species bird1, k=2, smoother=0.1: LL=-0.7386
# Species bird1, k=3, smoother=0.001: LL=-0.7324
# Species bird1, k=3, smoother=0.01: LL=-0.7290
# Species bird1, k=3, smoother=0.1: LL=-0.7265
# Species bird1, k=4, smoother=0.001: LL=-0.7351
# Species bird1, k=4, smoother=0.01: LL=-0.7316
# Species bird1, k=4, smoother=0.1: LL=-0.7296
# Species bird1, k=5, smoother=0.001: LL=-0.7430
# Species bird1, k=5, smoother=0.01: LL=-0.7386
# Species bird1, k=5, smoother=0.1: LL=-0.7367
# Species bird1, k=0, smoother=0.001: LL=-1.7505
# Species bird1, k=0, smoother=0.01: LL=-1.7505
# Species bird1, k=0, smoother=0.1: LL=-1.7505
# Species bird1, k=1, smoother=0.001: LL=-0.7829
# Species bird1, k=1, smoother=0.01: LL=-0.7827
# Species bird1, k=1, smoother=0.1: LL=-0.7826
# Species bird1, k=2, smoother=0.001: LL=-0.7416
# Species bird1, k=2, smoother=0.01: LL=-0.7400
# Species bird1, k=2, smoother=0.1: LL=-0.7388
# Species bird1, k=3, smoother=0.001: LL=-0.7280
# Species bird1, k=3, smoother=0.01: LL=-0.7263
# Species bird1, k=3, smoother=0.1: LL=-0.7253
# Species bird1, k=4, smoother=0.001: LL=-0.7346
# Species bird1, k=4, smoother=0.01: LL=-0.7310
# Species bird1, k=4, smoother=0.1: LL=-0.7290
# Species bird1, k=5, smoother=0.001: LL=-0.7385
# Species bird1, k=5, smoother=0.01: LL=-0.7342
# Species bird1, k=5, smoother=0.1: LL=-0.7326
# Species bird1, k=0, smoother=0.001: LL=-1.7524
# Species bird1, k=0, smoother=0.01: LL=-1.7524
# Species bird1, k=0, smoother=0.1: LL=-1.7524
# Species bird1, k=1, smoother=0.001: LL=-0.7791
# Species bird1, k=1, smoother=0.01: LL=-0.7791
# Species bird1, k=1, smoother=0.1: LL=-0.7792
# Species bird1, k=2, smoother=0.001: LL=-0.7347
# Species bird1, k=2, smoother=0.01: LL=-0.7342
# Species bird1, k=2, smoother=0.1: LL=-0.7340
# Species bird1, k=3, smoother=0.001: LL=-0.7191
# Species bird1, k=3, smoother=0.01: LL=-0.7183
# Species bird1, k=3, smoother=0.1: LL=-0.7181
# Species bird1, k=4, smoother=0.001: LL=-0.7228
# Species bird1, k=4, smoother=0.01: LL=-0.7195
# Species bird1, k=4, smoother=0.1: LL=-0.7180
# Species bird1, k=5, smoother=0.001: LL=-0.7246
# Species bird1, k=5, smoother=0.01: LL=-0.7209
# Species bird1, k=5, smoother=0.1: LL=-0.7196
# Species bird1, k=0, smoother=0.001: LL=-1.7659
# Species bird1, k=0, smoother=0.01: LL=-1.7659
# Species bird1, k=0, smoother=0.1: LL=-1.7659
# Species bird1, k=1, smoother=0.001: LL=-0.7845
# Species bird1, k=1, smoother=0.01: LL=-0.7840
# Species bird1, k=1, smoother=0.1: LL=-0.7835
# Species bird1, k=2, smoother=0.001: LL=-0.7433
# Species bird1, k=2, smoother=0.01: LL=-0.7416
# Species bird1, k=2, smoother=0.1: LL=-0.7402
# Species bird1, k=3, smoother=0.001: LL=-0.7334
# Species bird1, k=3, smoother=0.01: LL=-0.7299
# Species bird1, k=3, smoother=0.1: LL=-0.7275
# Species bird1, k=4, smoother=0.001: LL=-0.7367
# Species bird1, k=4, smoother=0.01: LL=-0.7332
# Species bird1, k=4, smoother=0.1: LL=-0.7314
# Species bird1, k=5, smoother=0.001: LL=-0.7491
# Species bird1, k=5, smoother=0.01: LL=-0.7413
# Species bird1, k=5, smoother=0.1: LL=-0.7368
# Species bird1, k=0, smoother=0.001: LL=-1.7747
# Species bird1, k=0, smoother=0.01: LL=-1.7747
# Species bird1, k=0, smoother=0.1: LL=-1.7747
# Species bird1, k=1, smoother=0.001: LL=-0.7917
# Species bird1, k=1, smoother=0.01: LL=-0.7912
# Species bird1, k=1, smoother=0.1: LL=-0.7907
# Species bird1, k=2, smoother=0.001: LL=-0.7463
# Species bird1, k=2, smoother=0.01: LL=-0.7451
# Species bird1, k=2, smoother=0.1: LL=-0.7443
# Species bird1, k=3, smoother=0.001: LL=-0.7362
# Species bird1, k=3, smoother=0.01: LL=-0.7341
# Species bird1, k=3, smoother=0.1: LL=-0.7329
# Species bird1, k=4, smoother=0.001: LL=-0.7382
# Species bird1, k=4, smoother=0.01: LL=-0.7358
# Species bird1, k=4, smoother=0.1: LL=-0.7351
# Species bird1, k=5, smoother=0.001: LL=-0.7556
# Species bird1, k=5, smoother=0.01: LL=-0.7474
# Species bird1, k=5, smoother=0.1: LL=-0.7426
# Species bird1, k=0, smoother=0.001: LL=-1.7634
# Species bird1, k=0, smoother=0.01: LL=-1.7634
# Species bird1, k=0, smoother=0.1: LL=-1.7634
# Species bird1, k=1, smoother=0.001: LL=-0.7827
# Species bird1, k=1, smoother=0.01: LL=-0.7827
# Species bird1, k=1, smoother=0.1: LL=-0.7828
# Species bird1, k=2, smoother=0.001: LL=-0.7405
# Species bird1, k=2, smoother=0.01: LL=-0.7398
# Species bird1, k=2, smoother=0.1: LL=-0.7393
# Species bird1, k=3, smoother=0.001: LL=-0.7262
# Species bird1, k=3, smoother=0.01: LL=-0.7256
# Species bird1, k=3, smoother=0.1: LL=-0.7257
# Species bird1, k=4, smoother=0.001: LL=-0.7274
# Species bird1, k=4, smoother=0.01: LL=-0.7246
# Species bird1, k=4, smoother=0.1: LL=-0.7238
# Species bird1, k=5, smoother=0.001: LL=-0.7452
# Species bird1, k=5, smoother=0.01: LL=-0.7381
# Species bird1, k=5, smoother=0.1: LL=-0.7345
# Species bird1, k=0, smoother=0.001: LL=-1.7840
# Species bird1, k=0, smoother=0.01: LL=-1.7840
# Species bird1, k=0, smoother=0.1: LL=-1.7840
# Species bird1, k=1, smoother=0.001: LL=-0.7868
# Species bird1, k=1, smoother=0.01: LL=-0.7863
# Species bird1, k=1, smoother=0.1: LL=-0.7858
# Species bird1, k=2, smoother=0.001: LL=-0.7458
# Species bird1, k=2, smoother=0.01: LL=-0.7428
# Species bird1, k=2, smoother=0.1: LL=-0.7404
# Species bird1, k=3, smoother=0.001: LL=-0.7354
# Species bird1, k=3, smoother=0.01: LL=-0.7305
# Species bird1, k=3, smoother=0.1: LL=-0.7270
# Species bird1, k=4, smoother=0.001: LL=-0.7405
# Species bird1, k=4, smoother=0.01: LL=-0.7349
# Species bird1, k=4, smoother=0.1: LL=-0.7313
# Species bird1, k=5, smoother=0.001: LL=-0.7589
# Species bird1, k=5, smoother=0.01: LL=-0.7505
# Species bird1, k=5, smoother=0.1: LL=-0.7454
# Species bird1, k=0, smoother=0.001: LL=-1.7495
# Species bird1, k=0, smoother=0.01: LL=-1.7495
# Species bird1, k=0, smoother=0.1: LL=-1.7495
# Species bird1, k=1, smoother=0.001: LL=-0.7798
# Species bird1, k=1, smoother=0.01: LL=-0.7793
# Species bird1, k=1, smoother=0.1: LL=-0.7789
# Species bird1, k=2, smoother=0.001: LL=-0.7418
# Species bird1, k=2, smoother=0.01: LL=-0.7400
# Species bird1, k=2, smoother=0.1: LL=-0.7385
# Species bird1, k=3, smoother=0.001: LL=-0.7295
# Species bird1, k=3, smoother=0.01: LL=-0.7275
# Species bird1, k=3, smoother=0.1: LL=-0.7263
# Species bird1, k=4, smoother=0.001: LL=-0.7295
# Species bird1, k=4, smoother=0.01: LL=-0.7271
# Species bird1, k=4, smoother=0.1: LL=-0.7259
# Species bird1, k=5, smoother=0.001: LL=-0.7376
# Species bird1, k=5, smoother=0.01: LL=-0.7329
# Species bird1, k=5, smoother=0.1: LL=-0.7302
# Species bird1, k=0, smoother=0.001: LL=-1.7428
# Species bird1, k=0, smoother=0.01: LL=-1.7428
# Species bird1, k=0, smoother=0.1: LL=-1.7428
# Species bird1, k=1, smoother=0.001: LL=-0.7906
# Species bird1, k=1, smoother=0.01: LL=-0.7902
# Species bird1, k=1, smoother=0.1: LL=-0.7899
# Species bird1, k=2, smoother=0.001: LL=-0.7506
# Species bird1, k=2, smoother=0.01: LL=-0.7493
# Species bird1, k=2, smoother=0.1: LL=-0.7483
# Species bird1, k=3, smoother=0.001: LL=-0.7421
# Species bird1, k=3, smoother=0.01: LL=-0.7392
# Species bird1, k=3, smoother=0.1: LL=-0.7371
# Species bird1, k=4, smoother=0.001: LL=-0.7510
# Species bird1, k=4, smoother=0.01: LL=-0.7469
# Species bird1, k=4, smoother=0.1: LL=-0.7444
# Species bird1, k=5, smoother=0.001: LL=-0.7693
# Species bird1, k=5, smoother=0.01: LL=-0.7599
# Species bird1, k=5, smoother=0.1: LL=-0.7538
# Species bird1, k=0, smoother=0.001: LL=-1.7509
# Species bird1, k=0, smoother=0.01: LL=-1.7509
# Species bird1, k=0, smoother=0.1: LL=-1.7509
# Species bird1, k=1, smoother=0.001: LL=-0.7816
# Species bird1, k=1, smoother=0.01: LL=-0.7814
# Species bird1, k=1, smoother=0.1: LL=-0.7813
# Species bird1, k=2, smoother=0.001: LL=-0.7362
# Species bird1, k=2, smoother=0.01: LL=-0.7349
# Species bird1, k=2, smoother=0.1: LL=-0.7339
# Species bird1, k=3, smoother=0.001: LL=-0.7235
# Species bird1, k=3, smoother=0.01: LL=-0.7216
# Species bird1, k=3, smoother=0.1: LL=-0.7205
# Species bird1, k=4, smoother=0.001: LL=-0.7409
# Species bird1, k=4, smoother=0.01: LL=-0.7334
# Species bird1, k=4, smoother=0.1: LL=-0.7280
# Species bird1, k=5, smoother=0.001: LL=-0.7406
# Species bird1, k=5, smoother=0.01: LL=-0.7343
# Species bird1, k=5, smoother=0.1: LL=-0.7309
# Species bird1, k=0, smoother=0.001: LL=-1.7661
# Species bird1, k=0, smoother=0.01: LL=-1.7661
# Species bird1, k=0, smoother=0.1: LL=-1.7661
# Species bird1, k=1, smoother=0.001: LL=-0.7885
# Species bird1, k=1, smoother=0.01: LL=-0.7884
# Species bird1, k=1, smoother=0.1: LL=-0.7882
# Species bird1, k=2, smoother=0.001: LL=-0.7467
# Species bird1, k=2, smoother=0.01: LL=-0.7450
# Species bird1, k=2, smoother=0.1: LL=-0.7436
# Species bird1, k=3, smoother=0.001: LL=-0.7362
# Species bird1, k=3, smoother=0.01: LL=-0.7332
# Species bird1, k=3, smoother=0.1: LL=-0.7314
# Species bird1, k=4, smoother=0.001: LL=-0.7409
# Species bird1, k=4, smoother=0.01: LL=-0.7352
# Species bird1, k=4, smoother=0.1: LL=-0.7321
# Species bird1, k=5, smoother=0.001: LL=-0.7413
# Species bird1, k=5, smoother=0.01: LL=-0.7368
# Species bird1, k=5, smoother=0.1: LL=-0.7359
# Species bird1, k=0, smoother=0.001: LL=-1.7488
# Species bird1, k=0, smoother=0.01: LL=-1.7488
# Species bird1, k=0, smoother=0.1: LL=-1.7488
# Species bird1, k=1, smoother=0.001: LL=-0.7823
# Species bird1, k=1, smoother=0.01: LL=-0.7821
# Species bird1, k=1, smoother=0.1: LL=-0.7819
# Species bird1, k=2, smoother=0.001: LL=-0.7431
# Species bird1, k=2, smoother=0.01: LL=-0.7415
# Species bird1, k=2, smoother=0.1: LL=-0.7403
# Species bird1, k=3, smoother=0.001: LL=-0.7295
# Species bird1, k=3, smoother=0.01: LL=-0.7278
# Species bird1, k=3, smoother=0.1: LL=-0.7269
# Species bird1, k=4, smoother=0.001: LL=-0.7334
# Species bird1, k=4, smoother=0.01: LL=-0.7307
# Species bird1, k=4, smoother=0.1: LL=-0.7297
# Species bird1, k=5, smoother=0.001: LL=-0.7482
# Species bird1, k=5, smoother=0.01: LL=-0.7405
# Species bird1, k=5, smoother=0.1: LL=-0.7367
# Species bird1, k=0, smoother=0.001: LL=-1.7480
# Species bird1, k=0, smoother=0.01: LL=-1.7480
# Species bird1, k=0, smoother=0.1: LL=-1.7480
# Species bird1, k=1, smoother=0.001: LL=-0.7878
# Species bird1, k=1, smoother=0.01: LL=-0.7878
# Species bird1, k=1, smoother=0.1: LL=-0.7878
# Species bird1, k=2, smoother=0.001: LL=-0.7462
# Species bird1, k=2, smoother=0.01: LL=-0.7449
# Species bird1, k=2, smoother=0.1: LL=-0.7438
# Species bird1, k=3, smoother=0.001: LL=-0.7322
# Species bird1, k=3, smoother=0.01: LL=-0.7310
# Species bird1, k=3, smoother=0.1: LL=-0.7307
# Species bird1, k=4, smoother=0.001: LL=-0.7365
# Species bird1, k=4, smoother=0.01: LL=-0.7332
# Species bird1, k=4, smoother=0.1: LL=-0.7316
# Species bird1, k=5, smoother=0.001: LL=-0.7552
# Species bird1, k=5, smoother=0.01: LL=-0.7479
# Species bird1, k=5, smoother=0.1: LL=-0.7436
# Species bird1, k=0, smoother=0.001: LL=-1.7631
# Species bird1, k=0, smoother=0.01: LL=-1.7631
# Species bird1, k=0, smoother=0.1: LL=-1.7631
# Species bird1, k=1, smoother=0.001: LL=-0.7810
# Species bird1, k=1, smoother=0.01: LL=-0.7810
# Species bird1, k=1, smoother=0.1: LL=-0.7811
# Species bird1, k=2, smoother=0.001: LL=-0.7394
# Species bird1, k=2, smoother=0.01: LL=-0.7391
# Species bird1, k=2, smoother=0.1: LL=-0.7391
# Species bird1, k=3, smoother=0.001: LL=-0.7309
# Species bird1, k=3, smoother=0.01: LL=-0.7288
# Species bird1, k=3, smoother=0.1: LL=-0.7280
# Species bird1, k=4, smoother=0.001: LL=-0.7311
# Species bird1, k=4, smoother=0.01: LL=-0.7277
# Species bird1, k=4, smoother=0.1: LL=-0.7266
# Species bird1, k=5, smoother=0.001: LL=-0.7481
# Species bird1, k=5, smoother=0.01: LL=-0.7401
# Species bird1, k=5, smoother=0.1: LL=-0.7361
# Species bird1, k=0, smoother=0.001: LL=-1.7789
# Species bird1, k=0, smoother=0.01: LL=-1.7789
# Species bird1, k=0, smoother=0.1: LL=-1.7789
# Species bird1, k=1, smoother=0.001: LL=-0.7881
# Species bird1, k=1, smoother=0.01: LL=-0.7879
# Species bird1, k=1, smoother=0.1: LL=-0.7877
# Species bird1, k=2, smoother=0.001: LL=-0.7440
# Species bird1, k=2, smoother=0.01: LL=-0.7426
# Species bird1, k=2, smoother=0.1: LL=-0.7416
# Species bird1, k=3, smoother=0.001: LL=-0.7343
# Species bird1, k=3, smoother=0.01: LL=-0.7312
# Species bird1, k=3, smoother=0.1: LL=-0.7292
# Species bird1, k=4, smoother=0.001: LL=-0.7395
# Species bird1, k=4, smoother=0.01: LL=-0.7344
# Species bird1, k=4, smoother=0.1: LL=-0.7312
# Species bird1, k=5, smoother=0.001: LL=-0.7535
# Species bird1, k=5, smoother=0.01: LL=-0.7456
# Species bird1, k=5, smoother=0.1: LL=-0.7409
# Species bird1, k=0, smoother=0.001: LL=-1.7707
# Species bird1, k=0, smoother=0.01: LL=-1.7707
# Species bird1, k=0, smoother=0.1: LL=-1.7707
# Species bird1, k=1, smoother=0.001: LL=-0.7889
# Species bird1, k=1, smoother=0.01: LL=-0.7882
# Species bird1, k=1, smoother=0.1: LL=-0.7876
# Species bird1, k=2, smoother=0.001: LL=-0.7490
# Species bird1, k=2, smoother=0.01: LL=-0.7472
# Species bird1, k=2, smoother=0.1: LL=-0.7458
# Species bird1, k=3, smoother=0.001: LL=-0.7357
# Species bird1, k=3, smoother=0.01: LL=-0.7331
# Species bird1, k=3, smoother=0.1: LL=-0.7313
# Species bird1, k=4, smoother=0.001: LL=-0.7431
# Species bird1, k=4, smoother=0.01: LL=-0.7388
# Species bird1, k=4, smoother=0.1: LL=-0.7364
# Species bird1, k=5, smoother=0.001: LL=-0.7597
# Species bird1, k=5, smoother=0.01: LL=-0.7510
# Species bird1, k=5, smoother=0.1: LL=-0.7460
# Species bird1, k=0, smoother=0.001: LL=-1.7564
# Species bird1, k=0, smoother=0.01: LL=-1.7564
# Species bird1, k=0, smoother=0.1: LL=-1.7564
# Species bird1, k=1, smoother=0.001: LL=-0.7871
# Species bird1, k=1, smoother=0.01: LL=-0.7868
# Species bird1, k=1, smoother=0.1: LL=-0.7865
# Species bird1, k=2, smoother=0.001: LL=-0.7409
# Species bird1, k=2, smoother=0.01: LL=-0.7399
# Species bird1, k=2, smoother=0.1: LL=-0.7393
# Species bird1, k=3, smoother=0.001: LL=-0.7320
# Species bird1, k=3, smoother=0.01: LL=-0.7295
# Species bird1, k=3, smoother=0.1: LL=-0.7281
# Species bird1, k=4, smoother=0.001: LL=-0.7408
# Species bird1, k=4, smoother=0.01: LL=-0.7345
# Species bird1, k=4, smoother=0.1: LL=-0.7306
# Species bird1, k=5, smoother=0.001: LL=-0.7475
# Species bird1, k=5, smoother=0.01: LL=-0.7393
# Species bird1, k=5, smoother=0.1: LL=-0.7349
# Species bird1, k=0, smoother=0.001: LL=-1.7741
# Species bird1, k=0, smoother=0.01: LL=-1.7741
# Species bird1, k=0, smoother=0.1: LL=-1.7741
# Species bird1, k=1, smoother=0.001: LL=-0.7835
# Species bird1, k=1, smoother=0.01: LL=-0.7830
# Species bird1, k=1, smoother=0.1: LL=-0.7825
# Species bird1, k=2, smoother=0.001: LL=-0.7446
# Species bird1, k=2, smoother=0.01: LL=-0.7427
# Species bird1, k=2, smoother=0.1: LL=-0.7410
# Species bird1, k=3, smoother=0.001: LL=-0.7377
# Species bird1, k=3, smoother=0.01: LL=-0.7346
# Species bird1, k=3, smoother=0.1: LL=-0.7325
# Species bird1, k=4, smoother=0.001: LL=-0.7401
# Species bird1, k=4, smoother=0.01: LL=-0.7362
# Species bird1, k=4, smoother=0.1: LL=-0.7340
# Species bird1, k=5, smoother=0.001: LL=-0.7487
# Species bird1, k=5, smoother=0.01: LL=-0.7430
# Species bird1, k=5, smoother=0.1: LL=-0.7401
# Species bird1, k=0, smoother=0.001: LL=-1.7651
# Species bird1, k=0, smoother=0.01: LL=-1.7651
# Species bird1, k=0, smoother=0.1: LL=-1.7651
# Species bird1, k=1, smoother=0.001: LL=-0.7783
# Species bird1, k=1, smoother=0.01: LL=-0.7782
# Species bird1, k=1, smoother=0.1: LL=-0.7780
# Species bird1, k=2, smoother=0.001: LL=-0.7372
# Species bird1, k=2, smoother=0.01: LL=-0.7363
# Species bird1, k=2, smoother=0.1: LL=-0.7358
# Species bird1, k=3, smoother=0.001: LL=-0.7288
# Species bird1, k=3, smoother=0.01: LL=-0.7265
# Species bird1, k=3, smoother=0.1: LL=-0.7253
# Species bird1, k=4, smoother=0.001: LL=-0.7275
# Species bird1, k=4, smoother=0.01: LL=-0.7243
# Species bird1, k=4, smoother=0.1: LL=-0.7232
# Species bird1, k=5, smoother=0.001: LL=-0.7455
# Species bird1, k=5, smoother=0.01: LL=-0.7367
# Species bird1, k=5, smoother=0.1: LL=-0.7319
# Species bird1, k=0, smoother=0.001: LL=-1.7665
# Species bird1, k=0, smoother=0.01: LL=-1.7665
# Species bird1, k=0, smoother=0.1: LL=-1.7665
# Species bird1, k=1, smoother=0.001: LL=-0.7838
# Species bird1, k=1, smoother=0.01: LL=-0.7837
# Species bird1, k=1, smoother=0.1: LL=-0.7835
# Species bird1, k=2, smoother=0.001: LL=-0.7414
# Species bird1, k=2, smoother=0.01: LL=-0.7399
# Species bird1, k=2, smoother=0.1: LL=-0.7386
# Species bird1, k=3, smoother=0.001: LL=-0.7327
# Species bird1, k=3, smoother=0.01: LL=-0.7302
# Species bird1, k=3, smoother=0.1: LL=-0.7286
# Species bird1, k=4, smoother=0.001: LL=-0.7340
# Species bird1, k=4, smoother=0.01: LL=-0.7312
# Species bird1, k=4, smoother=0.1: LL=-0.7301
# Species bird1, k=5, smoother=0.001: LL=-0.7449
# Species bird1, k=5, smoother=0.01: LL=-0.7387
# Species bird1, k=5, smoother=0.1: LL=-0.7355
# Species bird1, k=0, smoother=0.001: LL=-1.7677
# Species bird1, k=0, smoother=0.01: LL=-1.7677
# Species bird1, k=0, smoother=0.1: LL=-1.7677
# Species bird1, k=1, smoother=0.001: LL=-0.7924
# Species bird1, k=1, smoother=0.01: LL=-0.7924
# Species bird1, k=1, smoother=0.1: LL=-0.7924
# Species bird1, k=2, smoother=0.001: LL=-0.7470
# Species bird1, k=2, smoother=0.01: LL=-0.7452
# Species bird1, k=2, smoother=0.1: LL=-0.7438
# Species bird1, k=3, smoother=0.001: LL=-0.7371
# Species bird1, k=3, smoother=0.01: LL=-0.7336
# Species bird1, k=3, smoother=0.1: LL=-0.7315
# Species bird1, k=4, smoother=0.001: LL=-0.7441
# Species bird1, k=4, smoother=0.01: LL=-0.7382
# Species bird1, k=4, smoother=0.1: LL=-0.7348
# Species bird1, k=5, smoother=0.001: LL=-0.7470
# Species bird1, k=5, smoother=0.01: LL=-0.7413
# Species bird1, k=5, smoother=0.1: LL=-0.7389
# Species bird1, k=0, smoother=0.001: LL=-1.7516
# Species bird1, k=0, smoother=0.01: LL=-1.7516
# Species bird1, k=0, smoother=0.1: LL=-1.7516
# Species bird1, k=1, smoother=0.001: LL=-0.7846
# Species bird1, k=1, smoother=0.01: LL=-0.7841
# Species bird1, k=1, smoother=0.1: LL=-0.7836
# Species bird1, k=2, smoother=0.001: LL=-0.7429
# Species bird1, k=2, smoother=0.01: LL=-0.7414
# Species bird1, k=2, smoother=0.1: LL=-0.7403
# Species bird1, k=3, smoother=0.001: LL=-0.7333
# Species bird1, k=3, smoother=0.01: LL=-0.7308
# Species bird1, k=3, smoother=0.1: LL=-0.7290
# Species bird1, k=4, smoother=0.001: LL=-0.7361
# Species bird1, k=4, smoother=0.01: LL=-0.7310
# Species bird1, k=4, smoother=0.1: LL=-0.7279
# Species bird1, k=5, smoother=0.001: LL=-0.7369
# Species bird1, k=5, smoother=0.01: LL=-0.7323
# Species bird1, k=5, smoother=0.1: LL=-0.7303
# Species bird1, k=0, smoother=0.001: LL=-1.7626
# Species bird1, k=0, smoother=0.01: LL=-1.7626
# Species bird1, k=0, smoother=0.1: LL=-1.7626
# Species bird1, k=1, smoother=0.001: LL=-0.7885
# Species bird1, k=1, smoother=0.01: LL=-0.7881
# Species bird1, k=1, smoother=0.1: LL=-0.7878
# Species bird1, k=2, smoother=0.001: LL=-0.7463
# Species bird1, k=2, smoother=0.01: LL=-0.7440
# Species bird1, k=2, smoother=0.1: LL=-0.7419
# Species bird1, k=3, smoother=0.001: LL=-0.7348
# Species bird1, k=3, smoother=0.01: LL=-0.7319
# Species bird1, k=3, smoother=0.1: LL=-0.7299
# Species bird1, k=4, smoother=0.001: LL=-0.7369
# Species bird1, k=4, smoother=0.01: LL=-0.7321
# Species bird1, k=4, smoother=0.1: LL=-0.7293
# Species bird1, k=5, smoother=0.001: LL=-0.7430
# Species bird1, k=5, smoother=0.01: LL=-0.7363
# Species bird1, k=5, smoother=0.1: LL=-0.7329
# Species bird1, k=0, smoother=0.001: LL=-1.7527
# Species bird1, k=0, smoother=0.01: LL=-1.7527
# Species bird1, k=0, smoother=0.1: LL=-1.7527
# Species bird1, k=1, smoother=0.001: LL=-0.7783
# Species bird1, k=1, smoother=0.01: LL=-0.7783
# Species bird1, k=1, smoother=0.1: LL=-0.7784
# Species bird1, k=2, smoother=0.001: LL=-0.7383
# Species bird1, k=2, smoother=0.01: LL=-0.7373
# Species bird1, k=2, smoother=0.1: LL=-0.7366
# Species bird1, k=3, smoother=0.001: LL=-0.7243
# Species bird1, k=3, smoother=0.01: LL=-0.7235
# Species bird1, k=3, smoother=0.1: LL=-0.7232
# Species bird1, k=4, smoother=0.001: LL=-0.7241
# Species bird1, k=4, smoother=0.01: LL=-0.7224
# Species bird1, k=4, smoother=0.1: LL=-0.7222
# Species bird1, k=5, smoother=0.001: LL=-0.7332
# Species bird1, k=5, smoother=0.01: LL=-0.7296
# Species bird1, k=5, smoother=0.1: LL=-0.7287
# Species bird1, k=0, smoother=0.001: LL=-1.7587
# Species bird1, k=0, smoother=0.01: LL=-1.7587
# Species bird1, k=0, smoother=0.1: LL=-1.7587
# Species bird1, k=1, smoother=0.001: LL=-0.7878
# Species bird1, k=1, smoother=0.01: LL=-0.7875
# Species bird1, k=1, smoother=0.1: LL=-0.7871
# Species bird1, k=2, smoother=0.001: LL=-0.7447
# Species bird1, k=2, smoother=0.01: LL=-0.7429
# Species bird1, k=2, smoother=0.1: LL=-0.7415
# Species bird1, k=3, smoother=0.001: LL=-0.7339
# Species bird1, k=3, smoother=0.01: LL=-0.7326
# Species bird1, k=3, smoother=0.1: LL=-0.7325
# Species bird1, k=4, smoother=0.001: LL=-0.7390
# Species bird1, k=4, smoother=0.01: LL=-0.7354
# Species bird1, k=4, smoother=0.1: LL=-0.7340
# Species bird1, k=5, smoother=0.001: LL=-0.7688
# Species bird1, k=5, smoother=0.01: LL=-0.7566
# Species bird1, k=5, smoother=0.1: LL=-0.7489
# Species bird1, k=0, smoother=0.001: LL=-1.7973
# Species bird1, k=0, smoother=0.01: LL=-1.7973
# Species bird1, k=0, smoother=0.1: LL=-1.7973
# Species bird1, k=1, smoother=0.001: LL=-0.7892
# Species bird1, k=1, smoother=0.01: LL=-0.7885
# Species bird1, k=1, smoother=0.1: LL=-0.7879
# Species bird1, k=2, smoother=0.001: LL=-0.7447
# Species bird1, k=2, smoother=0.01: LL=-0.7429
# Species bird1, k=2, smoother=0.1: LL=-0.7414
# Species bird1, k=3, smoother=0.001: LL=-0.7331
# Species bird1, k=3, smoother=0.01: LL=-0.7305
# Species bird1, k=3, smoother=0.1: LL=-0.7288
# Species bird1, k=4, smoother=0.001: LL=-0.7303
# Species bird1, k=4, smoother=0.01: LL=-0.7273
# Species bird1, k=4, smoother=0.1: LL=-0.7260
# Species bird1, k=5, smoother=0.001: LL=-0.7378
# Species bird1, k=5, smoother=0.01: LL=-0.7331
# Species bird1, k=5, smoother=0.1: LL=-0.7307
# Species bird1, k=0, smoother=0.001: LL=-1.7743
# Species bird1, k=0, smoother=0.01: LL=-1.7743
# Species bird1, k=0, smoother=0.1: LL=-1.7743
# Species bird1, k=1, smoother=0.001: LL=-0.7846
# Species bird1, k=1, smoother=0.01: LL=-0.7846
# Species bird1, k=1, smoother=0.1: LL=-0.7846
# Species bird1, k=2, smoother=0.001: LL=-0.7398
# Species bird1, k=2, smoother=0.01: LL=-0.7391
# Species bird1, k=2, smoother=0.1: LL=-0.7388
# Species bird1, k=3, smoother=0.001: LL=-0.7262
# Species bird1, k=3, smoother=0.01: LL=-0.7251
# Species bird1, k=3, smoother=0.1: LL=-0.7247
# Species bird1, k=4, smoother=0.001: LL=-0.7304
# Species bird1, k=4, smoother=0.01: LL=-0.7277
# Species bird1, k=4, smoother=0.1: LL=-0.7269
# Species bird1, k=5, smoother=0.001: LL=-0.7373
# Species bird1, k=5, smoother=0.01: LL=-0.7332
# Species bird1, k=5, smoother=0.1: LL=-0.7320
# Species bird1, k=0, smoother=0.001: LL=-1.7561
# Species bird1, k=0, smoother=0.01: LL=-1.7561
# Species bird1, k=0, smoother=0.1: LL=-1.7561
# Species bird1, k=1, smoother=0.001: LL=-0.7826
# Species bird1, k=1, smoother=0.01: LL=-0.7825
# Species bird1, k=1, smoother=0.1: LL=-0.7823
# Species bird1, k=2, smoother=0.001: LL=-0.7391
# Species bird1, k=2, smoother=0.01: LL=-0.7384
# Species bird1, k=2, smoother=0.1: LL=-0.7381
# Species bird1, k=3, smoother=0.001: LL=-0.7278
# Species bird1, k=3, smoother=0.01: LL=-0.7262
# Species bird1, k=3, smoother=0.1: LL=-0.7257
# Species bird1, k=4, smoother=0.001: LL=-0.7398
# Species bird1, k=4, smoother=0.01: LL=-0.7336
# Species bird1, k=4, smoother=0.1: LL=-0.7297
# Species bird1, k=5, smoother=0.001: LL=-0.7590
# Species bird1, k=5, smoother=0.01: LL=-0.7486
# Species bird1, k=5, smoother=0.1: LL=-0.7416
# Species bird1, k=0, smoother=0.001: LL=-1.7784
# Species bird1, k=0, smoother=0.01: LL=-1.7784
# Species bird1, k=0, smoother=0.1: LL=-1.7784
# Species bird1, k=1, smoother=0.001: LL=-0.7938
# Species bird1, k=1, smoother=0.01: LL=-0.7933
# Species bird1, k=1, smoother=0.1: LL=-0.7928
# Species bird1, k=2, smoother=0.001: LL=-0.7471
# Species bird1, k=2, smoother=0.01: LL=-0.7455
# Species bird1, k=2, smoother=0.1: LL=-0.7445
# Species bird1, k=3, smoother=0.001: LL=-0.7373
# Species bird1, k=3, smoother=0.01: LL=-0.7349
# Species bird1, k=3, smoother=0.1: LL=-0.7335
# Species bird1, k=4, smoother=0.001: LL=-0.7455
# Species bird1, k=4, smoother=0.01: LL=-0.7406
# Species bird1, k=4, smoother=0.1: LL=-0.7379
# Species bird1, k=5, smoother=0.001: LL=-0.7642
# Species bird1, k=5, smoother=0.01: LL=-0.7555
# Species bird1, k=5, smoother=0.1: LL=-0.7504
# Species bird1, k=0, smoother=0.001: LL=-1.7634
# Species bird1, k=0, smoother=0.01: LL=-1.7634
# Species bird1, k=0, smoother=0.1: LL=-1.7634
# Species bird1, k=1, smoother=0.001: LL=-0.7855
# Species bird1, k=1, smoother=0.01: LL=-0.7850
# Species bird1, k=1, smoother=0.1: LL=-0.7845
# Species bird1, k=2, smoother=0.001: LL=-0.7457
# Species bird1, k=2, smoother=0.01: LL=-0.7448
# Species bird1, k=2, smoother=0.1: LL=-0.7442
# Species bird1, k=3, smoother=0.001: LL=-0.7387
# Species bird1, k=3, smoother=0.01: LL=-0.7369
# Species bird1, k=3, smoother=0.1: LL=-0.7360
# Species bird1, k=4, smoother=0.001: LL=-0.7442
# Species bird1, k=4, smoother=0.01: LL=-0.7399
# Species bird1, k=4, smoother=0.1: LL=-0.7376
# Species bird1, k=5, smoother=0.001: LL=-0.7687
# Species bird1, k=5, smoother=0.01: LL=-0.7575
# Species bird1, k=5, smoother=0.1: LL=-0.7503
# Species bird1, k=0, smoother=0.001: LL=-1.7681
# Species bird1, k=0, smoother=0.01: LL=-1.7681
# Species bird1, k=0, smoother=0.1: LL=-1.7681
# Species bird1, k=1, smoother=0.001: LL=-0.7881
# Species bird1, k=1, smoother=0.01: LL=-0.7878
# Species bird1, k=1, smoother=0.1: LL=-0.7875
# Species bird1, k=2, smoother=0.001: LL=-0.7488
# Species bird1, k=2, smoother=0.01: LL=-0.7458
# Species bird1, k=2, smoother=0.1: LL=-0.7432
# Species bird1, k=3, smoother=0.001: LL=-0.7391
# Species bird1, k=3, smoother=0.01: LL=-0.7359
# Species bird1, k=3, smoother=0.1: LL=-0.7335
# Species bird1, k=4, smoother=0.001: LL=-0.7464
# Species bird1, k=4, smoother=0.01: LL=-0.7410
# Species bird1, k=4, smoother=0.1: LL=-0.7378
# Species bird1, k=5, smoother=0.001: LL=-0.7507
# Species bird1, k=5, smoother=0.01: LL=-0.7449
# Species bird1, k=5, smoother=0.1: LL=-0.7422
# Species bird1, k=0, smoother=0.001: LL=-1.7549
# Species bird1, k=0, smoother=0.01: LL=-1.7549
# Species bird1, k=0, smoother=0.1: LL=-1.7549
# Species bird1, k=1, smoother=0.001: LL=-0.7851
# Species bird1, k=1, smoother=0.01: LL=-0.7850
# Species bird1, k=1, smoother=0.1: LL=-0.7848
# Species bird1, k=2, smoother=0.001: LL=-0.7436
# Species bird1, k=2, smoother=0.01: LL=-0.7419
# Species bird1, k=2, smoother=0.1: LL=-0.7405
# Species bird1, k=3, smoother=0.001: LL=-0.7317
# Species bird1, k=3, smoother=0.01: LL=-0.7290
# Species bird1, k=3, smoother=0.1: LL=-0.7270
# Species bird1, k=4, smoother=0.001: LL=-0.7339
# Species bird1, k=4, smoother=0.01: LL=-0.7310
# Species bird1, k=4, smoother=0.1: LL=-0.7294
# Species bird1, k=5, smoother=0.001: LL=-0.7444
# Species bird1, k=5, smoother=0.01: LL=-0.7385
# Species bird1, k=5, smoother=0.1: LL=-0.7353
# Species bird1, k=0, smoother=0.001: LL=-1.7576
# Species bird1, k=0, smoother=0.01: LL=-1.7576
# Species bird1, k=0, smoother=0.1: LL=-1.7576
# Species bird1, k=1, smoother=0.001: LL=-0.7821
# Species bird1, k=1, smoother=0.01: LL=-0.7820
# Species bird1, k=1, smoother=0.1: LL=-0.7819
# Species bird1, k=2, smoother=0.001: LL=-0.7407
# Species bird1, k=2, smoother=0.01: LL=-0.7395
# Species bird1, k=2, smoother=0.1: LL=-0.7385
# Species bird1, k=3, smoother=0.001: LL=-0.7263
# Species bird1, k=3, smoother=0.01: LL=-0.7244
# Species bird1, k=3, smoother=0.1: LL=-0.7233
# Species bird1, k=4, smoother=0.001: LL=-0.7279
# Species bird1, k=4, smoother=0.01: LL=-0.7249
# Species bird1, k=4, smoother=0.1: LL=-0.7234
# Species bird1, k=5, smoother=0.001: LL=-0.7319
# Species bird1, k=5, smoother=0.01: LL=-0.7278
# Species bird1, k=5, smoother=0.1: LL=-0.7264
# Species bird2, k=0, smoother=0.001: LL=-1.8329
# Species bird2, k=0, smoother=0.01: LL=-1.8329
# Species bird2, k=0, smoother=0.1: LL=-1.8329
# Species bird2, k=1, smoother=0.001: LL=-0.7892
# Species bird2, k=1, smoother=0.01: LL=-0.7887
# Species bird2, k=1, smoother=0.1: LL=-0.7883
# Species bird2, k=2, smoother=0.001: LL=-0.7289
# Species bird2, k=2, smoother=0.01: LL=-0.7259
# Species bird2, k=2, smoother=0.1: LL=-0.7234
# Species bird2, k=3, smoother=0.001: LL=-0.7233
# Species bird2, k=3, smoother=0.01: LL=-0.7173
# Species bird2, k=3, smoother=0.1: LL=-0.7132
# Species bird2, k=4, smoother=0.001: LL=-0.7353
# Species bird2, k=4, smoother=0.01: LL=-0.7216
# Species bird2, k=4, smoother=0.1: LL=-0.7120
# Species bird2, k=5, smoother=0.001: LL=-0.7732
# Species bird2, k=5, smoother=0.01: LL=-0.7503
# Species bird2, k=5, smoother=0.1: LL=-0.7339
# Species bird2, k=0, smoother=0.001: LL=-1.8259
# Species bird2, k=0, smoother=0.01: LL=-1.8259
# Species bird2, k=0, smoother=0.1: LL=-1.8259
# Species bird2, k=1, smoother=0.001: LL=-0.7986
# Species bird2, k=1, smoother=0.01: LL=-0.7976
# Species bird2, k=1, smoother=0.1: LL=-0.7967
# Species bird2, k=2, smoother=0.001: LL=-0.7345
# Species bird2, k=2, smoother=0.01: LL=-0.7324
# Species bird2, k=2, smoother=0.1: LL=-0.7309
# Species bird2, k=3, smoother=0.001: LL=-0.7361
# Species bird2, k=3, smoother=0.01: LL=-0.7322
# Species bird2, k=3, smoother=0.1: LL=-0.7299
# Species bird2, k=4, smoother=0.001: LL=-0.7513
# Species bird2, k=4, smoother=0.01: LL=-0.7410
# Species bird2, k=4, smoother=0.1: LL=-0.7345
# Species bird2, k=5, smoother=0.001: LL=-0.7992
# Species bird2, k=5, smoother=0.01: LL=-0.7762
# Species bird2, k=5, smoother=0.1: LL=-0.7599
# Species bird2, k=0, smoother=0.001: LL=-1.8213
# Species bird2, k=0, smoother=0.01: LL=-1.8213
# Species bird2, k=0, smoother=0.1: LL=-1.8213
# Species bird2, k=1, smoother=0.001: LL=-0.8096
# Species bird2, k=1, smoother=0.01: LL=-0.8096
# Species bird2, k=1, smoother=0.1: LL=-0.8097
# Species bird2, k=2, smoother=0.001: LL=-0.7496
# Species bird2, k=2, smoother=0.01: LL=-0.7460
# Species bird2, k=2, smoother=0.1: LL=-0.7430
# Species bird2, k=3, smoother=0.001: LL=-0.7562
# Species bird2, k=3, smoother=0.01: LL=-0.7494
# Species bird2, k=3, smoother=0.1: LL=-0.7445
# Species bird2, k=4, smoother=0.001: LL=-0.7847
# Species bird2, k=4, smoother=0.01: LL=-0.7635
# Species bird2, k=4, smoother=0.1: LL=-0.7473
# Species bird2, k=5, smoother=0.001: LL=-0.8242
# Species bird2, k=5, smoother=0.01: LL=-0.7922
# Species bird2, k=5, smoother=0.1: LL=-0.7684
# Species bird2, k=0, smoother=0.001: LL=-1.8315
# Species bird2, k=0, smoother=0.01: LL=-1.8315
# Species bird2, k=0, smoother=0.1: LL=-1.8315
# Species bird2, k=1, smoother=0.001: LL=-0.7916
# Species bird2, k=1, smoother=0.01: LL=-0.7916
# Species bird2, k=1, smoother=0.1: LL=-0.7917
# Species bird2, k=2, smoother=0.001: LL=-0.7293
# Species bird2, k=2, smoother=0.01: LL=-0.7288
# Species bird2, k=2, smoother=0.1: LL=-0.7289
# Species bird2, k=3, smoother=0.001: LL=-0.7458
# Species bird2, k=3, smoother=0.01: LL=-0.7369
# Species bird2, k=3, smoother=0.1: LL=-0.7302
# Species bird2, k=4, smoother=0.001: LL=-0.7530
# Species bird2, k=4, smoother=0.01: LL=-0.7390
# Species bird2, k=4, smoother=0.1: LL=-0.7291
# Species bird2, k=5, smoother=0.001: LL=-0.8019
# Species bird2, k=5, smoother=0.01: LL=-0.7736
# Species bird2, k=5, smoother=0.1: LL=-0.7528
# Species bird2, k=0, smoother=0.001: LL=-1.8381
# Species bird2, k=0, smoother=0.01: LL=-1.8381
# Species bird2, k=0, smoother=0.1: LL=-1.8381
# Species bird2, k=1, smoother=0.001: LL=-0.8160
# Species bird2, k=1, smoother=0.01: LL=-0.8155
# Species bird2, k=1, smoother=0.1: LL=-0.8149
# Species bird2, k=2, smoother=0.001: LL=-0.7534
# Species bird2, k=2, smoother=0.01: LL=-0.7489
# Species bird2, k=2, smoother=0.1: LL=-0.7454
# Species bird2, k=3, smoother=0.001: LL=-0.7811
# Species bird2, k=3, smoother=0.01: LL=-0.7613
# Species bird2, k=3, smoother=0.1: LL=-0.7455
# Species bird2, k=4, smoother=0.001: LL=-0.7705
# Species bird2, k=4, smoother=0.01: LL=-0.7504
# Species bird2, k=4, smoother=0.1: LL=-0.7355
# Species bird2, k=5, smoother=0.001: LL=-0.7930
# Species bird2, k=5, smoother=0.01: LL=-0.7677
# Species bird2, k=5, smoother=0.1: LL=-0.7496
# Species bird2, k=0, smoother=0.001: LL=-1.8311
# Species bird2, k=0, smoother=0.01: LL=-1.8311
# Species bird2, k=0, smoother=0.1: LL=-1.8311
# Species bird2, k=1, smoother=0.001: LL=-0.7905
# Species bird2, k=1, smoother=0.01: LL=-0.7905
# Species bird2, k=1, smoother=0.1: LL=-0.7906
# Species bird2, k=2, smoother=0.001: LL=-0.7377
# Species bird2, k=2, smoother=0.01: LL=-0.7346
# Species bird2, k=2, smoother=0.1: LL=-0.7322
# Species bird2, k=3, smoother=0.001: LL=-0.7395
# Species bird2, k=3, smoother=0.01: LL=-0.7333
# Species bird2, k=3, smoother=0.1: LL=-0.7289
# Species bird2, k=4, smoother=0.001: LL=-0.7403
# Species bird2, k=4, smoother=0.01: LL=-0.7306
# Species bird2, k=4, smoother=0.1: LL=-0.7248
# Species bird2, k=5, smoother=0.001: LL=-0.8055
# Species bird2, k=5, smoother=0.01: LL=-0.7740
# Species bird2, k=5, smoother=0.1: LL=-0.7504
# Species bird2, k=0, smoother=0.001: LL=-1.8356
# Species bird2, k=0, smoother=0.01: LL=-1.8356
# Species bird2, k=0, smoother=0.1: LL=-1.8356
# Species bird2, k=1, smoother=0.001: LL=-0.7865
# Species bird2, k=1, smoother=0.01: LL=-0.7865
# Species bird2, k=1, smoother=0.1: LL=-0.7866
# Species bird2, k=2, smoother=0.001: LL=-0.7291
# Species bird2, k=2, smoother=0.01: LL=-0.7265
# Species bird2, k=2, smoother=0.1: LL=-0.7243
# Species bird2, k=3, smoother=0.001: LL=-0.7267
# Species bird2, k=3, smoother=0.01: LL=-0.7217
# Species bird2, k=3, smoother=0.1: LL=-0.7182
# Species bird2, k=4, smoother=0.001: LL=-0.7433
# Species bird2, k=4, smoother=0.01: LL=-0.7287
# Species bird2, k=4, smoother=0.1: LL=-0.7182
# Species bird2, k=5, smoother=0.001: LL=-0.7751
# Species bird2, k=5, smoother=0.01: LL=-0.7516
# Species bird2, k=5, smoother=0.1: LL=-0.7347
# Species bird2, k=0, smoother=0.001: LL=-1.8361
# Species bird2, k=0, smoother=0.01: LL=-1.8361
# Species bird2, k=0, smoother=0.1: LL=-1.8361
# Species bird2, k=1, smoother=0.001: LL=-0.7822
# Species bird2, k=1, smoother=0.01: LL=-0.7822
# Species bird2, k=1, smoother=0.1: LL=-0.7823
# Species bird2, k=2, smoother=0.001: LL=-0.7211
# Species bird2, k=2, smoother=0.01: LL=-0.7179
# Species bird2, k=2, smoother=0.1: LL=-0.7152
# Species bird2, k=3, smoother=0.001: LL=-0.7147
# Species bird2, k=3, smoother=0.01: LL=-0.7107
# Species bird2, k=3, smoother=0.1: LL=-0.7081
# Species bird2, k=4, smoother=0.001: LL=-0.7116
# Species bird2, k=4, smoother=0.01: LL=-0.7067
# Species bird2, k=4, smoother=0.1: LL=-0.7042
# Species bird2, k=5, smoother=0.001: LL=-0.7359
# Species bird2, k=5, smoother=0.01: LL=-0.7235
# ...
# Species bird4, k=4, smoother=0.01: LL=-0.5611
# Species bird4, k=4, smoother=0.1: LL=-0.5590
# Species bird4, k=5, smoother=0.001: LL=-0.5790
# Species bird4, k=5, smoother=0.01: LL=-0.5716
# Species bird4, k=5, smoother=0.1: LL=-0.5657
# Species bird4, k=0, smoother=0.001: LL=-1.2751
# Species bird4, k=0, smoother=0.01: LL=-1.2751
# Species bird4, k=0, smoother=0.1: LL=-1.2751
# Species bird4, k=1, smoother=0.001: LL=-0.5556
# Species bird4, k=1, smoother=0.01: LL=-0.5556
# Species bird4, k=1, smoother=0.1: LL=-0.5556
# Species bird4, k=2, smoother=0.001: LL=-0.5393
# Species bird4, k=2, smoother=0.01: LL=-0.5389
# Species bird4, k=2, smoother=0.1: LL=-0.5384
# Species bird4, k=3, smoother=0.001: LL=-0.5471
# Species bird4, k=3, smoother=0.01: LL=-0.5447
# Species bird4, k=3, smoother=0.1: LL=-0.5424
# Species bird4, k=4, smoother=0.001: LL=-0.5638
# Species bird4, k=4, smoother=0.01: LL=-0.5603
# Species bird4, k=4, smoother=0.1: LL=-0.5573
# Species bird4, k=5, smoother=0.001: LL=-0.5798
# Species bird4, k=5, smoother=0.01: LL=-0.5716
# Species bird4, k=5, smoother=0.1: LL=-0.5645
# Species bird4, k=0, smoother=0.001: LL=-1.2882
# Species bird4, k=0, smoother=0.01: LL=-1.2882
# Species bird4, k=0, smoother=0.1: LL=-1.2882
# Species bird4, k=1, smoother=0.001: LL=-0.5716
# Species bird4, k=1, smoother=0.01: LL=-0.5716
# Species bird4, k=1, smoother=0.1: LL=-0.5716
# Species bird4, k=2, smoother=0.001: LL=-0.5480
# Species bird4, k=2, smoother=0.01: LL=-0.5476
# Species bird4, k=2, smoother=0.1: LL=-0.5471
# Species bird4, k=3, smoother=0.001: LL=-0.5505
# Species bird4, k=3, smoother=0.01: LL=-0.5485
# Species bird4, k=3, smoother=0.1: LL=-0.5468
# Species bird4, k=4, smoother=0.001: LL=-0.5662
# Species bird4, k=4, smoother=0.01: LL=-0.5627
# Species bird4, k=4, smoother=0.1: LL=-0.5597
# Species bird4, k=5, smoother=0.001: LL=-0.5740
# Species bird4, k=5, smoother=0.01: LL=-0.5681
# Species bird4, k=5, smoother=0.1: LL=-0.5635
# Species bird4, k=0, smoother=0.001: LL=-1.2781
# Species bird4, k=0, smoother=0.01: LL=-1.2781
# Species bird4, k=0, smoother=0.1: LL=-1.2781
# Species bird4, k=1, smoother=0.001: LL=-0.5644
# Species bird4, k=1, smoother=0.01: LL=-0.5644
# Species bird4, k=1, smoother=0.1: LL=-0.5644
# Species bird4, k=2, smoother=0.001: LL=-0.5424
# Species bird4, k=2, smoother=0.01: LL=-0.5419
# Species bird4, k=2, smoother=0.1: LL=-0.5414
# Species bird4, k=3, smoother=0.001: LL=-0.5476
# Species bird4, k=3, smoother=0.01: LL=-0.5469
# Species bird4, k=3, smoother=0.1: LL=-0.5462
# Species bird4, k=4, smoother=0.001: LL=-0.5653
# Species bird4, k=4, smoother=0.01: LL=-0.5628
# Species bird4, k=4, smoother=0.1: LL=-0.5606
# Species bird4, k=5, smoother=0.001: LL=-0.5777
# Species bird4, k=5, smoother=0.01: LL=-0.5721
# Species bird4, k=5, smoother=0.1: LL=-0.5674
# Species bird4, k=0, smoother=0.001: LL=-1.2745
# Species bird4, k=0, smoother=0.01: LL=-1.2745
# Species bird4, k=0, smoother=0.1: LL=-1.2745
# Species bird4, k=1, smoother=0.001: LL=-0.5592
# Species bird4, k=1, smoother=0.01: LL=-0.5592
# Species bird4, k=1, smoother=0.1: LL=-0.5593
# Species bird4, k=2, smoother=0.001: LL=-0.5337
# Species bird4, k=2, smoother=0.01: LL=-0.5337
# Species bird4, k=2, smoother=0.1: LL=-0.5338
# Species bird4, k=3, smoother=0.001: LL=-0.5343
# Species bird4, k=3, smoother=0.01: LL=-0.5341
# Species bird4, k=3, smoother=0.1: LL=-0.5340
# Species bird4, k=4, smoother=0.001: LL=-0.5533
# Species bird4, k=4, smoother=0.01: LL=-0.5514
# Species bird4, k=4, smoother=0.1: LL=-0.5499
# Species bird4, k=5, smoother=0.001: LL=-0.5597
# Species bird4, k=5, smoother=0.01: LL=-0.5556
# Species bird4, k=5, smoother=0.1: LL=-0.5523
# Species bird4, k=0, smoother=0.001: LL=-1.2895
# Species bird4, k=0, smoother=0.01: LL=-1.2895
# Species bird4, k=0, smoother=0.1: LL=-1.2895
# Species bird4, k=1, smoother=0.001: LL=-0.5765
# Species bird4, k=1, smoother=0.01: LL=-0.5765
# Species bird4, k=1, smoother=0.1: LL=-0.5765
# Species bird4, k=2, smoother=0.001: LL=-0.5519
# Species bird4, k=2, smoother=0.01: LL=-0.5517
# Species bird4, k=2, smoother=0.1: LL=-0.5514
# Species bird4, k=3, smoother=0.001: LL=-0.5565
# Species bird4, k=3, smoother=0.01: LL=-0.5552
# Species bird4, k=3, smoother=0.1: LL=-0.5540
# Species bird4, k=4, smoother=0.001: LL=-0.5795
# Species bird4, k=4, smoother=0.01: LL=-0.5758
# Species bird4, k=4, smoother=0.1: LL=-0.5725
# Species bird4, k=5, smoother=0.001: LL=-0.5910
# Species bird4, k=5, smoother=0.01: LL=-0.5840
# Species bird4, k=5, smoother=0.1: LL=-0.5781
# Species bird4, k=0, smoother=0.001: LL=-1.2824
# Species bird4, k=0, smoother=0.01: LL=-1.2824
# Species bird4, k=0, smoother=0.1: LL=-1.2824
# Species bird4, k=1, smoother=0.001: LL=-0.5616
# Species bird4, k=1, smoother=0.01: LL=-0.5616
# Species bird4, k=1, smoother=0.1: LL=-0.5616
# Species bird4, k=2, smoother=0.001: LL=-0.5409
# Species bird4, k=2, smoother=0.01: LL=-0.5409
# Species bird4, k=2, smoother=0.1: LL=-0.5409
# Species bird4, k=3, smoother=0.001: LL=-0.5452
# Species bird4, k=3, smoother=0.01: LL=-0.5445
# Species bird4, k=3, smoother=0.1: LL=-0.5438
# Species bird4, k=4, smoother=0.001: LL=-0.5723
# Species bird4, k=4, smoother=0.01: LL=-0.5645
# Species bird4, k=4, smoother=0.1: LL=-0.5577
# Species bird4, k=5, smoother=0.001: LL=-0.5840
# Species bird4, k=5, smoother=0.01: LL=-0.5751
# Species bird4, k=5, smoother=0.1: LL=-0.5677
# Species bird4, k=0, smoother=0.001: LL=-1.2831
# Species bird4, k=0, smoother=0.01: LL=-1.2831
# Species bird4, k=0, smoother=0.1: LL=-1.2831
# Species bird4, k=1, smoother=0.001: LL=-0.5725
# Species bird4, k=1, smoother=0.01: LL=-0.5725
# Species bird4, k=1, smoother=0.1: LL=-0.5725
# Species bird4, k=2, smoother=0.001: LL=-0.5466
# Species bird4, k=2, smoother=0.01: LL=-0.5464
# Species bird4, k=2, smoother=0.1: LL=-0.5462
# Species bird4, k=3, smoother=0.001: LL=-0.5505
# Species bird4, k=3, smoother=0.01: LL=-0.5493
# Species bird4, k=3, smoother=0.1: LL=-0.5483
# Species bird4, k=4, smoother=0.001: LL=-0.5745
# Species bird4, k=4, smoother=0.01: LL=-0.5696
# Species bird4, k=4, smoother=0.1: LL=-0.5653
# Species bird4, k=5, smoother=0.001: LL=-0.5869
# Species bird4, k=5, smoother=0.01: LL=-0.5780
# Species bird4, k=5, smoother=0.1: LL=-0.5701
# Species bird4, k=0, smoother=0.001: LL=-1.2852
# Species bird4, k=0, smoother=0.01: LL=-1.2852
# Species bird4, k=0, smoother=0.1: LL=-1.2852
# Species bird4, k=1, smoother=0.001: LL=-0.5785
# Species bird4, k=1, smoother=0.01: LL=-0.5785
# Species bird4, k=1, smoother=0.1: LL=-0.5785
# Species bird4, k=2, smoother=0.001: LL=-0.5505
# Species bird4, k=2, smoother=0.01: LL=-0.5503
# Species bird4, k=2, smoother=0.1: LL=-0.5501
# Species bird4, k=3, smoother=0.001: LL=-0.5568
# Species bird4, k=3, smoother=0.01: LL=-0.5558
# Species bird4, k=3, smoother=0.1: LL=-0.5549
# Species bird4, k=4, smoother=0.001: LL=-0.5845
# Species bird4, k=4, smoother=0.01: LL=-0.5782
# Species bird4, k=4, smoother=0.1: LL=-0.5726
# Species bird4, k=5, smoother=0.001: LL=-0.5991
# Species bird4, k=5, smoother=0.01: LL=-0.5898
# Species bird4, k=5, smoother=0.1: LL=-0.5820
# Species bird4, k=0, smoother=0.001: LL=-1.2811
# Species bird4, k=0, smoother=0.01: LL=-1.2811
# Species bird4, k=0, smoother=0.1: LL=-1.2811
# Species bird4, k=1, smoother=0.001: LL=-0.5645
# Species bird4, k=1, smoother=0.01: LL=-0.5645
# Species bird4, k=1, smoother=0.1: LL=-0.5645
# Species bird4, k=2, smoother=0.001: LL=-0.5390
# Species bird4, k=2, smoother=0.01: LL=-0.5386
# Species bird4, k=2, smoother=0.1: LL=-0.5382
# Species bird4, k=3, smoother=0.001: LL=-0.5442
# Species bird4, k=3, smoother=0.01: LL=-0.5438
# Species bird4, k=3, smoother=0.1: LL=-0.5434
# Species bird4, k=4, smoother=0.001: LL=-0.5670
# Species bird4, k=4, smoother=0.01: LL=-0.5633
# Species bird4, k=4, smoother=0.1: LL=-0.5602
# Species bird4, k=5, smoother=0.001: LL=-0.5735
# Species bird4, k=5, smoother=0.01: LL=-0.5674
# Species bird4, k=5, smoother=0.1: LL=-0.5625
# Species bird4, k=0, smoother=0.001: LL=-1.2771
# Species bird4, k=0, smoother=0.01: LL=-1.2771
# Species bird4, k=0, smoother=0.1: LL=-1.2771
# Species bird4, k=1, smoother=0.001: LL=-0.5622
# Species bird4, k=1, smoother=0.01: LL=-0.5622
# Species bird4, k=1, smoother=0.1: LL=-0.5622
# Species bird4, k=2, smoother=0.001: LL=-0.5467
# Species bird4, k=2, smoother=0.01: LL=-0.5467
# Species bird4, k=2, smoother=0.1: LL=-0.5467
# Species bird4, k=3, smoother=0.001: LL=-0.5503
# Species bird4, k=3, smoother=0.01: LL=-0.5491
# Species bird4, k=3, smoother=0.1: LL=-0.5481
# Species bird4, k=4, smoother=0.001: LL=-0.5787
# Species bird4, k=4, smoother=0.01: LL=-0.5718
# Species bird4, k=4, smoother=0.1: LL=-0.5660
# Species bird4, k=5, smoother=0.001: LL=-0.5944
# Species bird4, k=5, smoother=0.01: LL=-0.5828
# Species bird4, k=5, smoother=0.1: LL=-0.5732
# Species bird4, k=0, smoother=0.001: LL=-1.2782
# Species bird4, k=0, smoother=0.01: LL=-1.2782
# Species bird4, k=0, smoother=0.1: LL=-1.2782
# Species bird4, k=1, smoother=0.001: LL=-0.5657
# Species bird4, k=1, smoother=0.01: LL=-0.5657
# Species bird4, k=1, smoother=0.1: LL=-0.5657
# Species bird4, k=2, smoother=0.001: LL=-0.5437
# Species bird4, k=2, smoother=0.01: LL=-0.5428
# Species bird4, k=2, smoother=0.1: LL=-0.5419
# Species bird4, k=3, smoother=0.001: LL=-0.5489
# Species bird4, k=3, smoother=0.01: LL=-0.5468
# Species bird4, k=3, smoother=0.1: LL=-0.5449
# Species bird4, k=4, smoother=0.001: LL=-0.5696
# Species bird4, k=4, smoother=0.01: LL=-0.5659
# Species bird4, k=4, smoother=0.1: LL=-0.5624
# Species bird4, k=5, smoother=0.001: LL=-0.5816
# Species bird4, k=5, smoother=0.01: LL=-0.5746
# Species bird4, k=5, smoother=0.1: LL=-0.5684
# Species bird4, k=0, smoother=0.001: LL=-1.2823
# Species bird4, k=0, smoother=0.01: LL=-1.2823
# Species bird4, k=0, smoother=0.1: LL=-1.2823
# Species bird4, k=1, smoother=0.001: LL=-0.5661
# Species bird4, k=1, smoother=0.01: LL=-0.5661
# Species bird4, k=1, smoother=0.1: LL=-0.5661
# Species bird4, k=2, smoother=0.001: LL=-0.5439
# Species bird4, k=2, smoother=0.01: LL=-0.5439
# Species bird4, k=2, smoother=0.1: LL=-0.5439
# Species bird4, k=3, smoother=0.001: LL=-0.5479
# Species bird4, k=3, smoother=0.01: LL=-0.5472
# Species bird4, k=3, smoother=0.1: LL=-0.5467
# Species bird4, k=4, smoother=0.001: LL=-0.5673
# Species bird4, k=4, smoother=0.01: LL=-0.5646
# Species bird4, k=4, smoother=0.1: LL=-0.5622
# Species bird4, k=5, smoother=0.001: LL=-0.5814
# Species bird4, k=5, smoother=0.01: LL=-0.5753
# Species bird4, k=5, smoother=0.1: LL=-0.5703
# Species bird4, k=0, smoother=0.001: LL=-1.2786
# Species bird4, k=0, smoother=0.01: LL=-1.2786
# Species bird4, k=0, smoother=0.1: LL=-1.2786
# Species bird4, k=1, smoother=0.001: LL=-0.5587
# Species bird4, k=1, smoother=0.01: LL=-0.5587
# Species bird4, k=1, smoother=0.1: LL=-0.5587
# Species bird4, k=2, smoother=0.001: LL=-0.5345
# Species bird4, k=2, smoother=0.01: LL=-0.5343
# Species bird4, k=2, smoother=0.1: LL=-0.5341
# Species bird4, k=3, smoother=0.001: LL=-0.5364
# Species bird4, k=3, smoother=0.01: LL=-0.5362
# Species bird4, k=3, smoother=0.1: LL=-0.5360
# Species bird4, k=4, smoother=0.001: LL=-0.5552
# Species bird4, k=4, smoother=0.01: LL=-0.5539
# Species bird4, k=4, smoother=0.1: LL=-0.5527
# Species bird4, k=5, smoother=0.001: LL=-0.5666
# Species bird4, k=5, smoother=0.01: LL=-0.5614
# Species bird4, k=5, smoother=0.1: LL=-0.5569
# Species bird4, k=0, smoother=0.001: LL=-1.2672
# Species bird4, k=0, smoother=0.01: LL=-1.2672
# Species bird4, k=0, smoother=0.1: LL=-1.2672
# Species bird4, k=1, smoother=0.001: LL=-0.5621
# Species bird4, k=1, smoother=0.01: LL=-0.5621
# Species bird4, k=1, smoother=0.1: LL=-0.5621
# Species bird4, k=2, smoother=0.001: LL=-0.5449
# Species bird4, k=2, smoother=0.01: LL=-0.5444
# Species bird4, k=2, smoother=0.1: LL=-0.5439
# Species bird4, k=3, smoother=0.001: LL=-0.5484
# Species bird4, k=3, smoother=0.01: LL=-0.5461
# Species bird4, k=3, smoother=0.1: LL=-0.5438
# Species bird4, k=4, smoother=0.001: LL=-0.5683
# Species bird4, k=4, smoother=0.01: LL=-0.5639
# Species bird4, k=4, smoother=0.1: LL=-0.5600
# Species bird4, k=5, smoother=0.001: LL=-0.5857
# Species bird4, k=5, smoother=0.01: LL=-0.5762
# Species bird4, k=5, smoother=0.1: LL=-0.5680
# Species bird4, k=0, smoother=0.001: LL=-1.2942
# Species bird4, k=0, smoother=0.01: LL=-1.2942
# Species bird4, k=0, smoother=0.1: LL=-1.2942
# Species bird4, k=1, smoother=0.001: LL=-0.5797
# Species bird4, k=1, smoother=0.01: LL=-0.5797
# Species bird4, k=1, smoother=0.1: LL=-0.5797
# Species bird4, k=2, smoother=0.001: LL=-0.5592
# Species bird4, k=2, smoother=0.01: LL=-0.5592
# Species bird4, k=2, smoother=0.1: LL=-0.5592
# Species bird4, k=3, smoother=0.001: LL=-0.5599
# Species bird4, k=3, smoother=0.01: LL=-0.5587
# Species bird4, k=3, smoother=0.1: LL=-0.5576
# Species bird4, k=4, smoother=0.001: LL=-0.5959
# Species bird4, k=4, smoother=0.01: LL=-0.5870
# Species bird4, k=4, smoother=0.1: LL=-0.5794
# Species bird4, k=5, smoother=0.001: LL=-0.6074
# Species bird4, k=5, smoother=0.01: LL=-0.5960
# Species bird4, k=5, smoother=0.1: LL=-0.5863
# Species bird4, k=0, smoother=0.001: LL=-1.2655
# Species bird4, k=0, smoother=0.01: LL=-1.2655
# Species bird4, k=0, smoother=0.1: LL=-1.2655
# Species bird4, k=1, smoother=0.001: LL=-0.5618
# Species bird4, k=1, smoother=0.01: LL=-0.5618
# Species bird4, k=1, smoother=0.1: LL=-0.5618
# Species bird4, k=2, smoother=0.001: LL=-0.5382
# Species bird4, k=2, smoother=0.01: LL=-0.5377
# Species bird4, k=2, smoother=0.1: LL=-0.5373
# Species bird4, k=3, smoother=0.001: LL=-0.5431
# Species bird4, k=3, smoother=0.01: LL=-0.5402
# Species bird4, k=3, smoother=0.1: LL=-0.5373
# Species bird4, k=4, smoother=0.001: LL=-0.5635
# Species bird4, k=4, smoother=0.01: LL=-0.5575
# Species bird4, k=4, smoother=0.1: LL=-0.5519
# Species bird4, k=5, smoother=0.001: LL=-0.5753
# Species bird4, k=5, smoother=0.01: LL=-0.5679
# Species bird4, k=5, smoother=0.1: LL=-0.5615
# Species bird4, k=0, smoother=0.001: LL=-1.2757
# Species bird4, k=0, smoother=0.01: LL=-1.2757
# Species bird4, k=0, smoother=0.1: LL=-1.2757
# Species bird4, k=1, smoother=0.001: LL=-0.5624
# Species bird4, k=1, smoother=0.01: LL=-0.5624
# Species bird4, k=1, smoother=0.1: LL=-0.5624
# Species bird4, k=2, smoother=0.001: LL=-0.5387
# Species bird4, k=2, smoother=0.01: LL=-0.5384
# Species bird4, k=2, smoother=0.1: LL=-0.5382
# Species bird4, k=3, smoother=0.001: LL=-0.5416
# Species bird4, k=3, smoother=0.01: LL=-0.5406
# Species bird4, k=3, smoother=0.1: LL=-0.5398
# Species bird4, k=4, smoother=0.001: LL=-0.5607
# Species bird4, k=4, smoother=0.01: LL=-0.5577
# Species bird4, k=4, smoother=0.1: LL=-0.5552
# Species bird4, k=5, smoother=0.001: LL=-0.5785
# Species bird4, k=5, smoother=0.01: LL=-0.5707
# Species bird4, k=5, smoother=0.1: LL=-0.5641
# Species bird4, k=0, smoother=0.001: LL=-1.2780
# Species bird4, k=0, smoother=0.01: LL=-1.2780
# Species bird4, k=0, smoother=0.1: LL=-1.2780
# Species bird4, k=1, smoother=0.001: LL=-0.5555
# Species bird4, k=1, smoother=0.01: LL=-0.5555
# Species bird4, k=1, smoother=0.1: LL=-0.5555
# Species bird4, k=2, smoother=0.001: LL=-0.5323
# Species bird4, k=2, smoother=0.01: LL=-0.5323
# Species bird4, k=2, smoother=0.1: LL=-0.5323
# Species bird4, k=3, smoother=0.001: LL=-0.5346
# Species bird4, k=3, smoother=0.01: LL=-0.5343
# Species bird4, k=3, smoother=0.1: LL=-0.5342
# Species bird4, k=4, smoother=0.001: LL=-0.5507
# Species bird4, k=4, smoother=0.01: LL=-0.5499
# Species bird4, k=4, smoother=0.1: LL=-0.5494
# Species bird4, k=5, smoother=0.001: LL=-0.5519
# Species bird4, k=5, smoother=0.01: LL=-0.5496
# Species bird4, k=5, smoother=0.1: LL=-0.5478
# Species bird4, k=0, smoother=0.001: LL=-1.2758
# Species bird4, k=0, smoother=0.01: LL=-1.2758
# Species bird4, k=0, smoother=0.1: LL=-1.2758
# Species bird4, k=1, smoother=0.001: LL=-0.5599
# Species bird4, k=1, smoother=0.01: LL=-0.5599
# Species bird4, k=1, smoother=0.1: LL=-0.5599
# Species bird4, k=2, smoother=0.001: LL=-0.5363
# Species bird4, k=2, smoother=0.01: LL=-0.5361
# Species bird4, k=2, smoother=0.1: LL=-0.5359
# Species bird4, k=3, smoother=0.001: LL=-0.5392
# Species bird4, k=3, smoother=0.01: LL=-0.5389
# Species bird4, k=3, smoother=0.1: LL=-0.5388
# Species bird4, k=4, smoother=0.001: LL=-0.5581
# Species bird4, k=4, smoother=0.01: LL=-0.5551
# Species bird4, k=4, smoother=0.1: LL=-0.5524
# Species bird4, k=5, smoother=0.001: LL=-0.5686
# Species bird4, k=5, smoother=0.01: LL=-0.5623
# Species bird4, k=5, smoother=0.1: LL=-0.5569
