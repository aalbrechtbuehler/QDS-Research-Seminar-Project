# %%
# GLOBAL #

import random
import pandas as pd
from collections import defaultdict, Counter
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
from sklearn.model_selection import train_test_split

random.seed(123)
np.random.seed(123)

# %%
# HELPER FUNCTIONS #

# TODO: double-check that readSequences joining parts is correct

#create strings from the .csv file
def readSequences(species_df, by_length=True):

        sequences = []

        grouped = species_df.groupby(
            ["trial_id", "sequence_id", "fish_id"]
        )

        for (_, _, fish_id), group in grouped:

            group = group.sort_values("order_id")
            parts = []

            for _, row in group.iterrows():

                if by_length:
                    parts.append(str(row["state"]) * int(row["length"]))
                else:
                    parts.append(str(row["state"]))

            sequences.append("".join(parts) + "\n")

        return sequences

# collapse sequence by self-transitions (e.g. [aaaabbbbcccdddccc] = [abcdc]) for collapsed context model
def collapseLength(seq):

    collapsed = []

    for s in seq:
        if not collapsed or collapsed[-1] != s:
            collapsed.append(s)

    return collapsed

# check if tuple has consecutive repeated states (we want to ignore these combinations in collapsed context model transition matrix)
def hasConsecutiveRepeats(states):

    for i in range(len(states) - 1):
        if states[i] == states[i + 1]:
            return True
        
    return False

# find indices of first state in each state run within sequence (e.g., [aaaabbbbcccdddccccc] = [0, 4, 8, 11, 14])
def uniqueIdxs(seq):

    lasts = []
    runChar = seq[0]

    for i, s in enumerate(seq[1:], start=1):
        if s != runChar:
            lasts.append(i - 1)
            runChar = s

    lasts.append(len(seq) - 1)
    return lasts

# expand  numeric vector into repetitions corresponding to each number value (e.g., [0, 4, 8, 11, 14] = [0, 0, 0, 0, 4, 4, 4, 4, 8, 8, 8, 11, 11, 11, 14, 14, 14]) 
# for matching strings to indices in collapsed context model 
def expandVec(vec):

    if not vec:
        return []
    
    result = []

    vecIDX = 0

    for pos in range(vec[-1] + 1):
        while vecIDX < len(vec) - 1 and pos > vec[vecIDX]:
            vecIDX += 1
        result.append(vec[vecIDX])

    return result

#calculate weighted log likelihood of test transitions (unnormalized) under train model (normalized)
def averageLL(trainProbs, testProbs):

    ll = 0.0 # start at zero

    weight = 0.0

    for s, nexts in testProbs.items(): #for each item in the test transition 
        trainContext = trainProbs.get(s) #find matching train model probability

        if trainContext is None:
            continue  
                             # if context unseen in train, skip
        for s2, p_test in nexts.items():
            p_train = trainContext.get(s2)

            if p_train is None or p_train <= 0:
                continue  # if transition unseen in train, skip
                             
            ll += p_test * np.log(p_train)
            weight += p_test

    if weight == 0:
        return np.nan
    
    return ll / weight

#### main analysis functions ####

""" general pipeline:

normalize the training set because we are essentially building a smoothed model that we can use to evaluate test set fit
keep test set as count data because we are comparing how well it fits to our smoothed model

 """

##### Lagged Context Markov Sampling--bad performance in synthetic eval, not used #####

# def laggedTransNorm(states, lines, k, smoother, lag):

#     transitions = defaultdict(Counter)
    
#     #for k=0 version, transition matrix turns into simple marginal state distributions
#     if k == 0:
#         for state in states:
#             transitions[()][state] = smoother #add laplace smoother to each curr state

#         for seq in lines:
#             for curr in seq:
#                 transitions[()][curr] += 1 #add one count in corresponding transition cell for each instance of each state

#         total = sum(transitions[()].values())

#         return {(): {s: c / total for s, c in transitions[()].items()}} #normalize

#     for prev in product(states, repeat=k): #add laplace smoother to every combination of prev & curr states

#         for curr in states:
#             transitions[prev][curr] = smoother

#     for seq in lines:
#         seqLength = len(seq)

#         for t in range(k * lag, seqLength):
#             prev = tuple(seq[t - lag * i - 1] for i in reversed(range(k))) # important line: looks back at k previous states each spaced one lag apart, starting from t-1
#             curr = seq[t] # curr state is at time t
#             transitions[prev][curr] += 1 #add 1 count to this prev & curr combination

#     transNorm = {}

#     for cond, counter in transitions.items():
#         total = sum(counter.values())
#         transNorm[cond] = {s: c / total for s, c in counter.items()} #normalize counts by total number of transitions

#     return transNorm

# def laggedTransCount(lines, k, lag):

#     transitions = defaultdict(Counter)

#     # if k is zero, just count instances of each state
#     if k == 0:
#         for seq in lines:
#             for curr in seq:
#                 transitions[()][curr] += 1
#         return transitions
    

#     for seq in lines:
#         seqLength = len(seq)
#         for t in range(k * lag, seqLength):
#             prev = tuple(seq[t - lag * i - 1] for i in reversed(range(k))) # important line: looks back at k previous states each spaced one lag apart, starting from t-1
#             curr = seq[t] # curr state is at time t
#             transitions[prev][curr] += 1  #add 1 count to this prev & curr combination

#     return transitions

##### Collapsed Context Markov Sampling #####

def collapsedTransNorm(states, lines, k, smoother):
    
    transitions = defaultdict(Counter)

    #for k=0 version, transition matrix turns into simple marginal state distributions
    if k == 0:
        for state in states:
            transitions[()][state] = smoother #add laplace smoother to each curr state

        for seq in lines:
            for curr in seq:
                transitions[()][curr] += 1 #add one count in corresponding transition cell for each instance of each state

        total = sum(transitions[()].values())

        return {(): {s: c / total for s, c in transitions[()].items()}} #normalize

    for prev in product(states, repeat=k):

        if hasConsecutiveRepeats(prev): #if prev tuple has consecutive repeats, skip (because this cannot be observed when self-transitions are collapsed)
            continue

        for curr in states:
            transitions[prev][curr] = smoother #add laplace smoother to every valid combination of prev & curr states

    for seq in lines:

        idxs = uniqueIdxs(seq) #find indices of unique states in sequence
        idxsExpanded = expandVec(idxs) #expand indices for mapping

        for t in range(1, len(seq)):

            idxsCollapsed = idxs.index(idxsExpanded[t - 1]) #find corresponding index of each token

            if idxsCollapsed < k - 1:
                continue

            prevIdxsUnique = idxs[idxsCollapsed- (k - 1):idxsCollapsed+ 1]
            prev = tuple(seq[i] for i in prevIdxsUnique)
            curr = seq[t]
            transitions[prev][curr] += 1

    transNorm = {}

    for cond, counter in transitions.items():
        total = sum(counter.values())
        transNorm[cond] = {s: c / total for s, c in counter.items()} #normalize 

    return transNorm

def collapsedTransCount(lines, k):

    transitions = defaultdict(Counter)

    # if k is zero, just count instances of each state
    if k == 0:
        for seq in lines:
            for curr in seq:
                transitions[()][curr] += 1

        return transitions
    
    for seq in lines:
        idxs = uniqueIdxs(seq)
        idxsExpanded = expandVec(idxs)

        for t in range(1, len(seq)):
            idxsCollapsed= idxs.index(idxsExpanded[t - 1])

            if idxsCollapsed< k - 1:
                continue

            prevIdxsUnique = idxs[idxsCollapsed- (k - 1):idxsCollapsed+ 1]
            prev = tuple(seq[i] for i in prevIdxsUnique)
            curr = seq[t]
            transitions[prev][curr] += 1

    return transitions

##### comparative analysis #####

def fitModel(species, i, trainLines, testLines, kMax, smootherSet):
 
    results = []

    #find unique states in corpus
    states = sorted({char for line in trainLines for char in line})

    for k in range(0, kMax + 1):

        for smoother in smootherSet:

            train_trans = collapsedTransNorm(states = states, lines=trainLines, k=k, smoother=smoother)

            test_trans  = collapsedTransCount(lines=testLines, k=k)

            ll = averageLL(train_trans, test_trans)

            results.append({
                'species': species, 
                'k': k,
                'sim': i,
                'smoother': smoother,
                'log_likelihood': ll,
                'num_train_states': len(train_trans),
                'num_test_states':  len(test_trans),
            })
            print(f"Species {species}, k={k}, "
                    f"smoother={smoother}: LL={ll:.4f}")

    return pd.DataFrame(results)

# %%
# DO IT! #

dat = pd.read_csv("fish-data/raw/PrettyDat.csv")

# params to test
nIter = 50
kmax=5
smoothers=[0.001, 0.01, 0.1]

# run iterations
results = []

for species, species_df in dat.groupby("species"):

    sequences = readSequences(species_df)

    for i in range(1, nIter+1):

        train_lines, test_lines = train_test_split(
            sequences,
            test_size=0.2)
        
        iModel = fitModel(species = species, i = i, trainLines=train_lines, testLines=test_lines, kMax = kmax, smootherSet = smoothers)

        results.append(iModel)


results_df = pd.concat(results, ignore_index=True)
results_df.to_csv("fishResultsCollapsed.csv", index=False)
# Out:
# Species bre, k=0, smoother=0.001: LL=-2.2605
# Species bre, k=0, smoother=0.01: LL=-2.2605
# Species bre, k=0, smoother=0.1: LL=-2.2605
# Species bre, k=1, smoother=0.001: LL=-0.0984
# Species bre, k=1, smoother=0.01: LL=-0.0984
# Species bre, k=1, smoother=0.1: LL=-0.0984
# Species bre, k=2, smoother=0.001: LL=-0.0948
# Species bre, k=2, smoother=0.01: LL=-0.0942
# Species bre, k=2, smoother=0.1: LL=-0.0942
# Species bre, k=3, smoother=0.001: LL=-0.1148
# Species bre, k=3, smoother=0.01: LL=-0.1117
# Species bre, k=3, smoother=0.1: LL=-0.1123
# Species bre, k=4, smoother=0.001: LL=-0.3415
# Species bre, k=4, smoother=0.01: LL=-0.3366
# Species bre, k=4, smoother=0.1: LL=-0.3395
# Species bre, k=5, smoother=0.001: LL=-0.8294
# Species bre, k=5, smoother=0.01: LL=-0.8238
# Species bre, k=5, smoother=0.1: LL=-0.8361
# Species bre, k=0, smoother=0.001: LL=-2.2856
# Species bre, k=0, smoother=0.01: LL=-2.2856
# Species bre, k=0, smoother=0.1: LL=-2.2856
# Species bre, k=1, smoother=0.001: LL=-0.0742
# Species bre, k=1, smoother=0.01: LL=-0.0742
# Species bre, k=1, smoother=0.1: LL=-0.0742
# Species bre, k=2, smoother=0.001: LL=-0.0713
# Species bre, k=2, smoother=0.01: LL=-0.0709
# Species bre, k=2, smoother=0.1: LL=-0.0710
# Species bre, k=3, smoother=0.001: LL=-0.0891
# Species bre, k=3, smoother=0.01: LL=-0.0872
# Species bre, k=3, smoother=0.1: LL=-0.0874
# Species bre, k=4, smoother=0.001: LL=-0.3768
# Species bre, k=4, smoother=0.01: LL=-0.3715
# Species bre, k=4, smoother=0.1: LL=-0.3740
# Species bre, k=5, smoother=0.001: LL=-0.9188
# Species bre, k=5, smoother=0.01: LL=-0.9128
# Species bre, k=5, smoother=0.1: LL=-0.9137
# Species bre, k=0, smoother=0.001: LL=-2.2148
# Species bre, k=0, smoother=0.01: LL=-2.2148
# Species bre, k=0, smoother=0.1: LL=-2.2148
# Species bre, k=1, smoother=0.001: LL=-0.0614
# Species bre, k=1, smoother=0.01: LL=-0.0613
# Species bre, k=1, smoother=0.1: LL=-0.0613
# Species bre, k=2, smoother=0.001: LL=-0.0705
# Species bre, k=2, smoother=0.01: LL=-0.0703
# Species bre, k=2, smoother=0.1: LL=-0.0703
# Species bre, k=3, smoother=0.001: LL=-0.1002
# Species bre, k=3, smoother=0.01: LL=-0.0988
# Species bre, k=3, smoother=0.1: LL=-0.1004
# Species bre, k=4, smoother=0.001: LL=-0.2341
# Species bre, k=4, smoother=0.01: LL=-0.2313
# Species bre, k=4, smoother=0.1: LL=-0.2348
# Species bre, k=5, smoother=0.001: LL=-0.6344
# Species bre, k=5, smoother=0.01: LL=-0.6315
# Species bre, k=5, smoother=0.1: LL=-0.6426
# Species bre, k=0, smoother=0.001: LL=-2.3093
# Species bre, k=0, smoother=0.01: LL=-2.3093
# Species bre, k=0, smoother=0.1: LL=-2.3093
# Species bre, k=1, smoother=0.001: LL=-0.0813
# Species bre, k=1, smoother=0.01: LL=-0.0813
# Species bre, k=1, smoother=0.1: LL=-0.0813
# Species bre, k=2, smoother=0.001: LL=-0.0770
# Species bre, k=2, smoother=0.01: LL=-0.0769
# Species bre, k=2, smoother=0.1: LL=-0.0771
# Species bre, k=3, smoother=0.001: LL=-0.0950
# Species bre, k=3, smoother=0.01: LL=-0.0927
# Species bre, k=3, smoother=0.1: LL=-0.0929
# Species bre, k=4, smoother=0.001: LL=-0.2523
# Species bre, k=4, smoother=0.01: LL=-0.2426
# Species bre, k=4, smoother=0.1: LL=-0.2398
# Species bre, k=5, smoother=0.001: LL=-0.8540
# Species bre, k=5, smoother=0.01: LL=-0.8244
# Species bre, k=5, smoother=0.1: LL=-0.8119
# Species bre, k=0, smoother=0.001: LL=-2.1010
# Species bre, k=0, smoother=0.01: LL=-2.1010
# Species bre, k=0, smoother=0.1: LL=-2.1010
# Species bre, k=1, smoother=0.001: LL=-0.1033
# Species bre, k=1, smoother=0.01: LL=-0.1031
# Species bre, k=1, smoother=0.1: LL=-0.1030
# Species bre, k=2, smoother=0.001: LL=-0.1016
# Species bre, k=2, smoother=0.01: LL=-0.1010
# Species bre, k=2, smoother=0.1: LL=-0.1008
# Species bre, k=3, smoother=0.001: LL=-0.1200
# Species bre, k=3, smoother=0.01: LL=-0.1154
# Species bre, k=3, smoother=0.1: LL=-0.1129
# Species bre, k=4, smoother=0.001: LL=-0.3131
# Species bre, k=4, smoother=0.01: LL=-0.3077
# Species bre, k=4, smoother=0.1: LL=-0.3062
# Species bre, k=5, smoother=0.001: LL=-0.8138
# Species bre, k=5, smoother=0.01: LL=-0.8074
# Species bre, k=5, smoother=0.1: LL=-0.8064
# Species bre, k=0, smoother=0.001: LL=-2.2224
# Species bre, k=0, smoother=0.01: LL=-2.2224
# Species bre, k=0, smoother=0.1: LL=-2.2224
# Species bre, k=1, smoother=0.001: LL=-0.0688
# Species bre, k=1, smoother=0.01: LL=-0.0689
# Species bre, k=1, smoother=0.1: LL=-0.0689
# Species bre, k=2, smoother=0.001: LL=-0.0655
# Species bre, k=2, smoother=0.01: LL=-0.0654
# Species bre, k=2, smoother=0.1: LL=-0.0657
# Species bre, k=3, smoother=0.001: LL=-0.0691
# Species bre, k=3, smoother=0.01: LL=-0.0675
# Species bre, k=3, smoother=0.1: LL=-0.0677
# Species bre, k=4, smoother=0.001: LL=-0.2510
# Species bre, k=4, smoother=0.01: LL=-0.2480
# Species bre, k=4, smoother=0.1: LL=-0.2507
# Species bre, k=5, smoother=0.001: LL=-0.6429
# Species bre, k=5, smoother=0.01: LL=-0.6400
# Species bre, k=5, smoother=0.1: LL=-0.6471
# Species bre, k=0, smoother=0.001: LL=-2.3005
# Species bre, k=0, smoother=0.01: LL=-2.3005
# Species bre, k=0, smoother=0.1: LL=-2.3005
# Species bre, k=1, smoother=0.001: LL=-0.0798
# Species bre, k=1, smoother=0.01: LL=-0.0796
# Species bre, k=1, smoother=0.1: LL=-0.0794
# Species bre, k=2, smoother=0.001: LL=-0.0955
# Species bre, k=2, smoother=0.01: LL=-0.0949
# Species bre, k=2, smoother=0.1: LL=-0.0946
# Species bre, k=3, smoother=0.001: LL=-0.1498
# Species bre, k=3, smoother=0.01: LL=-0.1477
# Species bre, k=3, smoother=0.1: LL=-0.1471
# Species bre, k=4, smoother=0.001: LL=-0.2711
# Species bre, k=4, smoother=0.01: LL=-0.2664
# Species bre, k=4, smoother=0.1: LL=-0.2668
# Species bre, k=5, smoother=0.001: LL=-0.8440
# Species bre, k=5, smoother=0.01: LL=-0.8389
# Species bre, k=5, smoother=0.1: LL=-0.8506
# Species bre, k=0, smoother=0.001: LL=-2.2796
# Species bre, k=0, smoother=0.01: LL=-2.2796
# Species bre, k=0, smoother=0.1: LL=-2.2796
# Species bre, k=1, smoother=0.001: LL=-0.0816
# Species bre, k=1, smoother=0.01: LL=-0.0816
# Species bre, k=1, smoother=0.1: LL=-0.0816
# Species bre, k=2, smoother=0.001: LL=-0.0883
# Species bre, k=2, smoother=0.01: LL=-0.0877
# Species bre, k=2, smoother=0.1: LL=-0.0874
# Species bre, k=3, smoother=0.001: LL=-0.1225
# Species bre, k=3, smoother=0.01: LL=-0.1202
# Species bre, k=3, smoother=0.1: LL=-0.1196
# Species bre, k=4, smoother=0.001: LL=-0.3399
# Species bre, k=4, smoother=0.01: LL=-0.3347
# Species bre, k=4, smoother=0.1: LL=-0.3347
# Species bre, k=5, smoother=0.001: LL=-0.8560
# Species bre, k=5, smoother=0.01: LL=-0.8503
# Species bre, k=5, smoother=0.1: LL=-0.8534
# Species bre, k=0, smoother=0.001: LL=-2.2217
# Species bre, k=0, smoother=0.01: LL=-2.2217
# Species bre, k=0, smoother=0.1: LL=-2.2217
# Species bre, k=1, smoother=0.001: LL=-0.0825
# Species bre, k=1, smoother=0.01: LL=-0.0825
# Species bre, k=1, smoother=0.1: LL=-0.0826
# Species bre, k=2, smoother=0.001: LL=-0.0805
# Species bre, k=2, smoother=0.01: LL=-0.0797
# Species bre, k=2, smoother=0.1: LL=-0.0795
# Species bre, k=3, smoother=0.001: LL=-0.0974
# Species bre, k=3, smoother=0.01: LL=-0.0926
# Species bre, k=3, smoother=0.1: LL=-0.0913
# Species bre, k=4, smoother=0.001: LL=-0.2238
# Species bre, k=4, smoother=0.01: LL=-0.2178
# Species bre, k=4, smoother=0.1: LL=-0.2237
# Species bre, k=5, smoother=0.001: LL=-0.8629
# Species bre, k=5, smoother=0.01: LL=-0.8566
# Species bre, k=5, smoother=0.1: LL=-0.8620
# Species bre, k=0, smoother=0.001: LL=-2.2034
# Species bre, k=0, smoother=0.01: LL=-2.2034
# Species bre, k=0, smoother=0.1: LL=-2.2034
# Species bre, k=1, smoother=0.001: LL=-0.0811
# Species bre, k=1, smoother=0.01: LL=-0.0811
# Species bre, k=1, smoother=0.1: LL=-0.0812
# Species bre, k=2, smoother=0.001: LL=-0.0770
# Species bre, k=2, smoother=0.01: LL=-0.0768
# Species bre, k=2, smoother=0.1: LL=-0.0769
# Species bre, k=3, smoother=0.001: LL=-0.0906
# Species bre, k=3, smoother=0.01: LL=-0.0897
# Species bre, k=3, smoother=0.1: LL=-0.0901
# Species bre, k=4, smoother=0.001: LL=-0.1672
# Species bre, k=4, smoother=0.01: LL=-0.1624
# Species bre, k=4, smoother=0.1: LL=-0.1648
# Species bre, k=5, smoother=0.001: LL=-0.5468
# Species bre, k=5, smoother=0.01: LL=-0.5396
# Species bre, k=5, smoother=0.1: LL=-0.5481
# Species bre, k=0, smoother=0.001: LL=-2.2939
# Species bre, k=0, smoother=0.01: LL=-2.2939
# Species bre, k=0, smoother=0.1: LL=-2.2939
# Species bre, k=1, smoother=0.001: LL=-0.0649
# Species bre, k=1, smoother=0.01: LL=-0.0649
# Species bre, k=1, smoother=0.1: LL=-0.0650
# Species bre, k=2, smoother=0.001: LL=-0.0641
# Species bre, k=2, smoother=0.01: LL=-0.0640
# Species bre, k=2, smoother=0.1: LL=-0.0643
# Species bre, k=3, smoother=0.001: LL=-0.0726
# Species bre, k=3, smoother=0.01: LL=-0.0709
# Species bre, k=3, smoother=0.1: LL=-0.0716
# Species bre, k=4, smoother=0.001: LL=-0.2270
# Species bre, k=4, smoother=0.01: LL=-0.2186
# Species bre, k=4, smoother=0.1: LL=-0.2174
# Species bre, k=5, smoother=0.001: LL=-0.6972
# Species bre, k=5, smoother=0.01: LL=-0.6933
# Species bre, k=5, smoother=0.1: LL=-0.6996
# Species bre, k=0, smoother=0.001: LL=-2.2320
# Species bre, k=0, smoother=0.01: LL=-2.2320
# Species bre, k=0, smoother=0.1: LL=-2.2320
# Species bre, k=1, smoother=0.001: LL=-0.0809
# Species bre, k=1, smoother=0.01: LL=-0.0809
# Species bre, k=1, smoother=0.1: LL=-0.0809
# Species bre, k=2, smoother=0.001: LL=-0.0766
# Species bre, k=2, smoother=0.01: LL=-0.0762
# Species bre, k=2, smoother=0.1: LL=-0.0761
# Species bre, k=3, smoother=0.001: LL=-0.0849
# Species bre, k=3, smoother=0.01: LL=-0.0820
# Species bre, k=3, smoother=0.1: LL=-0.0817
# Species bre, k=4, smoother=0.001: LL=-0.2337
# Species bre, k=4, smoother=0.01: LL=-0.2290
# Species bre, k=4, smoother=0.1: LL=-0.2299
# Species bre, k=5, smoother=0.001: LL=-0.9499
# Species bre, k=5, smoother=0.01: LL=-0.9013
# Species bre, k=5, smoother=0.1: LL=-0.8774
# Species bre, k=0, smoother=0.001: LL=-2.3724
# Species bre, k=0, smoother=0.01: LL=-2.3724
# Species bre, k=0, smoother=0.1: LL=-2.3724
# Species bre, k=1, smoother=0.001: LL=-0.0770
# Species bre, k=1, smoother=0.01: LL=-0.0770
# Species bre, k=1, smoother=0.1: LL=-0.0771
# Species bre, k=2, smoother=0.001: LL=-0.0731
# Species bre, k=2, smoother=0.01: LL=-0.0729
# Species bre, k=2, smoother=0.1: LL=-0.0729
# Species bre, k=3, smoother=0.001: LL=-0.0916
# Species bre, k=3, smoother=0.01: LL=-0.0894
# Species bre, k=3, smoother=0.1: LL=-0.0912
# Species bre, k=4, smoother=0.001: LL=-0.3009
# Species bre, k=4, smoother=0.01: LL=-0.2968
# Species bre, k=4, smoother=0.1: LL=-0.3009
# Species bre, k=5, smoother=0.001: LL=-0.8851
# Species bre, k=5, smoother=0.01: LL=-0.8801
# Species bre, k=5, smoother=0.1: LL=-0.8882
# Species bre, k=0, smoother=0.001: LL=-2.1480
# Species bre, k=0, smoother=0.01: LL=-2.1480
# Species bre, k=0, smoother=0.1: LL=-2.1480
# Species bre, k=1, smoother=0.001: LL=-0.1014
# Species bre, k=1, smoother=0.01: LL=-0.1014
# Species bre, k=1, smoother=0.1: LL=-0.1015
# Species bre, k=2, smoother=0.001: LL=-0.0954
# Species bre, k=2, smoother=0.01: LL=-0.0952
# Species bre, k=2, smoother=0.1: LL=-0.0954
# Species bre, k=3, smoother=0.001: LL=-0.1078
# Species bre, k=3, smoother=0.01: LL=-0.1063
# Species bre, k=3, smoother=0.1: LL=-0.1077
# Species bre, k=4, smoother=0.001: LL=-0.2429
# Species bre, k=4, smoother=0.01: LL=-0.2309
# Species bre, k=4, smoother=0.1: LL=-0.2270
# Species bre, k=5, smoother=0.001: LL=-0.7233
# Species bre, k=5, smoother=0.01: LL=-0.7179
# Species bre, k=5, smoother=0.1: LL=-0.7242
# Species bre, k=0, smoother=0.001: LL=-2.2918
# Species bre, k=0, smoother=0.01: LL=-2.2918
# Species bre, k=0, smoother=0.1: LL=-2.2918
# Species bre, k=1, smoother=0.001: LL=-0.0729
# Species bre, k=1, smoother=0.01: LL=-0.0729
# Species bre, k=1, smoother=0.1: LL=-0.0730
# Species bre, k=2, smoother=0.001: LL=-0.0699
# Species bre, k=2, smoother=0.01: LL=-0.0699
# Species bre, k=2, smoother=0.1: LL=-0.0702
# Species bre, k=3, smoother=0.001: LL=-0.0741
# Species bre, k=3, smoother=0.01: LL=-0.0721
# Species bre, k=3, smoother=0.1: LL=-0.0718
# Species bre, k=4, smoother=0.001: LL=-0.2669
# Species bre, k=4, smoother=0.01: LL=-0.2618
# Species bre, k=4, smoother=0.1: LL=-0.2619
# Species bre, k=5, smoother=0.001: LL=-0.8090
# Species bre, k=5, smoother=0.01: LL=-0.8035
# Species bre, k=5, smoother=0.1: LL=-0.8066
# Species bre, k=0, smoother=0.001: LL=-2.1882
# Species bre, k=0, smoother=0.01: LL=-2.1882
# Species bre, k=0, smoother=0.1: LL=-2.1882
# Species bre, k=1, smoother=0.001: LL=-0.0855
# Species bre, k=1, smoother=0.01: LL=-0.0855
# Species bre, k=1, smoother=0.1: LL=-0.0856
# Species bre, k=2, smoother=0.001: LL=-0.0814
# Species bre, k=2, smoother=0.01: LL=-0.0812
# Species bre, k=2, smoother=0.1: LL=-0.0812
# Species bre, k=3, smoother=0.001: LL=-0.0944
# Species bre, k=3, smoother=0.01: LL=-0.0928
# Species bre, k=3, smoother=0.1: LL=-0.0927
# Species bre, k=4, smoother=0.001: LL=-0.2436
# Species bre, k=4, smoother=0.01: LL=-0.2405
# Species bre, k=4, smoother=0.1: LL=-0.2420
# Species bre, k=5, smoother=0.001: LL=-0.5560
# Species bre, k=5, smoother=0.01: LL=-0.5524
# Species bre, k=5, smoother=0.1: LL=-0.5593
# Species bre, k=0, smoother=0.001: LL=-2.3001
# Species bre, k=0, smoother=0.01: LL=-2.3001
# Species bre, k=0, smoother=0.1: LL=-2.3001
# Species bre, k=1, smoother=0.001: LL=-0.0811
# Species bre, k=1, smoother=0.01: LL=-0.0811
# Species bre, k=1, smoother=0.1: LL=-0.0812
# Species bre, k=2, smoother=0.001: LL=-0.0766
# Species bre, k=2, smoother=0.01: LL=-0.0766
# Species bre, k=2, smoother=0.1: LL=-0.0771
# Species bre, k=3, smoother=0.001: LL=-0.0817
# Species bre, k=3, smoother=0.01: LL=-0.0807
# Species bre, k=3, smoother=0.1: LL=-0.0815
# Species bre, k=4, smoother=0.001: LL=-0.1707
# Species bre, k=4, smoother=0.01: LL=-0.1655
# Species bre, k=4, smoother=0.1: LL=-0.1662
# Species bre, k=5, smoother=0.001: LL=-0.4914
# Species bre, k=5, smoother=0.01: LL=-0.4837
# Species bre, k=5, smoother=0.1: LL=-0.4902
# Species bre, k=0, smoother=0.001: LL=-2.1779
# Species bre, k=0, smoother=0.01: LL=-2.1779
# Species bre, k=0, smoother=0.1: LL=-2.1779
# Species bre, k=1, smoother=0.001: LL=-0.0717
# Species bre, k=1, smoother=0.01: LL=-0.0717
# Species bre, k=1, smoother=0.1: LL=-0.0717
# Species bre, k=2, smoother=0.001: LL=-0.0809
# Species bre, k=2, smoother=0.01: LL=-0.0806
# Species bre, k=2, smoother=0.1: LL=-0.0807
# Species bre, k=3, smoother=0.001: LL=-0.1016
# Species bre, k=3, smoother=0.01: LL=-0.1000
# Species bre, k=3, smoother=0.1: LL=-0.1005
# Species bre, k=4, smoother=0.001: LL=-0.2642
# Species bre, k=4, smoother=0.01: LL=-0.2589
# Species bre, k=4, smoother=0.1: LL=-0.2611
# Species bre, k=5, smoother=0.001: LL=-0.8174
# Species bre, k=5, smoother=0.01: LL=-0.7919
# Species bre, k=5, smoother=0.1: LL=-0.7832
# Species bre, k=0, smoother=0.001: LL=-2.2228
# Species bre, k=0, smoother=0.01: LL=-2.2228
# Species bre, k=0, smoother=0.1: LL=-2.2228
# Species bre, k=1, smoother=0.001: LL=-0.0776
# Species bre, k=1, smoother=0.01: LL=-0.0776
# Species bre, k=1, smoother=0.1: LL=-0.0776
# Species bre, k=2, smoother=0.001: LL=-0.0749
# Species bre, k=2, smoother=0.01: LL=-0.0744
# Species bre, k=2, smoother=0.1: LL=-0.0742
# Species bre, k=3, smoother=0.001: LL=-0.1015
# Species bre, k=3, smoother=0.01: LL=-0.0991
# Species bre, k=3, smoother=0.1: LL=-0.1007
# Species bre, k=4, smoother=0.001: LL=-0.4732
# Species bre, k=4, smoother=0.01: LL=-0.4664
# Species bre, k=4, smoother=0.1: LL=-0.4663
# Species bre, k=5, smoother=0.001: LL=-1.0238
# Species bre, k=5, smoother=0.01: LL=-0.9897
# Species bre, k=5, smoother=0.1: LL=-0.9737
# Species bre, k=0, smoother=0.001: LL=-2.2437
# Species bre, k=0, smoother=0.01: LL=-2.2437
# Species bre, k=0, smoother=0.1: LL=-2.2437
# Species bre, k=1, smoother=0.001: LL=-0.0841
# Species bre, k=1, smoother=0.01: LL=-0.0841
# Species bre, k=1, smoother=0.1: LL=-0.0841
# Species bre, k=2, smoother=0.001: LL=-0.0800
# Species bre, k=2, smoother=0.01: LL=-0.0797
# Species bre, k=2, smoother=0.1: LL=-0.0798
# Species bre, k=3, smoother=0.001: LL=-0.1032
# Species bre, k=3, smoother=0.01: LL=-0.1008
# Species bre, k=3, smoother=0.1: LL=-0.1000
# Species bre, k=4, smoother=0.001: LL=-0.3103
# Species bre, k=4, smoother=0.01: LL=-0.3065
# Species bre, k=4, smoother=0.1: LL=-0.3085
# Species bre, k=5, smoother=0.001: LL=-0.9517
# Species bre, k=5, smoother=0.01: LL=-0.9173
# Species bre, k=5, smoother=0.1: LL=-0.8972
# Species bre, k=0, smoother=0.001: LL=-2.1680
# Species bre, k=0, smoother=0.01: LL=-2.1680
# Species bre, k=0, smoother=0.1: LL=-2.1680
# Species bre, k=1, smoother=0.001: LL=-0.0916
# Species bre, k=1, smoother=0.01: LL=-0.0916
# Species bre, k=1, smoother=0.1: LL=-0.0916
# Species bre, k=2, smoother=0.001: LL=-0.0887
# Species bre, k=2, smoother=0.01: LL=-0.0883
# Species bre, k=2, smoother=0.1: LL=-0.0880
# Species bre, k=3, smoother=0.001: LL=-0.1249
# Species bre, k=3, smoother=0.01: LL=-0.1228
# Species bre, k=3, smoother=0.1: LL=-0.1227
# Species bre, k=4, smoother=0.001: LL=-0.3159
# Species bre, k=4, smoother=0.01: LL=-0.3067
# Species bre, k=4, smoother=0.1: LL=-0.3046
# Species bre, k=5, smoother=0.001: LL=-0.8541
# Species bre, k=5, smoother=0.01: LL=-0.8499
# Species bre, k=5, smoother=0.1: LL=-0.8559
# Species bre, k=0, smoother=0.001: LL=-2.2017
# Species bre, k=0, smoother=0.01: LL=-2.2017
# Species bre, k=0, smoother=0.1: LL=-2.2017
# Species bre, k=1, smoother=0.001: LL=-0.0838
# Species bre, k=1, smoother=0.01: LL=-0.0838
# Species bre, k=1, smoother=0.1: LL=-0.0839
# Species bre, k=2, smoother=0.001: LL=-0.0812
# Species bre, k=2, smoother=0.01: LL=-0.0812
# Species bre, k=2, smoother=0.1: LL=-0.0815
# Species bre, k=3, smoother=0.001: LL=-0.0872
# Species bre, k=3, smoother=0.01: LL=-0.0852
# Species bre, k=3, smoother=0.1: LL=-0.0859
# Species bre, k=4, smoother=0.001: LL=-0.2654
# Species bre, k=4, smoother=0.01: LL=-0.2589
# Species bre, k=4, smoother=0.1: LL=-0.2602
# Species bre, k=5, smoother=0.001: LL=-0.6472
# Species bre, k=5, smoother=0.01: LL=-0.6380
# Species bre, k=5, smoother=0.1: LL=-0.6415
# Species bre, k=0, smoother=0.001: LL=-2.2926
# Species bre, k=0, smoother=0.01: LL=-2.2926
# Species bre, k=0, smoother=0.1: LL=-2.2926
# Species bre, k=1, smoother=0.001: LL=-0.0676
# Species bre, k=1, smoother=0.01: LL=-0.0676
# Species bre, k=1, smoother=0.1: LL=-0.0677
# Species bre, k=2, smoother=0.001: LL=-0.0648
# Species bre, k=2, smoother=0.01: LL=-0.0645
# Species bre, k=2, smoother=0.1: LL=-0.0646
# Species bre, k=3, smoother=0.001: LL=-0.1685
# Species bre, k=3, smoother=0.01: LL=-0.1666
# Species bre, k=3, smoother=0.1: LL=-0.1666
# Species bre, k=4, smoother=0.001: LL=-0.3641
# Species bre, k=4, smoother=0.01: LL=-0.3610
# Species bre, k=4, smoother=0.1: LL=-0.3629
# Species bre, k=5, smoother=0.001: LL=-0.9300
# Species bre, k=5, smoother=0.01: LL=-0.9252
# Species bre, k=5, smoother=0.1: LL=-0.9292
# Species bre, k=0, smoother=0.001: LL=-2.2289
# Species bre, k=0, smoother=0.01: LL=-2.2289
# Species bre, k=0, smoother=0.1: LL=-2.2289
# Species bre, k=1, smoother=0.001: LL=-0.0861
# Species bre, k=1, smoother=0.01: LL=-0.0861
# Species bre, k=1, smoother=0.1: LL=-0.0862
# Species bre, k=2, smoother=0.001: LL=-0.0825
# Species bre, k=2, smoother=0.01: LL=-0.0820
# Species bre, k=2, smoother=0.1: LL=-0.0818
# Species bre, k=3, smoother=0.001: LL=-0.1088
# Species bre, k=3, smoother=0.01: LL=-0.1069
# Species bre, k=3, smoother=0.1: LL=-0.1066
# Species bre, k=4, smoother=0.001: LL=-0.2487
# Species bre, k=4, smoother=0.01: LL=-0.2455
# Species bre, k=4, smoother=0.1: LL=-0.2490
# Species bre, k=5, smoother=0.001: LL=-0.7480
# Species bre, k=5, smoother=0.01: LL=-0.7446
# Species bre, k=5, smoother=0.1: LL=-0.7500
# Species bre, k=0, smoother=0.001: LL=-2.2694
# Species bre, k=0, smoother=0.01: LL=-2.2694
# Species bre, k=0, smoother=0.1: LL=-2.2694
# Species bre, k=1, smoother=0.001: LL=-0.0833
# Species bre, k=1, smoother=0.01: LL=-0.0833
# Species bre, k=1, smoother=0.1: LL=-0.0834
# Species bre, k=2, smoother=0.001: LL=-0.0797
# Species bre, k=2, smoother=0.01: LL=-0.0797
# Species bre, k=2, smoother=0.1: LL=-0.0798
# Species bre, k=3, smoother=0.001: LL=-0.0855
# Species bre, k=3, smoother=0.01: LL=-0.0841
# Species bre, k=3, smoother=0.1: LL=-0.0843
# Species bre, k=4, smoother=0.001: LL=-0.1565
# Species bre, k=4, smoother=0.01: LL=-0.1539
# Species bre, k=4, smoother=0.1: LL=-0.1555
# Species bre, k=5, smoother=0.001: LL=-0.5314
# Species bre, k=5, smoother=0.01: LL=-0.5287
# Species bre, k=5, smoother=0.1: LL=-0.5354
# Species bre, k=0, smoother=0.001: LL=-2.2891
# Species bre, k=0, smoother=0.01: LL=-2.2891
# Species bre, k=0, smoother=0.1: LL=-2.2891
# Species bre, k=1, smoother=0.001: LL=-0.0749
# Species bre, k=1, smoother=0.01: LL=-0.0749
# Species bre, k=1, smoother=0.1: LL=-0.0750
# Species bre, k=2, smoother=0.001: LL=-0.0738
# Species bre, k=2, smoother=0.01: LL=-0.0733
# Species bre, k=2, smoother=0.1: LL=-0.0731
# Species bre, k=3, smoother=0.001: LL=-0.0868
# Species bre, k=3, smoother=0.01: LL=-0.0848
# Species bre, k=3, smoother=0.1: LL=-0.0843
# Species bre, k=4, smoother=0.001: LL=-0.2320
# Species bre, k=4, smoother=0.01: LL=-0.2290
# Species bre, k=4, smoother=0.1: LL=-0.2316
# Species bre, k=5, smoother=0.001: LL=-0.5513
# Species bre, k=5, smoother=0.01: LL=-0.5480
# Species bre, k=5, smoother=0.1: LL=-0.5545
# Species bre, k=0, smoother=0.001: LL=-2.3616
# Species bre, k=0, smoother=0.01: LL=-2.3616
# Species bre, k=0, smoother=0.1: LL=-2.3616
# Species bre, k=1, smoother=0.001: LL=-0.0764
# Species bre, k=1, smoother=0.01: LL=-0.0764
# Species bre, k=1, smoother=0.1: LL=-0.0765
# Species bre, k=2, smoother=0.001: LL=-0.0735
# Species bre, k=2, smoother=0.01: LL=-0.0730
# Species bre, k=2, smoother=0.1: LL=-0.0731
# Species bre, k=3, smoother=0.001: LL=-0.0995
# Species bre, k=3, smoother=0.01: LL=-0.0950
# Species bre, k=3, smoother=0.1: LL=-0.0932
# Species bre, k=4, smoother=0.001: LL=-0.3294
# Species bre, k=4, smoother=0.01: LL=-0.3239
# Species bre, k=4, smoother=0.1: LL=-0.3238
# Species bre, k=5, smoother=0.001: LL=-0.7305
# Species bre, k=5, smoother=0.01: LL=-0.6986
# Species bre, k=5, smoother=0.1: LL=-0.6849
# Species bre, k=0, smoother=0.001: LL=-2.3294
# Species bre, k=0, smoother=0.01: LL=-2.3294
# Species bre, k=0, smoother=0.1: LL=-2.3294
# Species bre, k=1, smoother=0.001: LL=-0.0690
# Species bre, k=1, smoother=0.01: LL=-0.0690
# Species bre, k=1, smoother=0.1: LL=-0.0691
# Species bre, k=2, smoother=0.001: LL=-0.0667
# Species bre, k=2, smoother=0.01: LL=-0.0664
# Species bre, k=2, smoother=0.1: LL=-0.0665
# Species bre, k=3, smoother=0.001: LL=-0.0728
# Species bre, k=3, smoother=0.01: LL=-0.0707
# Species bre, k=3, smoother=0.1: LL=-0.0705
# Species bre, k=4, smoother=0.001: LL=-0.2920
# Species bre, k=4, smoother=0.01: LL=-0.2870
# Species bre, k=4, smoother=0.1: LL=-0.2884
# Species bre, k=5, smoother=0.001: LL=-0.9253
# Species bre, k=5, smoother=0.01: LL=-0.9200
# Species bre, k=5, smoother=0.1: LL=-0.9244
# Species bre, k=0, smoother=0.001: LL=-2.3069
# Species bre, k=0, smoother=0.01: LL=-2.3069
# Species bre, k=0, smoother=0.1: LL=-2.3069
# Species bre, k=1, smoother=0.001: LL=-0.1021
# Species bre, k=1, smoother=0.01: LL=-0.1021
# Species bre, k=1, smoother=0.1: LL=-0.1022
# Species bre, k=2, smoother=0.001: LL=-0.0990
# Species bre, k=2, smoother=0.01: LL=-0.0984
# Species bre, k=2, smoother=0.1: LL=-0.0993
# Species bre, k=3, smoother=0.001: LL=-0.1308
# Species bre, k=3, smoother=0.01: LL=-0.1264
# Species bre, k=3, smoother=0.1: LL=-0.1264
# Species bre, k=4, smoother=0.001: LL=-0.3408
# Species bre, k=4, smoother=0.01: LL=-0.3363
# Species bre, k=4, smoother=0.1: LL=-0.3385
# Species bre, k=5, smoother=0.001: LL=-0.8462
# Species bre, k=5, smoother=0.01: LL=-0.8424
# Species bre, k=5, smoother=0.1: LL=-0.8471
# Species bre, k=0, smoother=0.001: LL=-2.2972
# Species bre, k=0, smoother=0.01: LL=-2.2972
# Species bre, k=0, smoother=0.1: LL=-2.2972
# Species bre, k=1, smoother=0.001: LL=-0.0632
# Species bre, k=1, smoother=0.01: LL=-0.0632
# Species bre, k=1, smoother=0.1: LL=-0.0632
# Species bre, k=2, smoother=0.001: LL=-0.0600
# Species bre, k=2, smoother=0.01: LL=-0.0597
# Species bre, k=2, smoother=0.1: LL=-0.0598
# Species bre, k=3, smoother=0.001: LL=-0.0740
# Species bre, k=3, smoother=0.01: LL=-0.0724
# Species bre, k=3, smoother=0.1: LL=-0.0742
# Species bre, k=4, smoother=0.001: LL=-0.1573
# Species bre, k=4, smoother=0.01: LL=-0.1546
# Species bre, k=4, smoother=0.1: LL=-0.1579
# Species bre, k=5, smoother=0.001: LL=-0.7393
# Species bre, k=5, smoother=0.01: LL=-0.7355
# Species bre, k=5, smoother=0.1: LL=-0.7414
# Species bre, k=0, smoother=0.001: LL=-2.2502
# Species bre, k=0, smoother=0.01: LL=-2.2502
# Species bre, k=0, smoother=0.1: LL=-2.2502
# Species bre, k=1, smoother=0.001: LL=-0.0851
# Species bre, k=1, smoother=0.01: LL=-0.0851
# Species bre, k=1, smoother=0.1: LL=-0.0852
# Species bre, k=2, smoother=0.001: LL=-0.0820
# Species bre, k=2, smoother=0.01: LL=-0.0817
# Species bre, k=2, smoother=0.1: LL=-0.0819
# Species bre, k=3, smoother=0.001: LL=-0.1125
# Species bre, k=3, smoother=0.01: LL=-0.1076
# Species bre, k=3, smoother=0.1: LL=-0.1072
# Species bre, k=4, smoother=0.001: LL=-0.3648
# Species bre, k=4, smoother=0.01: LL=-0.3520
# Species bre, k=4, smoother=0.1: LL=-0.3505
# Species bre, k=5, smoother=0.001: LL=-0.9972
# Species bre, k=5, smoother=0.01: LL=-0.9923
# Species bre, k=5, smoother=0.1: LL=-0.9990
# Species bre, k=0, smoother=0.001: LL=-2.2724
# Species bre, k=0, smoother=0.01: LL=-2.2724
# Species bre, k=0, smoother=0.1: LL=-2.2724
# Species bre, k=1, smoother=0.001: LL=-0.0918
# Species bre, k=1, smoother=0.01: LL=-0.0918
# Species bre, k=1, smoother=0.1: LL=-0.0918
# Species bre, k=2, smoother=0.001: LL=-0.0873
# Species bre, k=2, smoother=0.01: LL=-0.0870
# Species bre, k=2, smoother=0.1: LL=-0.0871
# Species bre, k=3, smoother=0.001: LL=-0.1026
# Species bre, k=3, smoother=0.01: LL=-0.0996
# Species bre, k=3, smoother=0.1: LL=-0.1015
# Species bre, k=4, smoother=0.001: LL=-0.3350
# Species bre, k=4, smoother=0.01: LL=-0.3287
# Species bre, k=4, smoother=0.1: LL=-0.3351
# Species bre, k=5, smoother=0.001: LL=-1.0940
# Species bre, k=5, smoother=0.01: LL=-1.0864
# Species bre, k=5, smoother=0.1: LL=-1.0917
# Species bre, k=0, smoother=0.001: LL=-2.2143
# Species bre, k=0, smoother=0.01: LL=-2.2143
# Species bre, k=0, smoother=0.1: LL=-2.2143
# Species bre, k=1, smoother=0.001: LL=-0.0769
# Species bre, k=1, smoother=0.01: LL=-0.0769
# Species bre, k=1, smoother=0.1: LL=-0.0770
# Species bre, k=2, smoother=0.001: LL=-0.0737
# Species bre, k=2, smoother=0.01: LL=-0.0734
# Species bre, k=2, smoother=0.1: LL=-0.0732
# Species bre, k=3, smoother=0.001: LL=-0.0818
# Species bre, k=3, smoother=0.01: LL=-0.0804
# Species bre, k=3, smoother=0.1: LL=-0.0807
# Species bre, k=4, smoother=0.001: LL=-0.2282
# Species bre, k=4, smoother=0.01: LL=-0.2233
# Species bre, k=4, smoother=0.1: LL=-0.2245
# Species bre, k=5, smoother=0.001: LL=-0.7149
# Species bre, k=5, smoother=0.01: LL=-0.7054
# Species bre, k=5, smoother=0.1: LL=-0.7068
# Species bre, k=0, smoother=0.001: LL=-2.2118
# Species bre, k=0, smoother=0.01: LL=-2.2118
# Species bre, k=0, smoother=0.1: LL=-2.2118
# Species bre, k=1, smoother=0.001: LL=-0.0998
# Species bre, k=1, smoother=0.01: LL=-0.0998
# Species bre, k=1, smoother=0.1: LL=-0.0999
# Species bre, k=2, smoother=0.001: LL=-0.0949
# Species bre, k=2, smoother=0.01: LL=-0.0946
# Species bre, k=2, smoother=0.1: LL=-0.0949
# Species bre, k=3, smoother=0.001: LL=-0.1099
# Species bre, k=3, smoother=0.01: LL=-0.1058
# Species bre, k=3, smoother=0.1: LL=-0.1063
# Species bre, k=4, smoother=0.001: LL=-0.2143
# Species bre, k=4, smoother=0.01: LL=-0.2069
# Species bre, k=4, smoother=0.1: LL=-0.2112
# Species bre, k=5, smoother=0.001: LL=-0.7335
# Species bre, k=5, smoother=0.01: LL=-0.7247
# Species bre, k=5, smoother=0.1: LL=-0.7258
# Species bre, k=0, smoother=0.001: LL=-2.2481
# Species bre, k=0, smoother=0.01: LL=-2.2481
# Species bre, k=0, smoother=0.1: LL=-2.2481
# Species bre, k=1, smoother=0.001: LL=-0.0682
# Species bre, k=1, smoother=0.01: LL=-0.0682
# Species bre, k=1, smoother=0.1: LL=-0.0683
# Species bre, k=2, smoother=0.001: LL=-0.0657
# Species bre, k=2, smoother=0.01: LL=-0.0653
# Species bre, k=2, smoother=0.1: LL=-0.0652
# Species bre, k=3, smoother=0.001: LL=-0.1810
# Species bre, k=3, smoother=0.01: LL=-0.1789
# Species bre, k=3, smoother=0.1: LL=-0.1802
# Species bre, k=4, smoother=0.001: LL=-0.3716
# Species bre, k=4, smoother=0.01: LL=-0.3681
# Species bre, k=4, smoother=0.1: LL=-0.3719
# Species bre, k=5, smoother=0.001: LL=-0.9924
# Species bre, k=5, smoother=0.01: LL=-0.9888
# Species bre, k=5, smoother=0.1: LL=-1.0000
# Species bre, k=0, smoother=0.001: LL=-2.3307
# Species bre, k=0, smoother=0.01: LL=-2.3307
# Species bre, k=0, smoother=0.1: LL=-2.3307
# Species bre, k=1, smoother=0.001: LL=-0.0762
# Species bre, k=1, smoother=0.01: LL=-0.0761
# Species bre, k=1, smoother=0.1: LL=-0.0761
# Species bre, k=2, smoother=0.001: LL=-0.0827
# Species bre, k=2, smoother=0.01: LL=-0.0823
# Species bre, k=2, smoother=0.1: LL=-0.0823
# Species bre, k=3, smoother=0.001: LL=-0.1209
# Species bre, k=3, smoother=0.01: LL=-0.1184
# Species bre, k=3, smoother=0.1: LL=-0.1188
# Species bre, k=4, smoother=0.001: LL=-0.3817
# Species bre, k=4, smoother=0.01: LL=-0.3773
# Species bre, k=4, smoother=0.1: LL=-0.3807
# Species bre, k=5, smoother=0.001: LL=-0.9133
# Species bre, k=5, smoother=0.01: LL=-0.9083
# Species bre, k=5, smoother=0.1: LL=-0.9128
# Species bre, k=0, smoother=0.001: LL=-2.2104
# Species bre, k=0, smoother=0.01: LL=-2.2104
# Species bre, k=0, smoother=0.1: LL=-2.2104
# Species bre, k=1, smoother=0.001: LL=-0.0902
# Species bre, k=1, smoother=0.01: LL=-0.0902
# Species bre, k=1, smoother=0.1: LL=-0.0902
# Species bre, k=2, smoother=0.001: LL=-0.0980
# Species bre, k=2, smoother=0.01: LL=-0.0977
# Species bre, k=2, smoother=0.1: LL=-0.0976
# Species bre, k=3, smoother=0.001: LL=-0.1125
# Species bre, k=3, smoother=0.01: LL=-0.1107
# Species bre, k=3, smoother=0.1: LL=-0.1105
# Species bre, k=4, smoother=0.001: LL=-0.3368
# Species bre, k=4, smoother=0.01: LL=-0.3318
# Species bre, k=4, smoother=0.1: LL=-0.3316
# Species bre, k=5, smoother=0.001: LL=-0.6675
# Species bre, k=5, smoother=0.01: LL=-0.6584
# Species bre, k=5, smoother=0.1: LL=-0.6605
# Species bre, k=0, smoother=0.001: LL=-2.2216
# Species bre, k=0, smoother=0.01: LL=-2.2216
# Species bre, k=0, smoother=0.1: LL=-2.2216
# Species bre, k=1, smoother=0.001: LL=-0.0903
# Species bre, k=1, smoother=0.01: LL=-0.0903
# Species bre, k=1, smoother=0.1: LL=-0.0904
# Species bre, k=2, smoother=0.001: LL=-0.0870
# Species bre, k=2, smoother=0.01: LL=-0.0865
# Species bre, k=2, smoother=0.1: LL=-0.0863
# Species bre, k=3, smoother=0.001: LL=-0.1214
# Species bre, k=3, smoother=0.01: LL=-0.1196
# Species bre, k=3, smoother=0.1: LL=-0.1197
# Species bre, k=4, smoother=0.001: LL=-0.2201
# Species bre, k=4, smoother=0.01: LL=-0.2174
# Species bre, k=4, smoother=0.1: LL=-0.2197
# Species bre, k=5, smoother=0.001: LL=-0.6047
# Species bre, k=5, smoother=0.01: LL=-0.6011
# Species bre, k=5, smoother=0.1: LL=-0.6125
# Species bre, k=0, smoother=0.001: LL=-2.3809
# Species bre, k=0, smoother=0.01: LL=-2.3809
# Species bre, k=0, smoother=0.1: LL=-2.3809
# Species bre, k=1, smoother=0.001: LL=-0.0801
# Species bre, k=1, smoother=0.01: LL=-0.0801
# Species bre, k=1, smoother=0.1: LL=-0.0801
# Species bre, k=2, smoother=0.001: LL=-0.0763
# Species bre, k=2, smoother=0.01: LL=-0.0762
# Species bre, k=2, smoother=0.1: LL=-0.0765
# Species bre, k=3, smoother=0.001: LL=-0.0848
# Species bre, k=3, smoother=0.01: LL=-0.0827
# Species bre, k=3, smoother=0.1: LL=-0.0829
# Species bre, k=4, smoother=0.001: LL=-0.2475
# Species bre, k=4, smoother=0.01: LL=-0.2433
# Species bre, k=4, smoother=0.1: LL=-0.2462
# Species bre, k=5, smoother=0.001: LL=-0.6646
# Species bre, k=5, smoother=0.01: LL=-0.6608
# Species bre, k=5, smoother=0.1: LL=-0.6671
# Species bre, k=0, smoother=0.001: LL=-2.1618
# Species bre, k=0, smoother=0.01: LL=-2.1618
# Species bre, k=0, smoother=0.1: LL=-2.1618
# Species bre, k=1, smoother=0.001: LL=-0.0969
# Species bre, k=1, smoother=0.01: LL=-0.0969
# Species bre, k=1, smoother=0.1: LL=-0.0970
# Species bre, k=2, smoother=0.001: LL=-0.0920
# Species bre, k=2, smoother=0.01: LL=-0.0919
# Species bre, k=2, smoother=0.1: LL=-0.0921
# Species bre, k=3, smoother=0.001: LL=-0.1133
# Species bre, k=3, smoother=0.01: LL=-0.1095
# Species bre, k=3, smoother=0.1: LL=-0.1096
# Species bre, k=4, smoother=0.001: LL=-0.3383
# Species bre, k=4, smoother=0.01: LL=-0.3344
# Species bre, k=4, smoother=0.1: LL=-0.3373
# Species bre, k=5, smoother=0.001: LL=-0.7970
# Species bre, k=5, smoother=0.01: LL=-0.7928
# Species bre, k=5, smoother=0.1: LL=-0.7978
# Species bre, k=0, smoother=0.001: LL=-2.1500
# Species bre, k=0, smoother=0.01: LL=-2.1500
# Species bre, k=0, smoother=0.1: LL=-2.1500
# Species bre, k=1, smoother=0.001: LL=-0.0804
# Species bre, k=1, smoother=0.01: LL=-0.0804
# Species bre, k=1, smoother=0.1: LL=-0.0804
# Species bre, k=2, smoother=0.001: LL=-0.0917
# Species bre, k=2, smoother=0.01: LL=-0.0915
# Species bre, k=2, smoother=0.1: LL=-0.0916
# Species bre, k=3, smoother=0.001: LL=-0.0970
# Species bre, k=3, smoother=0.01: LL=-0.0952
# Species bre, k=3, smoother=0.1: LL=-0.0957
# Species bre, k=4, smoother=0.001: LL=-0.2760
# Species bre, k=4, smoother=0.01: LL=-0.2707
# Species bre, k=4, smoother=0.1: LL=-0.2728
# Species bre, k=5, smoother=0.001: LL=-0.6764
# Species bre, k=5, smoother=0.01: LL=-0.6703
# Species bre, k=5, smoother=0.1: LL=-0.6744
# Species bre, k=0, smoother=0.001: LL=-2.2887
# Species bre, k=0, smoother=0.01: LL=-2.2887
# Species bre, k=0, smoother=0.1: LL=-2.2887
# Species bre, k=1, smoother=0.001: LL=-0.0833
# Species bre, k=1, smoother=0.01: LL=-0.0833
# Species bre, k=1, smoother=0.1: LL=-0.0833
# Species bre, k=2, smoother=0.001: LL=-0.0809
# Species bre, k=2, smoother=0.01: LL=-0.0803
# Species bre, k=2, smoother=0.1: LL=-0.0800
# Species bre, k=3, smoother=0.001: LL=-0.0919
# Species bre, k=3, smoother=0.01: LL=-0.0894
# Species bre, k=3, smoother=0.1: LL=-0.0900
# Species bre, k=4, smoother=0.001: LL=-0.3762
# Species bre, k=4, smoother=0.01: LL=-0.3645
# Species bre, k=4, smoother=0.1: LL=-0.3626
# Species bre, k=5, smoother=0.001: LL=-1.0849
# Species bre, k=5, smoother=0.01: LL=-1.0795
# Species bre, k=5, smoother=0.1: LL=-1.0831
# Species bre, k=0, smoother=0.001: LL=-2.2979
# Species bre, k=0, smoother=0.01: LL=-2.2979
# Species bre, k=0, smoother=0.1: LL=-2.2979
# Species bre, k=1, smoother=0.001: LL=-0.0720
# Species bre, k=1, smoother=0.01: LL=-0.0720
# Species bre, k=1, smoother=0.1: LL=-0.0721
# Species bre, k=2, smoother=0.001: LL=-0.0689
# Species bre, k=2, smoother=0.01: LL=-0.0688
# Species bre, k=2, smoother=0.1: LL=-0.0690
# Species bre, k=3, smoother=0.001: LL=-0.0765
# Species bre, k=3, smoother=0.01: LL=-0.0739
# Species bre, k=3, smoother=0.1: LL=-0.0744
# Species bre, k=4, smoother=0.001: LL=-0.3119
# Species bre, k=4, smoother=0.01: LL=-0.3001
# Species bre, k=4, smoother=0.1: LL=-0.2957
# Species bre, k=5, smoother=0.001: LL=-0.9053
# Species bre, k=5, smoother=0.01: LL=-0.9007
# Species bre, k=5, smoother=0.1: LL=-0.9043
# Species bre, k=0, smoother=0.001: LL=-2.2681
# Species bre, k=0, smoother=0.01: LL=-2.2681
# Species bre, k=0, smoother=0.1: LL=-2.2681
# Species bre, k=1, smoother=0.001: LL=-0.0778
# Species bre, k=1, smoother=0.01: LL=-0.0778
# Species bre, k=1, smoother=0.1: LL=-0.0778
# Species bre, k=2, smoother=0.001: LL=-0.0738
# Species bre, k=2, smoother=0.01: LL=-0.0736
# Species bre, k=2, smoother=0.1: LL=-0.0738
# Species bre, k=3, smoother=0.001: LL=-0.0966
# Species bre, k=3, smoother=0.01: LL=-0.0949
# Species bre, k=3, smoother=0.1: LL=-0.0953
# Species bre, k=4, smoother=0.001: LL=-0.2801
# Species bre, k=4, smoother=0.01: LL=-0.2765
# Species bre, k=4, smoother=0.1: LL=-0.2790
# Species bre, k=5, smoother=0.001: LL=-0.9500
# Species bre, k=5, smoother=0.01: LL=-0.9254
# Species bre, k=5, smoother=0.1: LL=-0.9162
# Species bre, k=0, smoother=0.001: LL=-2.2324
# Species bre, k=0, smoother=0.01: LL=-2.2324
# Species bre, k=0, smoother=0.1: LL=-2.2324
# Species bre, k=1, smoother=0.001: LL=-0.1058
# Species bre, k=1, smoother=0.01: LL=-0.1058
# Species bre, k=1, smoother=0.1: LL=-0.1059
# Species bre, k=2, smoother=0.001: LL=-0.1009
# Species bre, k=2, smoother=0.01: LL=-0.1006
# Species bre, k=2, smoother=0.1: LL=-0.1008
# Species bre, k=3, smoother=0.001: LL=-0.1268
# Species bre, k=3, smoother=0.01: LL=-0.1245
# Species bre, k=3, smoother=0.1: LL=-0.1254
# Species bre, k=4, smoother=0.001: LL=-0.4263
# Species bre, k=4, smoother=0.01: LL=-0.4222
# Species bre, k=4, smoother=0.1: LL=-0.4248
# Species bre, k=5, smoother=0.001: LL=-0.9778
# Species bre, k=5, smoother=0.01: LL=-0.9477
# Species bre, k=5, smoother=0.1: LL=-0.9362
# Species bre, k=0, smoother=0.001: LL=-2.2124
# Species bre, k=0, smoother=0.01: LL=-2.2124
# Species bre, k=0, smoother=0.1: LL=-2.2124
# Species bre, k=1, smoother=0.001: LL=-0.0799
# Species bre, k=1, smoother=0.01: LL=-0.0799
# Species bre, k=1, smoother=0.1: LL=-0.0799
# Species bre, k=2, smoother=0.001: LL=-0.0780
# Species bre, k=2, smoother=0.01: LL=-0.0776
# Species bre, k=2, smoother=0.1: LL=-0.0774
# Species bre, k=3, smoother=0.001: LL=-0.1068
# Species bre, k=3, smoother=0.01: LL=-0.1052
# Species bre, k=3, smoother=0.1: LL=-0.1048
# Species bre, k=4, smoother=0.001: LL=-0.2550
# Species bre, k=4, smoother=0.01: LL=-0.2463
# Species bre, k=4, smoother=0.1: LL=-0.2428
# Species bre, k=5, smoother=0.001: LL=-0.5888
# Species bre, k=5, smoother=0.01: LL=-0.5858
# Species bre, k=5, smoother=0.1: LL=-0.5949
# Species bre, k=0, smoother=0.001: LL=-2.1874
# Species bre, k=0, smoother=0.01: LL=-2.1874
# Species bre, k=0, smoother=0.1: LL=-2.1874
# Species bre, k=1, smoother=0.001: LL=-0.0832
# Species bre, k=1, smoother=0.01: LL=-0.0831
# Species bre, k=1, smoother=0.1: LL=-0.0831
# Species bre, k=2, smoother=0.001: LL=-0.0894
# Species bre, k=2, smoother=0.01: LL=-0.0891
# Species bre, k=2, smoother=0.1: LL=-0.0890
# Species bre, k=3, smoother=0.001: LL=-0.1053
# Species bre, k=3, smoother=0.01: LL=-0.1037
# Species bre, k=3, smoother=0.1: LL=-0.1032
# Species bre, k=4, smoother=0.001: LL=-0.2553
# Species bre, k=4, smoother=0.01: LL=-0.2504
# Species bre, k=4, smoother=0.1: LL=-0.2515
# Species bre, k=5, smoother=0.001: LL=-0.6776
# Species bre, k=5, smoother=0.01: LL=-0.6709
# Species bre, k=5, smoother=0.1: LL=-0.6741
# Species bre, k=0, smoother=0.001: LL=-2.3688
# Species bre, k=0, smoother=0.01: LL=-2.3688
# Species bre, k=0, smoother=0.1: LL=-2.3688
# Species bre, k=1, smoother=0.001: LL=-0.0629
# Species bre, k=1, smoother=0.01: LL=-0.0629
# Species bre, k=1, smoother=0.1: LL=-0.0630
# Species bre, k=2, smoother=0.001: LL=-0.0615
# Species bre, k=2, smoother=0.01: LL=-0.0612
# Species bre, k=2, smoother=0.1: LL=-0.0614
# Species bre, k=3, smoother=0.001: LL=-0.0820
# Species bre, k=3, smoother=0.01: LL=-0.0803
# Species bre, k=3, smoother=0.1: LL=-0.0807
# Species bre, k=4, smoother=0.001: LL=-0.2960
# Species bre, k=4, smoother=0.01: LL=-0.2910
# Species bre, k=4, smoother=0.1: LL=-0.2934
# Species bre, k=5, smoother=0.001: LL=-0.8334
# Species bre, k=5, smoother=0.01: LL=-0.8260
# Species bre, k=5, smoother=0.1: LL=-0.8285
# Species bre, k=0, smoother=0.001: LL=-2.3518
# Species bre, k=0, smoother=0.01: LL=-2.3518
# Species bre, k=0, smoother=0.1: LL=-2.3518
# Species bre, k=1, smoother=0.001: LL=-0.0838
# Species bre, k=1, smoother=0.01: LL=-0.0838
# Species bre, k=1, smoother=0.1: LL=-0.0839
# Species bre, k=2, smoother=0.001: LL=-0.0796
# Species bre, k=2, smoother=0.01: LL=-0.0793
# Species bre, k=2, smoother=0.1: LL=-0.0794
# Species bre, k=3, smoother=0.001: LL=-0.0868
# Species bre, k=3, smoother=0.01: LL=-0.0848
# Species bre, k=3, smoother=0.1: LL=-0.0857
# Species bre, k=4, smoother=0.001: LL=-0.2972
# Species bre, k=4, smoother=0.01: LL=-0.2938
# Species bre, k=4, smoother=0.1: LL=-0.2990
# Species bre, k=5, smoother=0.001: LL=-1.0788
# Species bre, k=5, smoother=0.01: LL=-1.0476
# Species bre, k=5, smoother=0.1: LL=-1.0364
# Species bre, k=0, smoother=0.001: LL=-2.2332
# Species bre, k=0, smoother=0.01: LL=-2.2332
# Species bre, k=0, smoother=0.1: LL=-2.2332
# Species bre, k=1, smoother=0.001: LL=-0.0697
# Species bre, k=1, smoother=0.01: LL=-0.0697
# Species bre, k=1, smoother=0.1: LL=-0.0698
# Species bre, k=2, smoother=0.001: LL=-0.0665
# Species bre, k=2, smoother=0.01: LL=-0.0663
# Species bre, k=2, smoother=0.1: LL=-0.0665
# Species bre, k=3, smoother=0.001: LL=-0.0824
# Species bre, k=3, smoother=0.01: LL=-0.0805
# Species bre, k=3, smoother=0.1: LL=-0.0805
# Species bre, k=4, smoother=0.001: LL=-0.2477
# Species bre, k=4, smoother=0.01: LL=-0.2444
# Species bre, k=4, smoother=0.1: LL=-0.2461
# Species bre, k=5, smoother=0.001: LL=-0.9406
# Species bre, k=5, smoother=0.01: LL=-0.8955
# Species bre, k=5, smoother=0.1: LL=-0.8745
# Species mil, k=0, smoother=0.001: LL=-2.0753
# Species mil, k=0, smoother=0.01: LL=-2.0753
# Species mil, k=0, smoother=0.1: LL=-2.0753
# Species mil, k=1, smoother=0.001: LL=-0.0627
# Species mil, k=1, smoother=0.01: LL=-0.0626
# Species mil, k=1, smoother=0.1: LL=-0.0627
# Species mil, k=2, smoother=0.001: LL=-0.0654
# Species mil, k=2, smoother=0.01: LL=-0.0646
# Species mil, k=2, smoother=0.1: LL=-0.0648
# Species mil, k=3, smoother=0.001: LL=-0.1844
# Species mil, k=3, smoother=0.01: LL=-0.1828
# Species mil, k=3, smoother=0.1: LL=-0.1866
# Species mil, k=4, smoother=0.001: LL=-0.9096
# Species mil, k=4, smoother=0.01: LL=-0.9073
# Species mil, k=4, smoother=0.1: LL=-0.9128
# Species mil, k=5, smoother=0.001: LL=-1.6891
# Species mil, k=5, smoother=0.01: LL=-1.6865
# Species mil, k=5, smoother=0.1: LL=-1.6939
# Species mil, k=0, smoother=0.001: LL=-2.1870
# Species mil, k=0, smoother=0.01: LL=-2.1870
# Species mil, k=0, smoother=0.1: LL=-2.1870
# Species mil, k=1, smoother=0.001: LL=-0.1458
# Species mil, k=1, smoother=0.01: LL=-0.1457
# Species mil, k=1, smoother=0.1: LL=-0.1456
# Species mil, k=2, smoother=0.001: LL=-0.3347
# Species mil, k=2, smoother=0.01: LL=-0.3308
# Species mil, k=2, smoother=0.1: LL=-0.3282
# Species mil, k=3, smoother=0.001: LL=-0.6979
# Species mil, k=3, smoother=0.01: LL=-0.6930
# Species mil, k=3, smoother=0.1: LL=-0.6962
# Species mil, k=4, smoother=0.001: LL=-1.2143
# Species mil, k=4, smoother=0.01: LL=-1.2137
# Species mil, k=4, smoother=0.1: LL=-1.2312
# Species mil, k=5, smoother=0.001: LL=-2.0540
# Species mil, k=5, smoother=0.01: LL=-2.0526
# Species mil, k=5, smoother=0.1: LL=-2.0540
# Species mil, k=0, smoother=0.001: LL=-2.4085
# Species mil, k=0, smoother=0.01: LL=-2.4085
# Species mil, k=0, smoother=0.1: LL=-2.4085
# Species mil, k=1, smoother=0.001: LL=-0.0412
# Species mil, k=1, smoother=0.01: LL=-0.0411
# Species mil, k=1, smoother=0.1: LL=-0.0411
# Species mil, k=2, smoother=0.001: LL=-0.3136
# Species mil, k=2, smoother=0.01: LL=-0.3128
# Species mil, k=2, smoother=0.1: LL=-0.3130
# Species mil, k=3, smoother=0.001: LL=-0.3456
# Species mil, k=3, smoother=0.01: LL=-0.3445
# Species mil, k=3, smoother=0.1: LL=-0.3498
# Species mil, k=4, smoother=0.001: LL=-0.4102
# Species mil, k=4, smoother=0.01: LL=-0.4095
# Species mil, k=4, smoother=0.1: LL=-0.4262
# Species mil, k=5, smoother=0.001: LL=-1.4749
# Species mil, k=5, smoother=0.01: LL=-1.4733
# Species mil, k=5, smoother=0.1: LL=-1.4811
# Species mil, k=0, smoother=0.001: LL=-1.9613
# Species mil, k=0, smoother=0.01: LL=-1.9613
# Species mil, k=0, smoother=0.1: LL=-1.9613
# Species mil, k=1, smoother=0.001: LL=-0.0530
# Species mil, k=1, smoother=0.01: LL=-0.0525
# Species mil, k=1, smoother=0.1: LL=-0.0522
# Species mil, k=2, smoother=0.001: LL=-0.0662
# Species mil, k=2, smoother=0.01: LL=-0.0652
# Species mil, k=2, smoother=0.1: LL=-0.0651
# Species mil, k=3, smoother=0.001: LL=-0.1303
# Species mil, k=3, smoother=0.01: LL=-0.1291
# Species mil, k=3, smoother=0.1: LL=-0.1307
# Species mil, k=4, smoother=0.001: LL=-0.1905
# Species mil, k=4, smoother=0.01: LL=-0.1889
# Species mil, k=4, smoother=0.1: LL=-0.1944
# Species mil, k=5, smoother=0.001: LL=-1.6516
# Species mil, k=5, smoother=0.01: LL=-1.6491
# Species mil, k=5, smoother=0.1: LL=-1.6624
# Species mil, k=0, smoother=0.001: LL=-2.3858
# Species mil, k=0, smoother=0.01: LL=-2.3858
# Species mil, k=0, smoother=0.1: LL=-2.3858
# Species mil, k=1, smoother=0.001: LL=-0.0813
# Species mil, k=1, smoother=0.01: LL=-0.0813
# Species mil, k=1, smoother=0.1: LL=-0.0813
# Species mil, k=2, smoother=0.001: LL=-0.0852
# Species mil, k=2, smoother=0.01: LL=-0.0836
# Species mil, k=2, smoother=0.1: LL=-0.0831
# Species mil, k=3, smoother=0.001: LL=-0.4188
# Species mil, k=3, smoother=0.01: LL=-0.4085
# Species mil, k=3, smoother=0.1: LL=-0.4049
# Species mil, k=4, smoother=0.001: LL=-1.4681
# Species mil, k=4, smoother=0.01: LL=-1.4661
# Species mil, k=4, smoother=0.1: LL=-1.4762
# Species mil, k=5, smoother=0.001: LL=-1.9036
# Species mil, k=5, smoother=0.01: LL=-1.9026
# Species mil, k=5, smoother=0.1: LL=-1.9132
# Species mil, k=0, smoother=0.001: LL=-1.9917
# Species mil, k=0, smoother=0.01: LL=-1.9917
# Species mil, k=0, smoother=0.1: LL=-1.9917
# Species mil, k=1, smoother=0.001: LL=-0.0468
# Species mil, k=1, smoother=0.01: LL=-0.0466
# Species mil, k=1, smoother=0.1: LL=-0.0465
# Species mil, k=2, smoother=0.001: LL=-0.2725
# Species mil, k=2, smoother=0.01: LL=-0.2713
# Species mil, k=2, smoother=0.1: LL=-0.2707
# Species mil, k=3, smoother=0.001: LL=-0.4823
# Species mil, k=3, smoother=0.01: LL=-0.4809
# Species mil, k=3, smoother=0.1: LL=-0.4820
# Species mil, k=4, smoother=0.001: LL=-0.5945
# Species mil, k=4, smoother=0.01: LL=-0.5928
# Species mil, k=4, smoother=0.1: LL=-0.5955
# Species mil, k=5, smoother=0.001: LL=-1.5908
# Species mil, k=5, smoother=0.01: LL=-1.5890
# Species mil, k=5, smoother=0.1: LL=-1.5947
# Species mil, k=0, smoother=0.001: LL=-2.6621
# Species mil, k=0, smoother=0.01: LL=-2.6621
# Species mil, k=0, smoother=0.1: LL=-2.6621
# Species mil, k=1, smoother=0.001: LL=-0.0596
# Species mil, k=1, smoother=0.01: LL=-0.0596
# Species mil, k=1, smoother=0.1: LL=-0.0598
# Species mil, k=2, smoother=0.001: LL=-0.0593
# Species mil, k=2, smoother=0.01: LL=-0.0586
# Species mil, k=2, smoother=0.1: LL=-0.0591
# Species mil, k=3, smoother=0.001: LL=-0.2873
# Species mil, k=3, smoother=0.01: LL=-0.2846
# Species mil, k=3, smoother=0.1: LL=-0.2879
# Species mil, k=4, smoother=0.001: LL=-0.7362
# Species mil, k=4, smoother=0.01: LL=-0.7335
# Species mil, k=4, smoother=0.1: LL=-0.7422
# Species mil, k=5, smoother=0.001: LL=-1.4501
# Species mil, k=5, smoother=0.01: LL=-1.4484
# Species mil, k=5, smoother=0.1: LL=-1.4574
# Species mil, k=0, smoother=0.001: LL=-1.9575
# Species mil, k=0, smoother=0.01: LL=-1.9575
# Species mil, k=0, smoother=0.1: LL=-1.9575
# Species mil, k=1, smoother=0.001: LL=-0.1740
# Species mil, k=1, smoother=0.01: LL=-0.1740
# Species mil, k=1, smoother=0.1: LL=-0.1741
# Species mil, k=2, smoother=0.001: LL=-0.1518
# Species mil, k=2, smoother=0.01: LL=-0.1512
# Species mil, k=2, smoother=0.1: LL=-0.1512
# Species mil, k=3, smoother=0.001: LL=-0.2032
# Species mil, k=3, smoother=0.01: LL=-0.2045
# Species mil, k=3, smoother=0.1: LL=-0.2389
# Species mil, k=4, smoother=0.001: LL=-0.8503
# Species mil, k=4, smoother=0.01: LL=-0.8481
# Species mil, k=4, smoother=0.1: LL=-0.8683
# Species mil, k=5, smoother=0.001: LL=-1.3898
# Species mil, k=5, smoother=0.01: LL=-1.3881
# Species mil, k=5, smoother=0.1: LL=-1.4012
# Species mil, k=0, smoother=0.001: LL=-2.5784
# Species mil, k=0, smoother=0.01: LL=-2.5784
# Species mil, k=0, smoother=0.1: LL=-2.5784
# Species mil, k=1, smoother=0.001: LL=-0.0377
# Species mil, k=1, smoother=0.01: LL=-0.0376
# Species mil, k=1, smoother=0.1: LL=-0.0376
# Species mil, k=2, smoother=0.001: LL=-0.2536
# Species mil, k=2, smoother=0.01: LL=-0.2526
# Species mil, k=2, smoother=0.1: LL=-0.2527
# Species mil, k=3, smoother=0.001: LL=-0.6492
# Species mil, k=3, smoother=0.01: LL=-0.6483
# Species mil, k=3, smoother=0.1: LL=-0.6518
# Species mil, k=4, smoother=0.001: LL=-0.7387
# Species mil, k=4, smoother=0.01: LL=-0.7374
# Species mil, k=4, smoother=0.1: LL=-0.7449
# Species mil, k=5, smoother=0.001: LL=-1.4610
# Species mil, k=5, smoother=0.01: LL=-1.4598
# Species mil, k=5, smoother=0.1: LL=-1.4664
# Species mil, k=0, smoother=0.001: LL=-2.0971
# Species mil, k=0, smoother=0.01: LL=-2.0971
# Species mil, k=0, smoother=0.1: LL=-2.0971
# Species mil, k=1, smoother=0.001: LL=-0.0318
# Species mil, k=1, smoother=0.01: LL=-0.0318
# Species mil, k=1, smoother=0.1: LL=-0.0318
# Species mil, k=2, smoother=0.001: LL=-0.0338
# Species mil, k=2, smoother=0.01: LL=-0.0333
# Species mil, k=2, smoother=0.1: LL=-0.0345
# Species mil, k=3, smoother=0.001: LL=-0.0862
# Species mil, k=3, smoother=0.01: LL=-0.0858
# Species mil, k=3, smoother=0.1: LL=-0.0916
# Species mil, k=4, smoother=0.001: LL=-0.1404
# Species mil, k=4, smoother=0.01: LL=-0.1400
# Species mil, k=4, smoother=0.1: LL=-0.1537
# Species mil, k=5, smoother=0.001: LL=-1.3894
# Species mil, k=5, smoother=0.01: LL=-1.3887
# Species mil, k=5, smoother=0.1: LL=-1.4005
# Species mil, k=0, smoother=0.001: LL=-2.5810
# Species mil, k=0, smoother=0.01: LL=-2.5810
# Species mil, k=0, smoother=0.1: LL=-2.5810
# Species mil, k=1, smoother=0.001: LL=-0.0739
# Species mil, k=1, smoother=0.01: LL=-0.0739
# Species mil, k=1, smoother=0.1: LL=-0.0741
# Species mil, k=2, smoother=0.001: LL=-0.0736
# Species mil, k=2, smoother=0.01: LL=-0.0718
# Species mil, k=2, smoother=0.1: LL=-0.0716
# Species mil, k=3, smoother=0.001: LL=-0.4283
# ...
# Species pul, k=5, smoother=0.001: LL=-0.1702
# Species pul, k=5, smoother=0.01: LL=-0.1672
# Species pul, k=5, smoother=0.1: LL=-0.1689
# Species pul, k=0, smoother=0.001: LL=-2.1870
# Species pul, k=0, smoother=0.01: LL=-2.1870
# Species pul, k=0, smoother=0.1: LL=-2.1870
# Species pul, k=1, smoother=0.001: LL=-0.0621
# Species pul, k=1, smoother=0.01: LL=-0.0621
# Species pul, k=1, smoother=0.1: LL=-0.0621
# Species pul, k=2, smoother=0.001: LL=-0.0593
# Species pul, k=2, smoother=0.01: LL=-0.0593
# Species pul, k=2, smoother=0.1: LL=-0.0593
# Species pul, k=3, smoother=0.001: LL=-0.0607
# Species pul, k=3, smoother=0.01: LL=-0.0604
# Species pul, k=3, smoother=0.1: LL=-0.0605
# Species pul, k=4, smoother=0.001: LL=-0.0786
# Species pul, k=4, smoother=0.01: LL=-0.0778
# Species pul, k=4, smoother=0.1: LL=-0.0780
# Species pul, k=5, smoother=0.001: LL=-0.1889
# Species pul, k=5, smoother=0.01: LL=-0.1871
# Species pul, k=5, smoother=0.1: LL=-0.1900
# Species pul, k=0, smoother=0.001: LL=-2.2293
# Species pul, k=0, smoother=0.01: LL=-2.2293
# Species pul, k=0, smoother=0.1: LL=-2.2293
# Species pul, k=1, smoother=0.001: LL=-0.0697
# Species pul, k=1, smoother=0.01: LL=-0.0697
# Species pul, k=1, smoother=0.1: LL=-0.0697
# Species pul, k=2, smoother=0.001: LL=-0.0663
# Species pul, k=2, smoother=0.01: LL=-0.0661
# Species pul, k=2, smoother=0.1: LL=-0.0661
# Species pul, k=3, smoother=0.001: LL=-0.0701
# Species pul, k=3, smoother=0.01: LL=-0.0698
# Species pul, k=3, smoother=0.1: LL=-0.0698
# Species pul, k=4, smoother=0.001: LL=-0.0878
# Species pul, k=4, smoother=0.01: LL=-0.0868
# Species pul, k=4, smoother=0.1: LL=-0.0875
# Species pul, k=5, smoother=0.001: LL=-0.2005
# Species pul, k=5, smoother=0.01: LL=-0.1982
# Species pul, k=5, smoother=0.1: LL=-0.2008
# Species pul, k=0, smoother=0.001: LL=-2.2295
# Species pul, k=0, smoother=0.01: LL=-2.2295
# Species pul, k=0, smoother=0.1: LL=-2.2295
# Species pul, k=1, smoother=0.001: LL=-0.0740
# Species pul, k=1, smoother=0.01: LL=-0.0740
# Species pul, k=1, smoother=0.1: LL=-0.0740
# Species pul, k=2, smoother=0.001: LL=-0.0707
# Species pul, k=2, smoother=0.01: LL=-0.0707
# Species pul, k=2, smoother=0.1: LL=-0.0707
# Species pul, k=3, smoother=0.001: LL=-0.0706
# Species pul, k=3, smoother=0.01: LL=-0.0703
# Species pul, k=3, smoother=0.1: LL=-0.0701
# Species pul, k=4, smoother=0.001: LL=-0.0940
# Species pul, k=4, smoother=0.01: LL=-0.0930
# Species pul, k=4, smoother=0.1: LL=-0.0936
# Species pul, k=5, smoother=0.001: LL=-0.2065
# Species pul, k=5, smoother=0.01: LL=-0.2045
# Species pul, k=5, smoother=0.1: LL=-0.2062
# Species pul, k=0, smoother=0.001: LL=-2.2412
# Species pul, k=0, smoother=0.01: LL=-2.2412
# Species pul, k=0, smoother=0.1: LL=-2.2412
# Species pul, k=1, smoother=0.001: LL=-0.0734
# Species pul, k=1, smoother=0.01: LL=-0.0734
# Species pul, k=1, smoother=0.1: LL=-0.0734
# Species pul, k=2, smoother=0.001: LL=-0.0700
# Species pul, k=2, smoother=0.01: LL=-0.0699
# Species pul, k=2, smoother=0.1: LL=-0.0699
# Species pul, k=3, smoother=0.001: LL=-0.0771
# Species pul, k=3, smoother=0.01: LL=-0.0767
# Species pul, k=3, smoother=0.1: LL=-0.0767
# Species pul, k=4, smoother=0.001: LL=-0.0994
# Species pul, k=4, smoother=0.01: LL=-0.0983
# Species pul, k=4, smoother=0.1: LL=-0.0986
# Species pul, k=5, smoother=0.001: LL=-0.1776
# Species pul, k=5, smoother=0.01: LL=-0.1754
# Species pul, k=5, smoother=0.1: LL=-0.1766
# Species pul, k=0, smoother=0.001: LL=-2.2087
# Species pul, k=0, smoother=0.01: LL=-2.2087
# Species pul, k=0, smoother=0.1: LL=-2.2087
# Species pul, k=1, smoother=0.001: LL=-0.0629
# Species pul, k=1, smoother=0.01: LL=-0.0629
# Species pul, k=1, smoother=0.1: LL=-0.0629
# Species pul, k=2, smoother=0.001: LL=-0.0605
# Species pul, k=2, smoother=0.01: LL=-0.0604
# Species pul, k=2, smoother=0.1: LL=-0.0603
# Species pul, k=3, smoother=0.001: LL=-0.0609
# Species pul, k=3, smoother=0.01: LL=-0.0606
# Species pul, k=3, smoother=0.1: LL=-0.0608
# Species pul, k=4, smoother=0.001: LL=-0.0740
# Species pul, k=4, smoother=0.01: LL=-0.0732
# Species pul, k=4, smoother=0.1: LL=-0.0737
# Species pul, k=5, smoother=0.001: LL=-0.1608
# Species pul, k=5, smoother=0.01: LL=-0.1590
# Species pul, k=5, smoother=0.1: LL=-0.1612
# Species pul, k=0, smoother=0.001: LL=-2.2814
# Species pul, k=0, smoother=0.01: LL=-2.2814
# Species pul, k=0, smoother=0.1: LL=-2.2814
# Species pul, k=1, smoother=0.001: LL=-0.0740
# Species pul, k=1, smoother=0.01: LL=-0.0739
# Species pul, k=1, smoother=0.1: LL=-0.0739
# Species pul, k=2, smoother=0.001: LL=-0.0711
# Species pul, k=2, smoother=0.01: LL=-0.0710
# Species pul, k=2, smoother=0.1: LL=-0.0710
# Species pul, k=3, smoother=0.001: LL=-0.0717
# Species pul, k=3, smoother=0.01: LL=-0.0713
# Species pul, k=3, smoother=0.1: LL=-0.0712
# Species pul, k=4, smoother=0.001: LL=-0.0947
# Species pul, k=4, smoother=0.01: LL=-0.0934
# Species pul, k=4, smoother=0.1: LL=-0.0936
# Species pul, k=5, smoother=0.001: LL=-0.2028
# Species pul, k=5, smoother=0.01: LL=-0.1956
# Species pul, k=5, smoother=0.1: LL=-0.1937
# Species pul, k=0, smoother=0.001: LL=-2.2605
# Species pul, k=0, smoother=0.01: LL=-2.2605
# Species pul, k=0, smoother=0.1: LL=-2.2605
# Species pul, k=1, smoother=0.001: LL=-0.0749
# Species pul, k=1, smoother=0.01: LL=-0.0749
# Species pul, k=1, smoother=0.1: LL=-0.0750
# Species pul, k=2, smoother=0.001: LL=-0.0710
# Species pul, k=2, smoother=0.01: LL=-0.0709
# Species pul, k=2, smoother=0.1: LL=-0.0709
# Species pul, k=3, smoother=0.001: LL=-0.0769
# Species pul, k=3, smoother=0.01: LL=-0.0765
# Species pul, k=3, smoother=0.1: LL=-0.0765
# Species pul, k=4, smoother=0.001: LL=-0.1173
# Species pul, k=4, smoother=0.01: LL=-0.1162
# Species pul, k=4, smoother=0.1: LL=-0.1171
# Species pul, k=5, smoother=0.001: LL=-0.2411
# Species pul, k=5, smoother=0.01: LL=-0.2361
# Species pul, k=5, smoother=0.1: LL=-0.2364
# Species pul, k=0, smoother=0.001: LL=-2.2889
# Species pul, k=0, smoother=0.01: LL=-2.2889
# Species pul, k=0, smoother=0.1: LL=-2.2889
# Species pul, k=1, smoother=0.001: LL=-0.0775
# Species pul, k=1, smoother=0.01: LL=-0.0775
# Species pul, k=1, smoother=0.1: LL=-0.0775
# Species pul, k=2, smoother=0.001: LL=-0.0732
# Species pul, k=2, smoother=0.01: LL=-0.0732
# Species pul, k=2, smoother=0.1: LL=-0.0731
# Species pul, k=3, smoother=0.001: LL=-0.0740
# Species pul, k=3, smoother=0.01: LL=-0.0736
# Species pul, k=3, smoother=0.1: LL=-0.0736
# Species pul, k=4, smoother=0.001: LL=-0.1036
# Species pul, k=4, smoother=0.01: LL=-0.1018
# Species pul, k=4, smoother=0.1: LL=-0.1017
# Species pul, k=5, smoother=0.001: LL=-0.2567
# Species pul, k=5, smoother=0.01: LL=-0.2525
# Species pul, k=5, smoother=0.1: LL=-0.2536
# Species pul, k=0, smoother=0.001: LL=-2.2647
# Species pul, k=0, smoother=0.01: LL=-2.2647
# Species pul, k=0, smoother=0.1: LL=-2.2647
# Species pul, k=1, smoother=0.001: LL=-0.0689
# Species pul, k=1, smoother=0.01: LL=-0.0689
# Species pul, k=1, smoother=0.1: LL=-0.0689
# Species pul, k=2, smoother=0.001: LL=-0.0660
# Species pul, k=2, smoother=0.01: LL=-0.0659
# Species pul, k=2, smoother=0.1: LL=-0.0659
# Species pul, k=3, smoother=0.001: LL=-0.0667
# Species pul, k=3, smoother=0.01: LL=-0.0663
# Species pul, k=3, smoother=0.1: LL=-0.0663
# Species pul, k=4, smoother=0.001: LL=-0.0985
# Species pul, k=4, smoother=0.01: LL=-0.0973
# Species pul, k=4, smoother=0.1: LL=-0.0975
# Species pul, k=5, smoother=0.001: LL=-0.2175
# Species pul, k=5, smoother=0.01: LL=-0.2125
# Species pul, k=5, smoother=0.1: LL=-0.2121
# Species pul, k=0, smoother=0.001: LL=-2.2384
# Species pul, k=0, smoother=0.01: LL=-2.2384
# Species pul, k=0, smoother=0.1: LL=-2.2384
# Species pul, k=1, smoother=0.001: LL=-0.0747
# Species pul, k=1, smoother=0.01: LL=-0.0747
# Species pul, k=1, smoother=0.1: LL=-0.0747
# Species pul, k=2, smoother=0.001: LL=-0.0710
# Species pul, k=2, smoother=0.01: LL=-0.0710
# Species pul, k=2, smoother=0.1: LL=-0.0710
# Species pul, k=3, smoother=0.001: LL=-0.0719
# Species pul, k=3, smoother=0.01: LL=-0.0717
# Species pul, k=3, smoother=0.1: LL=-0.0717
# Species pul, k=4, smoother=0.001: LL=-0.0980
# Species pul, k=4, smoother=0.01: LL=-0.0968
# Species pul, k=4, smoother=0.1: LL=-0.0966
# Species pul, k=5, smoother=0.001: LL=-0.2129
# Species pul, k=5, smoother=0.01: LL=-0.2102
# Species pul, k=5, smoother=0.1: LL=-0.2109
# Species pul, k=0, smoother=0.001: LL=-2.2005
# Species pul, k=0, smoother=0.01: LL=-2.2005
# Species pul, k=0, smoother=0.1: LL=-2.2005
# Species pul, k=1, smoother=0.001: LL=-0.0674
# Species pul, k=1, smoother=0.01: LL=-0.0674
# Species pul, k=1, smoother=0.1: LL=-0.0674
# Species pul, k=2, smoother=0.001: LL=-0.0644
# Species pul, k=2, smoother=0.01: LL=-0.0644
# Species pul, k=2, smoother=0.1: LL=-0.0644
# Species pul, k=3, smoother=0.001: LL=-0.0645
# Species pul, k=3, smoother=0.01: LL=-0.0642
# Species pul, k=3, smoother=0.1: LL=-0.0642
# Species pul, k=4, smoother=0.001: LL=-0.0830
# Species pul, k=4, smoother=0.01: LL=-0.0821
# Species pul, k=4, smoother=0.1: LL=-0.0826
# Species pul, k=5, smoother=0.001: LL=-0.1998
# Species pul, k=5, smoother=0.01: LL=-0.1972
# Species pul, k=5, smoother=0.1: LL=-0.1981
# Species pul, k=0, smoother=0.001: LL=-2.2347
# Species pul, k=0, smoother=0.01: LL=-2.2347
# Species pul, k=0, smoother=0.1: LL=-2.2347
# Species pul, k=1, smoother=0.001: LL=-0.0792
# Species pul, k=1, smoother=0.01: LL=-0.0792
# Species pul, k=1, smoother=0.1: LL=-0.0792
# Species pul, k=2, smoother=0.001: LL=-0.0748
# Species pul, k=2, smoother=0.01: LL=-0.0747
# Species pul, k=2, smoother=0.1: LL=-0.0747
# Species pul, k=3, smoother=0.001: LL=-0.0761
# Species pul, k=3, smoother=0.01: LL=-0.0756
# Species pul, k=3, smoother=0.1: LL=-0.0757
# Species pul, k=4, smoother=0.001: LL=-0.1049
# Species pul, k=4, smoother=0.01: LL=-0.1031
# Species pul, k=4, smoother=0.1: LL=-0.1035
# Species pul, k=5, smoother=0.001: LL=-0.2611
# Species pul, k=5, smoother=0.01: LL=-0.2580
# Species pul, k=5, smoother=0.1: LL=-0.2629
# Species pul, k=0, smoother=0.001: LL=-2.2031
# Species pul, k=0, smoother=0.01: LL=-2.2031
# Species pul, k=0, smoother=0.1: LL=-2.2031
# Species pul, k=1, smoother=0.001: LL=-0.0689
# Species pul, k=1, smoother=0.01: LL=-0.0689
# Species pul, k=1, smoother=0.1: LL=-0.0689
# Species pul, k=2, smoother=0.001: LL=-0.0653
# Species pul, k=2, smoother=0.01: LL=-0.0653
# Species pul, k=2, smoother=0.1: LL=-0.0653
# Species pul, k=3, smoother=0.001: LL=-0.0654
# Species pul, k=3, smoother=0.01: LL=-0.0652
# Species pul, k=3, smoother=0.1: LL=-0.0651
# Species pul, k=4, smoother=0.001: LL=-0.0948
# Species pul, k=4, smoother=0.01: LL=-0.0936
# Species pul, k=4, smoother=0.1: LL=-0.0940
# Species pul, k=5, smoother=0.001: LL=-0.2054
# Species pul, k=5, smoother=0.01: LL=-0.2024
# Species pul, k=5, smoother=0.1: LL=-0.2033
# Species pul, k=0, smoother=0.001: LL=-2.2955
# Species pul, k=0, smoother=0.01: LL=-2.2955
# Species pul, k=0, smoother=0.1: LL=-2.2955
# Species pul, k=1, smoother=0.001: LL=-0.0682
# Species pul, k=1, smoother=0.01: LL=-0.0682
# Species pul, k=1, smoother=0.1: LL=-0.0682
# Species pul, k=2, smoother=0.001: LL=-0.0646
# Species pul, k=2, smoother=0.01: LL=-0.0645
# Species pul, k=2, smoother=0.1: LL=-0.0645
# Species pul, k=3, smoother=0.001: LL=-0.0652
# Species pul, k=3, smoother=0.01: LL=-0.0648
# Species pul, k=3, smoother=0.1: LL=-0.0647
# Species pul, k=4, smoother=0.001: LL=-0.0997
# Species pul, k=4, smoother=0.01: LL=-0.0983
# Species pul, k=4, smoother=0.1: LL=-0.0982
# Species pul, k=5, smoother=0.001: LL=-0.2148
# Species pul, k=5, smoother=0.01: LL=-0.2106
# Species pul, k=5, smoother=0.1: LL=-0.2110
# Species pul, k=0, smoother=0.001: LL=-2.3138
# Species pul, k=0, smoother=0.01: LL=-2.3138
# Species pul, k=0, smoother=0.1: LL=-2.3138
# Species pul, k=1, smoother=0.001: LL=-0.0762
# Species pul, k=1, smoother=0.01: LL=-0.0762
# Species pul, k=1, smoother=0.1: LL=-0.0762
# Species pul, k=2, smoother=0.001: LL=-0.0727
# Species pul, k=2, smoother=0.01: LL=-0.0726
# Species pul, k=2, smoother=0.1: LL=-0.0726
# Species pul, k=3, smoother=0.001: LL=-0.0770
# Species pul, k=3, smoother=0.01: LL=-0.0766
# Species pul, k=3, smoother=0.1: LL=-0.0764
# Species pul, k=4, smoother=0.001: LL=-0.0981
# Species pul, k=4, smoother=0.01: LL=-0.0969
# Species pul, k=4, smoother=0.1: LL=-0.0967
# Species pul, k=5, smoother=0.001: LL=-0.2020
# Species pul, k=5, smoother=0.01: LL=-0.1994
# Species pul, k=5, smoother=0.1: LL=-0.2005
# Species pul, k=0, smoother=0.001: LL=-2.2405
# Species pul, k=0, smoother=0.01: LL=-2.2405
# Species pul, k=0, smoother=0.1: LL=-2.2405
# Species pul, k=1, smoother=0.001: LL=-0.0773
# Species pul, k=1, smoother=0.01: LL=-0.0773
# Species pul, k=1, smoother=0.1: LL=-0.0773
# Species pul, k=2, smoother=0.001: LL=-0.0743
# Species pul, k=2, smoother=0.01: LL=-0.0742
# Species pul, k=2, smoother=0.1: LL=-0.0741
# Species pul, k=3, smoother=0.001: LL=-0.0773
# Species pul, k=3, smoother=0.01: LL=-0.0770
# Species pul, k=3, smoother=0.1: LL=-0.0770
# Species pul, k=4, smoother=0.001: LL=-0.1134
# Species pul, k=4, smoother=0.01: LL=-0.1121
# Species pul, k=4, smoother=0.1: LL=-0.1127
# Species pul, k=5, smoother=0.001: LL=-0.2384
# Species pul, k=5, smoother=0.01: LL=-0.2357
# Species pul, k=5, smoother=0.1: LL=-0.2374
# Species pul, k=0, smoother=0.001: LL=-2.2768
# Species pul, k=0, smoother=0.01: LL=-2.2768
# Species pul, k=0, smoother=0.1: LL=-2.2768
# Species pul, k=1, smoother=0.001: LL=-0.0770
# Species pul, k=1, smoother=0.01: LL=-0.0770
# Species pul, k=1, smoother=0.1: LL=-0.0770
# Species pul, k=2, smoother=0.001: LL=-0.0731
# Species pul, k=2, smoother=0.01: LL=-0.0731
# Species pul, k=2, smoother=0.1: LL=-0.0731
# Species pul, k=3, smoother=0.001: LL=-0.0730
# Species pul, k=3, smoother=0.01: LL=-0.0726
# Species pul, k=3, smoother=0.1: LL=-0.0725
# Species pul, k=4, smoother=0.001: LL=-0.1004
# Species pul, k=4, smoother=0.01: LL=-0.0990
# Species pul, k=4, smoother=0.1: LL=-0.0999
# Species pul, k=5, smoother=0.001: LL=-0.2299
# Species pul, k=5, smoother=0.01: LL=-0.2270
# Species pul, k=5, smoother=0.1: LL=-0.2300
# Species pul, k=0, smoother=0.001: LL=-2.2631
# Species pul, k=0, smoother=0.01: LL=-2.2631
# Species pul, k=0, smoother=0.1: LL=-2.2631
# Species pul, k=1, smoother=0.001: LL=-0.0657
# Species pul, k=1, smoother=0.01: LL=-0.0657
# Species pul, k=1, smoother=0.1: LL=-0.0657
# Species pul, k=2, smoother=0.001: LL=-0.0629
# Species pul, k=2, smoother=0.01: LL=-0.0628
# Species pul, k=2, smoother=0.1: LL=-0.0629
# Species pul, k=3, smoother=0.001: LL=-0.0795
# Species pul, k=3, smoother=0.01: LL=-0.0748
# Species pul, k=3, smoother=0.1: LL=-0.0716
# Species pul, k=4, smoother=0.001: LL=-0.1001
# Species pul, k=4, smoother=0.01: LL=-0.0946
# Species pul, k=4, smoother=0.1: LL=-0.0917
# Species pul, k=5, smoother=0.001: LL=-0.2061
# Species pul, k=5, smoother=0.01: LL=-0.2024
# Species pul, k=5, smoother=0.1: LL=-0.2023
# Species pul, k=0, smoother=0.001: LL=-2.1990
# Species pul, k=0, smoother=0.01: LL=-2.1990
# Species pul, k=0, smoother=0.1: LL=-2.1990
# Species pul, k=1, smoother=0.001: LL=-0.0661
# Species pul, k=1, smoother=0.01: LL=-0.0661
# Species pul, k=1, smoother=0.1: LL=-0.0661
# Species pul, k=2, smoother=0.001: LL=-0.0629
# Species pul, k=2, smoother=0.01: LL=-0.0628
# Species pul, k=2, smoother=0.1: LL=-0.0628
# Species pul, k=3, smoother=0.001: LL=-0.0682
# Species pul, k=3, smoother=0.01: LL=-0.0678
# Species pul, k=3, smoother=0.1: LL=-0.0677
# Species pul, k=4, smoother=0.001: LL=-0.0898
# Species pul, k=4, smoother=0.01: LL=-0.0888
# Species pul, k=4, smoother=0.1: LL=-0.0892
# Species pul, k=5, smoother=0.001: LL=-0.1911
# Species pul, k=5, smoother=0.01: LL=-0.1873
# Species pul, k=5, smoother=0.1: LL=-0.1876
# Species pul, k=0, smoother=0.001: LL=-2.2299
# Species pul, k=0, smoother=0.01: LL=-2.2299
# Species pul, k=0, smoother=0.1: LL=-2.2299
# Species pul, k=1, smoother=0.001: LL=-0.0699
# Species pul, k=1, smoother=0.01: LL=-0.0699
# Species pul, k=1, smoother=0.1: LL=-0.0699
# Species pul, k=2, smoother=0.001: LL=-0.0659
# Species pul, k=2, smoother=0.01: LL=-0.0659
# Species pul, k=2, smoother=0.1: LL=-0.0659
# Species pul, k=3, smoother=0.001: LL=-0.0658
# Species pul, k=3, smoother=0.01: LL=-0.0655
# Species pul, k=3, smoother=0.1: LL=-0.0654
# Species pul, k=4, smoother=0.001: LL=-0.0910
# Species pul, k=4, smoother=0.01: LL=-0.0866
# Species pul, k=4, smoother=0.1: LL=-0.0843
# Species pul, k=5, smoother=0.001: LL=-0.2391
# Species pul, k=5, smoother=0.01: LL=-0.2300
# Species pul, k=5, smoother=0.1: LL=-0.2270
